# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#importing dataset
bugs=pd.read_csv(r"E:\Project\Firefox_Bugs_data.csv")
bugs.head()
# Out:
#     Bug ID     Reporting                                            Summary  \
# 0  1116989      Beginner       Guest users should not see introduction info
# 1  1047673      Beginner  URL checksums (for "securely" linking third-pa...
# 2  1108341  Intermediate  Context menu entries use the original URI inst...
# 3  1111278  Intermediate  A strip with all(?) possible icons is showing ...
# 4   992209      Beginner  invoking firefox with command line argument(s)...
#
#    Product                   Component Assignee       Status Notification  \
# 0  Firefox  Toolbars and Customization   Random  Unconfirmed       Normal
# 1  Firefox                     General   Random  Unconfirmed       Normal
# 2  Firefox                       Menus   Random  Unconfirmed       Normal
# 3  Firefox  Toolbars and Customization   Random  Unconfirmed         High
# 4  Firefox                     General   Random  Unconfirmed         High
#
#           Updated
# 0  1/2/2015 12:31
# 1  1/2/2015 14:16
# ...

# %%
#assigning integer values to values in Reporting column
def trans_reporting(x):
    if x == 'Beginner':
        return 0
    if x == 'Intermediate':
        return 1
    if x == 'Advanced':
        return 2

# %%
#assigning integer values to values in Assignee column
def trans_assignee(x):
    if x == 'Particular':
        return 0
    if x == 'Random':
        return 1

# %%
#assigning integer values to values in Status column
def trans_status(x):
    if x == 'Unconfirmed':
        return 0
    if x == 'New':
        return 1

# %%
#assigning integer values to values in Notification column
def trans_notification(x):
    if x == 'Normal':
        return 0
    if x == 'High':
        return 1

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#applying these values to Firefox_bugs dataset
bugs['Trans_Reporting']=bugs['Reporting'].apply(trans_reporting)
bugs['Trans_Assignee']=bugs['Assignee'].apply(trans_assignee)
bugs['Trans_Status']=bugs['Status'].apply(trans_status)
bugs['Trans_Notification']=bugs['Notification'].apply(trans_notification)

# %%
#importing date-time
bugs["Updated"] = pd.to_datetime(bugs["Updated"])
bugs.head(5)
# Out:
#     Bug ID     Reporting                                            Summary  \
# 0  1116989      Beginner       Guest users should not see introduction info
# 1  1047673      Beginner  URL checksums (for "securely" linking third-pa...
# 2  1108341  Intermediate  Context menu entries use the original URI inst...
# 3  1111278  Intermediate  A strip with all(?) possible icons is showing ...
# 4   992209      Beginner  invoking firefox with command line argument(s)...
#
#    Product                   Component Assignee       Status Notification  \
# 0  Firefox  Toolbars and Customization   Random  Unconfirmed       Normal
# 1  Firefox                     General   Random  Unconfirmed       Normal
# 2  Firefox                       Menus   Random  Unconfirmed       Normal
# 3  Firefox  Toolbars and Customization   Random  Unconfirmed         High
# 4  Firefox                     General   Random  Unconfirmed         High
#
# ...

# %%
#assigning index for Updated column
bugs.set_index("Updated").head(2)
# Out:
#                       Bug ID Reporting  \
# Updated
# 2015-01-02 12:31:00  1116989  Beginner
# 2015-01-02 14:16:00  1047673  Beginner
#
#                                                                Summary  \
# Updated
# 2015-01-02 12:31:00       Guest users should not see introduction info
# 2015-01-02 14:16:00  URL checksums (for "securely" linking third-pa...
#
#                      Product                   Component Assignee  \
# Updated
# 2015-01-02 12:31:00  Firefox  Toolbars and Customization   Random
# 2015-01-02 14:16:00  Firefox                     General   Random
#
#                           Status Notification  Trans_Reporting  \
# Updated
# 2015-01-02 12:31:00  Unconfirmed       Normal                0
# 2015-01-02 14:16:00  Unconfirmed       Normal                0
#
#                      Trans_Assignee  Trans_Status  Trans_Notification
# Updated
# 2015-01-02 12:31:00               1             0                   0
# ...

# %%
#grouping bugs in 2015 into one dataset
Firefox_bugs_2015 = bugs[bugs["Updated"].between('2015-01-02','2016-01-01')]
#grouping bugs in 2016 into one dataset
Firefox_bugs_2016 = bugs[bugs["Updated"].between('2016-01-01','2017-01-01')]
#grouping bugs in 2017 into one dataset
Firefox_bugs_2017 = bugs[bugs["Updated"].between('2017-01-01','2018-01-03')]
#grouping bugs in 2018 into one dataset
Firefox_bugs_2018 = bugs[bugs["Updated"].between('2018-01-03','2019-01-02')]
#grouping bugs in 2019 into one dataset
Firefox_bugs_2019 = bugs[bugs["Updated"].between('2019-01-02','2020-01-02')]
#grouping bugs in 2020 into one dataset
Firefox_bugs_2020 = bugs[bugs["Updated"].between('2020-01-02','2021-04-01')]
#grouping bugs in 2021 into one dataset
Firefox_bugs_2021 = bugs[bugs["Updated"].between('2021-04-01','2022-01-01')]
#grouping bugs in 2022 into one dataset
Firefox_bugs_2022 = bugs[bugs["Updated"].between('2022-01-01','2022-11-09')]

# %%
#applying these values to Firefox_bugs_2015 dataset
Firefox_bugs_2015['Trans_Reporting']=Firefox_bugs_2015['Reporting'].apply(trans_reporting)
Firefox_bugs_2015['Trans_Assignee']=Firefox_bugs_2015['Assignee'].apply(trans_assignee)
Firefox_bugs_2015['Trans_Status']=Firefox_bugs_2015['Status'].apply(trans_status)
Firefox_bugs_2015['Trans_Notification']=Firefox_bugs_2015['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2016 dataset
Firefox_bugs_2016['Trans_Reporting']=Firefox_bugs_2016['Reporting'].apply(trans_reporting)
Firefox_bugs_2016['Trans_Assignee']=Firefox_bugs_2016['Assignee'].apply(trans_assignee)
Firefox_bugs_2016['Trans_Status']=Firefox_bugs_2016['Status'].apply(trans_status)
Firefox_bugs_2016['Trans_Notification']=Firefox_bugs_2016['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2017 dataset
Firefox_bugs_2017['Trans_Reporting']=Firefox_bugs_2017['Reporting'].apply(trans_reporting)
Firefox_bugs_2017['Trans_Assignee']=Firefox_bugs_2017['Assignee'].apply(trans_assignee)
Firefox_bugs_2017['Trans_Status']=Firefox_bugs_2017['Status'].apply(trans_status)
Firefox_bugs_2017['Trans_Notification']=Firefox_bugs_2017['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2018 dataset
Firefox_bugs_2018['Trans_Reporting']=Firefox_bugs_2018['Reporting'].apply(trans_reporting)
Firefox_bugs_2018['Trans_Assignee']=Firefox_bugs_2018['Assignee'].apply(trans_assignee)
Firefox_bugs_2018['Trans_Status']=Firefox_bugs_2018['Status'].apply(trans_status)
Firefox_bugs_2018['Trans_Notification']=Firefox_bugs_2018['Notification'].apply(trans_notification)
Firefox_bugs_2018.head(5)
#applying these values to Firefox_bugs_2019 dataset
Firefox_bugs_2019['Trans_Reporting']=Firefox_bugs_2019['Reporting'].apply(trans_reporting)
Firefox_bugs_2019['Trans_Assignee']=Firefox_bugs_2019['Assignee'].apply(trans_assignee)
Firefox_bugs_2019['Trans_Status']=Firefox_bugs_2019['Status'].apply(trans_status)
Firefox_bugs_2019['Trans_Notification']=Firefox_bugs_2019['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2020 dataset
Firefox_bugs_2020['Trans_Reporting']=Firefox_bugs_2020['Reporting'].apply(trans_reporting)
Firefox_bugs_2020['Trans_Assignee']=Firefox_bugs_2020['Assignee'].apply(trans_assignee)
Firefox_bugs_2020['Trans_Status']=Firefox_bugs_2020['Status'].apply(trans_status)
Firefox_bugs_2020['Trans_Notification']=Firefox_bugs_2020['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2021 dataset
Firefox_bugs_2021['Trans_Reporting']=Firefox_bugs_2021['Reporting'].apply(trans_reporting)
Firefox_bugs_2021['Trans_Assignee']=Firefox_bugs_2021['Assignee'].apply(trans_assignee)
Firefox_bugs_2021['Trans_Status']=Firefox_bugs_2021['Status'].apply(trans_status)
Firefox_bugs_2021['Trans_Notification']=Firefox_bugs_2021['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2022 dataset
Firefox_bugs_2022['Trans_Reporting']=Firefox_bugs_2022['Reporting'].apply(trans_reporting)
Firefox_bugs_2022['Trans_Assignee']=Firefox_bugs_2022['Assignee'].apply(trans_assignee)
Firefox_bugs_2022['Trans_Status']=Firefox_bugs_2022['Status'].apply(trans_status)
Firefox_bugs_2022['Trans_Notification']=Firefox_bugs_2022['Notification'].apply(trans_notification)

# %%
#assingning values to x1,x2,x3,x4,x5,x6,x7,x8 and y1,y2,y3,y4,y5,y6,y7,y8
X1=Firefox_bugs_2015.iloc[:,9:12].values
y1=Firefox_bugs_2015.iloc[:,12:13].values
X2=Firefox_bugs_2016.iloc[:,9:12].values
y2=Firefox_bugs_2016.iloc[:,12:13].values
X3=Firefox_bugs_2017.iloc[:,9:12].values
y3=Firefox_bugs_2017.iloc[:,12:13].values
X4=Firefox_bugs_2018.iloc[:,9:12].values
y4=Firefox_bugs_2018.iloc[:,12:13].values
X5=Firefox_bugs_2019.iloc[:,9:12].values
y5=Firefox_bugs_2019.iloc[:,12:13].values
X6=Firefox_bugs_2020.iloc[:,9:12].values
y6=Firefox_bugs_2020.iloc[:,12:13].values
X7=Firefox_bugs_2021.iloc[:,9:12].values
y7=Firefox_bugs_2021.iloc[:,12:13].values
X8=Firefox_bugs_2022.iloc[:,9:12].values
y8=Firefox_bugs_2022.iloc[:,12:13].values

# %%
#diving the dataset into training and testing data
from sklearn.model_selection import train_test_split  
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1,y1,test_size=0.2)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2,y2,test_size=0.2)
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3,y3,test_size=0.2)
X_train4, X_test4, y_train4, y_test4 = train_test_split(X4,y4,test_size=0.2)
X_train5, X_test5, y_train5, y_test5 = train_test_split(X5,y5,test_size=0.2)
X_train6, X_test6, y_train6, y_test6 = train_test_split(X6,y6,test_size=0.2)
X_train7, X_test7, y_train7, y_test7 = train_test_split(X7,y7,test_size=0.2)
X_train8, X_test8, y_train8, y_test8 = train_test_split(X8,y8,test_size=0.2)

# %%
#assingning values to x and y
X=bugs.iloc[:,9:12].values
y=bugs.iloc[:,12:13].values

# %%
#diving the dataset into 80% training and 20% testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7026
# Fold 2: 0.7162
# Fold 3: 0.6741
# Fold 4: 0.7171
# Fold 5: 0.6911
# Fold 6: 0.7159
# Fold 7: 0.7084
# Fold 8: 0.6935
# Fold 9: 0.6873
# Fold 10: 0.7146
#
# Iteration 2:
# Fold 1: 0.7063
# Fold 2: 0.6753
# Fold 3: 0.7138
# Fold 4: 0.6998
# Fold 5: 0.7320
# Fold 6: 0.6861
# Fold 7: 0.6935
# Fold 8: 0.7084
# Fold 9: 0.6985
# Fold 10: 0.7072
#
# Iteration 3:
# Fold 1: 0.6902
# Fold 2: 0.6914
# Fold 3: 0.7051
# Fold 4: 0.6911
# Fold 5: 0.7233
# Fold 6: 0.6873
# Fold 7: 0.6861
# Fold 8: 0.7159
# Fold 9: 0.7134
# Fold 10: 0.7171
#
# Iteration 4:
# Fold 1: 0.7224
# Fold 2: 0.6865
# Fold 3: 0.6815
# Fold 4: 0.6960
# Fold 5: 0.7084
# Fold 6: 0.7072
# Fold 7: 0.6985
# Fold 8: 0.7035
# Fold 9: 0.6973
# Fold 10: 0.7196
#
# Iteration 5:
# Fold 1: 0.6902
# Fold 2: 0.7076
# Fold 3: 0.7026
# Fold 4: 0.7084
# Fold 5: 0.6973
# Fold 6: 0.7196
# Fold 7: 0.6911
# Fold 8: 0.6935
# Fold 9: 0.7047
# Fold 10: 0.7060
#
# Iteration 6:
# Fold 1: 0.6865
# Fold 2: 0.7026
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_1 = np.mean(mnb_cv_scores)
mnb_std_scores_1 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_1)
print("Standard Deviations:", mnb_std_scores_1)
# Out:
# Mean Scores: 0.7020969279351579
# Standard Deviations: 0.013545174954489262

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7113
# Fold 2: 0.6729
# Fold 3: 0.6989
# Fold 4: 0.7097
# Fold 5: 0.6998
# Fold 6: 0.6749
# Fold 7: 0.6923
# Fold 8: 0.7146
# Fold 9: 0.7122
# Fold 10: 0.7345
#
# Iteration 2:
# Fold 1: 0.7038
# Fold 2: 0.7076
# Fold 3: 0.6853
# Fold 4: 0.7208
# Fold 5: 0.6911
# Fold 6: 0.7122
# Fold 7: 0.6824
# Fold 8: 0.7022
# Fold 9: 0.6985
# Fold 10: 0.7171
#
# Iteration 3:
# Fold 1: 0.7138
# Fold 2: 0.6853
# Fold 3: 0.6890
# Fold 4: 0.7159
# Fold 5: 0.7010
# Fold 6: 0.7060
# Fold 7: 0.6911
# Fold 8: 0.7060
# Fold 9: 0.7109
# Fold 10: 0.7022
#
# Iteration 4:
# Fold 1: 0.6778
# Fold 2: 0.7162
# Fold 3: 0.6704
# Fold 4: 0.6998
# Fold 5: 0.7333
# Fold 6: 0.6935
# Fold 7: 0.6998
# Fold 8: 0.6849
# Fold 9: 0.7457
# Fold 10: 0.6998
#
# Iteration 5:
# Fold 1: 0.6890
# Fold 2: 0.6865
# Fold 3: 0.6890
# Fold 4: 0.6911
# Fold 5: 0.7146
# Fold 6: 0.7122
# Fold 7: 0.6935
# Fold 8: 0.6973
# Fold 9: 0.7233
# Fold 10: 0.7246
#
# Iteration 6:
# Fold 1: 0.6927
# Fold 2: 0.7001
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_2 = np.mean(mnb_cv_scores)
mnb_std_scores_2 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_2)
print("Standard Deviations:", mnb_std_scores_2)
# Out:
# Mean Scores: 0.7020976966432058
# Standard Deviations: 0.01605713468272106

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7311
# Fold 2: 0.7113
# Fold 3: 0.7224
# Fold 4: 0.6787
# Fold 5: 0.7146
# Fold 6: 0.6774
# Fold 7: 0.6973
# Fold 8: 0.7184
# Fold 9: 0.7047
# Fold 10: 0.6650
#
# Iteration 2:
# Fold 1: 0.7138
# Fold 2: 0.7373
# Fold 3: 0.6791
# Fold 4: 0.6973
# Fold 5: 0.7035
# Fold 6: 0.6985
# Fold 7: 0.6985
# Fold 8: 0.7060
# Fold 9: 0.6737
# Fold 10: 0.7134
#
# Iteration 3:
# Fold 1: 0.7224
# Fold 2: 0.7076
# Fold 3: 0.7038
# Fold 4: 0.6985
# Fold 5: 0.7246
# Fold 6: 0.6799
# Fold 7: 0.7097
# Fold 8: 0.6985
# Fold 9: 0.6960
# Fold 10: 0.6799
#
# Iteration 4:
# Fold 1: 0.7274
# Fold 2: 0.7038
# Fold 3: 0.6927
# Fold 4: 0.7072
# Fold 5: 0.7060
# Fold 6: 0.7084
# Fold 7: 0.7060
# Fold 8: 0.7022
# Fold 9: 0.6749
# Fold 10: 0.6923
#
# Iteration 5:
# Fold 1: 0.6828
# Fold 2: 0.6976
# Fold 3: 0.7175
# Fold 4: 0.7134
# Fold 5: 0.6985
# Fold 6: 0.7022
# Fold 7: 0.6700
# Fold 8: 0.6923
# Fold 9: 0.7084
# Fold 10: 0.7382
#
# Iteration 6:
# Fold 1: 0.6927
# Fold 2: 0.7113
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_3 = np.mean(mnb_cv_scores)
mnb_std_scores_3 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_3)
print("Standard Deviations:", mnb_std_scores_3)
# Out:
# Mean Scores: 0.7020947448043023
# Standard Deviations: 0.01612190663125187

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6902
# Fold 2: 0.7001
# Fold 3: 0.7076
# Fold 4: 0.7184
# Fold 5: 0.6687
# Fold 6: 0.7097
# Fold 7: 0.7184
# Fold 8: 0.7184
# Fold 9: 0.6762
# Fold 10: 0.7134
#
# Iteration 2:
# Fold 1: 0.7150
# Fold 2: 0.6853
# Fold 3: 0.7224
# Fold 4: 0.6787
# Fold 5: 0.6923
# Fold 6: 0.6948
# Fold 7: 0.7370
# Fold 8: 0.7010
# Fold 9: 0.6985
# Fold 10: 0.6960
#
# Iteration 3:
# Fold 1: 0.6976
# Fold 2: 0.7113
# Fold 3: 0.6803
# Fold 4: 0.6998
# Fold 5: 0.6948
# Fold 6: 0.7208
# Fold 7: 0.7146
# Fold 8: 0.6985
# Fold 9: 0.6960
# Fold 10: 0.7072
#
# Iteration 4:
# Fold 1: 0.6914
# Fold 2: 0.6865
# Fold 3: 0.7038
# Fold 4: 0.7159
# Fold 5: 0.6935
# Fold 6: 0.7084
# Fold 7: 0.7010
# Fold 8: 0.6849
# Fold 9: 0.6898
# Fold 10: 0.7457
#
# Iteration 5:
# Fold 1: 0.6803
# Fold 2: 0.7014
# Fold 3: 0.6989
# Fold 4: 0.6960
# Fold 5: 0.7072
# Fold 6: 0.7060
# Fold 7: 0.7109
# Fold 8: 0.7084
# Fold 9: 0.7022
# Fold 10: 0.7097
#
# Iteration 6:
# Fold 1: 0.6927
# Fold 2: 0.7038
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_4 = np.mean(mnb_cv_scores)
mnb_std_scores_4 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_4)
print("Standard Deviations:", mnb_std_scores_4)
# Out:
# Mean Scores: 0.7020962207237541
# Standard Deviations: 0.015041876938787365

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7113
# Fold 2: 0.6976
# Fold 3: 0.6902
# Fold 4: 0.7171
# Fold 5: 0.6799
# Fold 6: 0.6911
# Fold 7: 0.7419
# Fold 8: 0.6886
# Fold 9: 0.7072
# Fold 10: 0.6960
#
# Iteration 2:
# Fold 1: 0.7125
# Fold 2: 0.7001
# Fold 3: 0.7014
# Fold 4: 0.7333
# Fold 5: 0.6985
# Fold 6: 0.6861
# Fold 7: 0.7072
# Fold 8: 0.7047
# Fold 9: 0.6787
# Fold 10: 0.6985
#
# Iteration 3:
# Fold 1: 0.7138
# Fold 2: 0.7063
# Fold 3: 0.7038
# Fold 4: 0.7022
# Fold 5: 0.6873
# Fold 6: 0.7097
# Fold 7: 0.7060
# Fold 8: 0.7084
# Fold 9: 0.6898
# Fold 10: 0.6935
#
# Iteration 4:
# Fold 1: 0.7162
# Fold 2: 0.7001
# Fold 3: 0.6989
# Fold 4: 0.7035
# Fold 5: 0.7258
# Fold 6: 0.6700
# Fold 7: 0.7047
# Fold 8: 0.6973
# Fold 9: 0.7097
# Fold 10: 0.6948
#
# Iteration 5:
# Fold 1: 0.7113
# Fold 2: 0.6952
# Fold 3: 0.6952
# Fold 4: 0.7035
# Fold 5: 0.7060
# Fold 6: 0.6998
# Fold 7: 0.6873
# Fold 8: 0.7109
# Fold 9: 0.7159
# Fold 10: 0.6960
#
# Iteration 6:
# Fold 1: 0.7274
# Fold 2: 0.6815
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_5 = np.mean(mnb_cv_scores)
mnb_std_scores_5 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_5)
print("Standard Deviations:", mnb_std_scores_5)
# Out:
# Mean Scores: 0.7020959132405348
# Standard Deviations: 0.013393835556726026

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6964
# Fold 2: 0.7398
# Fold 3: 0.6976
# Fold 4: 0.7060
# Fold 5: 0.6898
# Fold 6: 0.6948
# Fold 7: 0.6935
# Fold 8: 0.7109
# Fold 9: 0.6873
# Fold 10: 0.7047
#
# Iteration 2:
# Fold 1: 0.6976
# Fold 2: 0.6741
# Fold 3: 0.6914
# Fold 4: 0.7084
# Fold 5: 0.7010
# Fold 6: 0.7022
# Fold 7: 0.7146
# Fold 8: 0.7084
# Fold 9: 0.7047
# Fold 10: 0.7184
#
# Iteration 3:
# Fold 1: 0.6989
# Fold 2: 0.6927
# Fold 3: 0.7200
# Fold 4: 0.7035
# Fold 5: 0.6712
# Fold 6: 0.7345
# Fold 7: 0.6973
# Fold 8: 0.6824
# Fold 9: 0.7221
# Fold 10: 0.6985
#
# Iteration 4:
# Fold 1: 0.6840
# Fold 2: 0.6890
# Fold 3: 0.7076
# Fold 4: 0.7010
# Fold 5: 0.7084
# Fold 6: 0.7060
# Fold 7: 0.6774
# Fold 8: 0.7022
# Fold 9: 0.7246
# Fold 10: 0.7208
#
# Iteration 5:
# Fold 1: 0.7249
# Fold 2: 0.7076
# Fold 3: 0.6927
# Fold 4: 0.6849
# Fold 5: 0.7171
# Fold 6: 0.6811
# Fold 7: 0.7047
# Fold 8: 0.6948
# Fold 9: 0.7060
# Fold 10: 0.7072
#
# Iteration 6:
# Fold 1: 0.7088
# Fold 2: 0.7237
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_6 = np.mean(mnb_cv_scores)
mnb_std_scores_6 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_6)
print("Standard Deviations:", mnb_std_scores_6)
# Out:
# Mean Scores: 0.7020963437170415
# Standard Deviations: 0.014995671282596636

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7038
# Fold 2: 0.6964
# Fold 3: 0.7138
# Fold 4: 0.6935
# Fold 5: 0.7047
# Fold 6: 0.6836
# Fold 7: 0.7270
# Fold 8: 0.6973
# Fold 9: 0.6935
# Fold 10: 0.7072
#
# Iteration 2:
# Fold 1: 0.6778
# Fold 2: 0.7212
# Fold 3: 0.6853
# Fold 4: 0.7196
# Fold 5: 0.6824
# Fold 6: 0.7295
# Fold 7: 0.6861
# Fold 8: 0.7022
# Fold 9: 0.7208
# Fold 10: 0.6960
#
# Iteration 3:
# Fold 1: 0.6976
# Fold 2: 0.6989
# Fold 3: 0.6778
# Fold 4: 0.6675
# Fold 5: 0.7084
# Fold 6: 0.7258
# Fold 7: 0.7122
# Fold 8: 0.7208
# Fold 9: 0.7072
# Fold 10: 0.7047
#
# Iteration 4:
# Fold 1: 0.6989
# Fold 2: 0.7299
# Fold 3: 0.7014
# Fold 4: 0.7196
# Fold 5: 0.6737
# Fold 6: 0.7035
# Fold 7: 0.6948
# Fold 8: 0.6998
# Fold 9: 0.7047
# Fold 10: 0.6948
#
# Iteration 5:
# Fold 1: 0.7026
# Fold 2: 0.6964
# Fold 3: 0.6840
# Fold 4: 0.7171
# Fold 5: 0.7010
# Fold 6: 0.7208
# Fold 7: 0.7097
# Fold 8: 0.7060
# Fold 9: 0.6898
# Fold 10: 0.6935
#
# Iteration 6:
# Fold 1: 0.7125
# Fold 2: 0.7063
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_7 = np.mean(mnb_cv_scores)
mnb_std_scores_7 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_7)
print("Standard Deviations:", mnb_std_scores_7)
# Out:
# Mean Scores: 0.7020959747371788
# Standard Deviations: 0.014892874029123865

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7026
# Fold 2: 0.6778
# Fold 3: 0.7113
# Fold 4: 0.7022
# Fold 5: 0.7084
# Fold 6: 0.6886
# Fold 7: 0.7022
# Fold 8: 0.7084
# Fold 9: 0.7060
# Fold 10: 0.7134
#
# Iteration 2:
# Fold 1: 0.6803
# Fold 2: 0.7051
# Fold 3: 0.7113
# Fold 4: 0.7072
# Fold 5: 0.6960
# Fold 6: 0.7022
# Fold 7: 0.7084
# Fold 8: 0.7022
# Fold 9: 0.7184
# Fold 10: 0.6898
#
# Iteration 3:
# Fold 1: 0.7088
# Fold 2: 0.7175
# Fold 3: 0.7125
# Fold 4: 0.7233
# Fold 5: 0.7035
# Fold 6: 0.6935
# Fold 7: 0.6948
# Fold 8: 0.6774
# Fold 9: 0.6948
# Fold 10: 0.6948
#
# Iteration 4:
# Fold 1: 0.7026
# Fold 2: 0.6865
# Fold 3: 0.7113
# Fold 4: 0.6873
# Fold 5: 0.7159
# Fold 6: 0.6873
# Fold 7: 0.7035
# Fold 8: 0.7060
# Fold 9: 0.7060
# Fold 10: 0.7146
#
# Iteration 5:
# Fold 1: 0.6976
# Fold 2: 0.7001
# Fold 3: 0.6939
# Fold 4: 0.7060
# Fold 5: 0.6935
# Fold 6: 0.7270
# Fold 7: 0.7022
# Fold 8: 0.6948
# Fold 9: 0.7060
# Fold 10: 0.6998
#
# Iteration 6:
# Fold 1: 0.6840
# Fold 2: 0.6840
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_8 = np.mean(mnb_cv_scores)
mnb_std_scores_8 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_8)
print("Standard Deviations:", mnb_std_scores_8)
# Out:
# Mean Scores: 0.7020976658948839
# Standard Deviations: 0.014306603129348328

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7113
# Fold 2: 0.7063
# Fold 3: 0.6667
# Fold 4: 0.6911
# Fold 5: 0.6861
# Fold 6: 0.7097
# Fold 7: 0.7047
# Fold 8: 0.7060
# Fold 9: 0.7146
# Fold 10: 0.7246
#
# Iteration 2:
# Fold 1: 0.7224
# Fold 2: 0.6853
# Fold 3: 0.7125
# Fold 4: 0.6960
# Fold 5: 0.6973
# Fold 6: 0.7246
# Fold 7: 0.7072
# Fold 8: 0.6923
# Fold 9: 0.6849
# Fold 10: 0.6985
#
# Iteration 3:
# Fold 1: 0.6964
# Fold 2: 0.6853
# Fold 3: 0.7001
# Fold 4: 0.7084
# Fold 5: 0.7221
# Fold 6: 0.6749
# Fold 7: 0.7208
# Fold 8: 0.7419
# Fold 9: 0.6923
# Fold 10: 0.6787
#
# Iteration 4:
# Fold 1: 0.7162
# Fold 2: 0.6964
# Fold 3: 0.7014
# Fold 4: 0.6998
# Fold 5: 0.6886
# Fold 6: 0.6923
# Fold 7: 0.7221
# Fold 8: 0.7047
# Fold 9: 0.7060
# Fold 10: 0.6935
#
# Iteration 5:
# Fold 1: 0.7014
# Fold 2: 0.6704
# Fold 3: 0.7113
# Fold 4: 0.6799
# Fold 5: 0.7233
# Fold 6: 0.6948
# Fold 7: 0.7109
# Fold 8: 0.7134
# Fold 9: 0.6973
# Fold 10: 0.7184
#
# Iteration 6:
# Fold 1: 0.6939
# Fold 2: 0.7113
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_9 = np.mean(mnb_cv_scores)
mnb_std_scores_9 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_9)
print("Standard Deviations:", mnb_std_scores_9)
# Out:
# Mean Scores: 0.7020970663026066
# Standard Deviations: 0.01622984086145767

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7162
# Fold 2: 0.7237
# Fold 3: 0.6902
# Fold 4: 0.7047
# Fold 5: 0.6935
# Fold 6: 0.6935
# Fold 7: 0.6849
# Fold 8: 0.7022
# Fold 9: 0.6998
# Fold 10: 0.7122
#
# Iteration 2:
# Fold 1: 0.6716
# Fold 2: 0.7299
# Fold 3: 0.7100
# Fold 4: 0.7072
# Fold 5: 0.6836
# Fold 6: 0.7097
# Fold 7: 0.7122
# Fold 8: 0.6849
# Fold 9: 0.7047
# Fold 10: 0.7072
#
# Iteration 3:
# Fold 1: 0.6976
# Fold 2: 0.7026
# Fold 3: 0.7175
# Fold 4: 0.6960
# Fold 5: 0.6911
# Fold 6: 0.7357
# Fold 7: 0.6625
# Fold 8: 0.6960
# Fold 9: 0.7097
# Fold 10: 0.7122
#
# Iteration 4:
# Fold 1: 0.6853
# Fold 2: 0.6815
# Fold 3: 0.6964
# Fold 4: 0.7084
# Fold 5: 0.7072
# Fold 6: 0.7134
# Fold 7: 0.6973
# Fold 8: 0.7159
# Fold 9: 0.7109
# Fold 10: 0.7047
#
# Iteration 5:
# Fold 1: 0.6939
# Fold 2: 0.7175
# Fold 3: 0.7125
# Fold 4: 0.6849
# Fold 5: 0.7022
# Fold 6: 0.7196
# Fold 7: 0.7084
# Fold 8: 0.6613
# Fold 9: 0.6973
# Fold 10: 0.7233
#
# Iteration 6:
# Fold 1: 0.7063
# Fold 2: 0.7175
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_10 = np.mean(mnb_cv_scores)
mnb_std_scores_10 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_10)
print("Standard Deviations:", mnb_std_scores_10)
# Out:
# Mean Scores: 0.7020954366415453
# Standard Deviations: 0.013992891268741373

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6716
# Fold 2: 0.7125
# Fold 3: 0.7063
# Fold 4: 0.7159
# Fold 5: 0.7270
# Fold 6: 0.7022
# Fold 7: 0.6613
# Fold 8: 0.7097
# Fold 9: 0.7035
# Fold 10: 0.7109
#
# Iteration 2:
# Fold 1: 0.6791
# Fold 2: 0.7150
# Fold 3: 0.6902
# Fold 4: 0.7134
# Fold 5: 0.7208
# Fold 6: 0.6886
# Fold 7: 0.6985
# Fold 8: 0.6911
# Fold 9: 0.7122
# Fold 10: 0.7122
#
# Iteration 3:
# Fold 1: 0.6989
# Fold 2: 0.7373
# Fold 3: 0.7113
# Fold 4: 0.6700
# Fold 5: 0.7221
# Fold 6: 0.7159
# Fold 7: 0.6923
# Fold 8: 0.6811
# Fold 9: 0.6948
# Fold 10: 0.6973
#
# Iteration 4:
# Fold 1: 0.6853
# Fold 2: 0.7200
# Fold 3: 0.7088
# Fold 4: 0.6911
# Fold 5: 0.7097
# Fold 6: 0.6811
# Fold 7: 0.6985
# Fold 8: 0.7171
# Fold 9: 0.6973
# Fold 10: 0.7122
#
# Iteration 5:
# Fold 1: 0.6976
# Fold 2: 0.6939
# Fold 3: 0.6890
# Fold 4: 0.7357
# Fold 5: 0.7072
# Fold 6: 0.6923
# Fold 7: 0.6824
# Fold 8: 0.6898
# Fold 9: 0.7097
# Fold 10: 0.7233
#
# Iteration 6:
# Fold 1: 0.6976
# Fold 2: 0.7001
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_11 = np.mean(mnb_cv_scores)
mnb_std_scores_11 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_11)
print("Standard Deviations:", mnb_std_scores_11)
# Out:
# Mean Scores: 0.7020968664385143
# Standard Deviations: 0.015585269125875201

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7038
# Fold 2: 0.6778
# Fold 3: 0.7162
# Fold 4: 0.6799
# Fold 5: 0.7171
# Fold 6: 0.6762
# Fold 7: 0.7146
# Fold 8: 0.7159
# Fold 9: 0.7072
# Fold 10: 0.7122
#
# Iteration 2:
# Fold 1: 0.7051
# Fold 2: 0.7088
# Fold 3: 0.6927
# Fold 4: 0.6849
# Fold 5: 0.7097
# Fold 6: 0.6861
# Fold 7: 0.7184
# Fold 8: 0.6935
# Fold 9: 0.7097
# Fold 10: 0.7122
#
# Iteration 3:
# Fold 1: 0.7100
# Fold 2: 0.7051
# Fold 3: 0.7051
# Fold 4: 0.6762
# Fold 5: 0.7134
# Fold 6: 0.7221
# Fold 7: 0.6985
# Fold 8: 0.6935
# Fold 9: 0.7072
# Fold 10: 0.6898
#
# Iteration 4:
# Fold 1: 0.7162
# Fold 2: 0.6964
# Fold 3: 0.7200
# Fold 4: 0.6861
# Fold 5: 0.7134
# Fold 6: 0.7246
# Fold 7: 0.7134
# Fold 8: 0.6501
# Fold 9: 0.7084
# Fold 10: 0.6923
#
# Iteration 5:
# Fold 1: 0.6704
# Fold 2: 0.7063
# Fold 3: 0.6890
# Fold 4: 0.7072
# Fold 5: 0.7233
# Fold 6: 0.6973
# Fold 7: 0.6849
# Fold 8: 0.7097
# Fold 9: 0.7270
# Fold 10: 0.7060
#
# Iteration 6:
# Fold 1: 0.6952
# Fold 2: 0.6877
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_12 = np.mean(mnb_cv_scores)
mnb_std_scores_12 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_12)
print("Standard Deviations:", mnb_std_scores_12)
# Out:
# Mean Scores: 0.7020960516079835
# Standard Deviations: 0.016259900288598327

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6976
# Fold 2: 0.7063
# Fold 3: 0.7237
# Fold 4: 0.6973
# Fold 5: 0.7146
# Fold 6: 0.7122
# Fold 7: 0.6787
# Fold 8: 0.7010
# Fold 9: 0.6935
# Fold 10: 0.6960
#
# Iteration 2:
# Fold 1: 0.6877
# Fold 2: 0.6989
# Fold 3: 0.7224
# Fold 4: 0.6911
# Fold 5: 0.6973
# Fold 6: 0.7196
# Fold 7: 0.6749
# Fold 8: 0.7122
# Fold 9: 0.7109
# Fold 10: 0.7060
#
# Iteration 3:
# Fold 1: 0.7026
# Fold 2: 0.7088
# Fold 3: 0.7001
# Fold 4: 0.7146
# Fold 5: 0.6799
# Fold 6: 0.7060
# Fold 7: 0.7196
# Fold 8: 0.6911
# Fold 9: 0.6923
# Fold 10: 0.7060
#
# Iteration 4:
# Fold 1: 0.6803
# Fold 2: 0.7100
# Fold 3: 0.7088
# Fold 4: 0.6787
# Fold 5: 0.7035
# Fold 6: 0.7395
# Fold 7: 0.7109
# Fold 8: 0.6948
# Fold 9: 0.6824
# Fold 10: 0.7122
#
# Iteration 5:
# Fold 1: 0.6890
# Fold 2: 0.6778
# Fold 3: 0.7534
# Fold 4: 0.7432
# Fold 5: 0.6948
# Fold 6: 0.6712
# Fold 7: 0.6923
# Fold 8: 0.6973
# Fold 9: 0.6985
# Fold 10: 0.7035
#
# Iteration 6:
# Fold 1: 0.6741
# Fold 2: 0.7175
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_13 = np.mean(mnb_cv_scores)
mnb_std_scores_13 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_13)
print("Standard Deviations:", mnb_std_scores_13)
# Out:
# Mean Scores: 0.7020959439888569
# Standard Deviations: 0.01609494125693961

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7237
# Fold 2: 0.7299
# Fold 3: 0.7212
# Fold 4: 0.6836
# Fold 5: 0.6960
# Fold 6: 0.6799
# Fold 7: 0.6886
# Fold 8: 0.7270
# Fold 9: 0.7010
# Fold 10: 0.6700
#
# Iteration 2:
# Fold 1: 0.7311
# Fold 2: 0.6853
# Fold 3: 0.6989
# Fold 4: 0.6935
# Fold 5: 0.6923
# Fold 6: 0.7060
# Fold 7: 0.7159
# Fold 8: 0.7084
# Fold 9: 0.6960
# Fold 10: 0.6935
#
# Iteration 3:
# Fold 1: 0.6976
# Fold 2: 0.7113
# Fold 3: 0.7125
# Fold 4: 0.6935
# Fold 5: 0.7109
# Fold 6: 0.6873
# Fold 7: 0.7084
# Fold 8: 0.7035
# Fold 9: 0.6998
# Fold 10: 0.6960
#
# Iteration 4:
# Fold 1: 0.7026
# Fold 2: 0.6939
# Fold 3: 0.6914
# Fold 4: 0.6824
# Fold 5: 0.7109
# Fold 6: 0.6911
# Fold 7: 0.7072
# Fold 8: 0.7221
# Fold 9: 0.6985
# Fold 10: 0.7208
#
# Iteration 5:
# Fold 1: 0.7001
# Fold 2: 0.7200
# Fold 3: 0.7026
# Fold 4: 0.6824
# Fold 5: 0.6886
# Fold 6: 0.7060
# Fold 7: 0.7295
# Fold 8: 0.6712
# Fold 9: 0.7159
# Fold 10: 0.7047
#
# Iteration 6:
# Fold 1: 0.7063
# Fold 2: 0.6964
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_14 = np.mean(mnb_cv_scores)
mnb_std_scores_14 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_14)
print("Standard Deviations:", mnb_std_scores_14)
# Out:
# Mean Scores: 0.7020948370492678
# Standard Deviations: 0.01486192130921507

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7125
# Fold 2: 0.6952
# Fold 3: 0.7063
# Fold 4: 0.6799
# Fold 5: 0.6898
# Fold 6: 0.7320
# Fold 7: 0.7221
# Fold 8: 0.6935
# Fold 9: 0.6762
# Fold 10: 0.7134
#
# Iteration 2:
# Fold 1: 0.7051
# Fold 2: 0.7001
# Fold 3: 0.7014
# Fold 4: 0.6811
# Fold 5: 0.6873
# Fold 6: 0.7345
# Fold 7: 0.7146
# Fold 8: 0.6824
# Fold 9: 0.6948
# Fold 10: 0.7196
#
# Iteration 3:
# Fold 1: 0.7485
# Fold 2: 0.6914
# Fold 3: 0.7026
# Fold 4: 0.7171
# Fold 5: 0.7097
# Fold 6: 0.7022
# Fold 7: 0.6886
# Fold 8: 0.7084
# Fold 9: 0.6836
# Fold 10: 0.6687
#
# Iteration 4:
# Fold 1: 0.7100
# Fold 2: 0.6952
# Fold 3: 0.6865
# Fold 4: 0.7419
# Fold 5: 0.7010
# Fold 6: 0.7035
# Fold 7: 0.7035
# Fold 8: 0.6824
# Fold 9: 0.6960
# Fold 10: 0.7010
#
# Iteration 5:
# Fold 1: 0.7100
# Fold 2: 0.6890
# Fold 3: 0.7175
# Fold 4: 0.7159
# Fold 5: 0.6836
# Fold 6: 0.7122
# Fold 7: 0.7246
# Fold 8: 0.6799
# Fold 9: 0.6898
# Fold 10: 0.6985
#
# Iteration 6:
# Fold 1: 0.7113
# Fold 2: 0.7125
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_15 = np.mean(mnb_cv_scores)
mnb_std_scores_15 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_15)
print("Standard Deviations:", mnb_std_scores_15)
# Out:
# Mean Scores: 0.7020958824922127
# Standard Deviations: 0.01649625145620127

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7286
# Fold 2: 0.6976
# Fold 3: 0.6989
# Fold 4: 0.6836
# Fold 5: 0.6873
# Fold 6: 0.6787
# Fold 7: 0.7134
# Fold 8: 0.7047
# Fold 9: 0.7035
# Fold 10: 0.7246
#
# Iteration 2:
# Fold 1: 0.7014
# Fold 2: 0.7051
# Fold 3: 0.6791
# Fold 4: 0.6898
# Fold 5: 0.6898
# Fold 6: 0.7097
# Fold 7: 0.7258
# Fold 8: 0.7208
# Fold 9: 0.6824
# Fold 10: 0.7171
#
# Iteration 3:
# Fold 1: 0.6716
# Fold 2: 0.7026
# Fold 3: 0.7336
# Fold 4: 0.7047
# Fold 5: 0.7084
# Fold 6: 0.7035
# Fold 7: 0.6911
# Fold 8: 0.6861
# Fold 9: 0.7109
# Fold 10: 0.7084
#
# Iteration 4:
# Fold 1: 0.6902
# Fold 2: 0.7485
# Fold 3: 0.6939
# Fold 4: 0.6948
# Fold 5: 0.6799
# Fold 6: 0.7097
# Fold 7: 0.7109
# Fold 8: 0.7196
# Fold 9: 0.6811
# Fold 10: 0.6923
#
# Iteration 5:
# Fold 1: 0.6840
# Fold 2: 0.6815
# Fold 3: 0.7125
# Fold 4: 0.7022
# Fold 5: 0.6861
# Fold 6: 0.7221
# Fold 7: 0.7035
# Fold 8: 0.7022
# Fold 9: 0.7084
# Fold 10: 0.7184
#
# Iteration 6:
# Fold 1: 0.6890
# Fold 2: 0.7125
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_16 = np.mean(mnb_cv_scores)
mnb_std_scores_16 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_16)
print("Standard Deviations:", mnb_std_scores_16)
# Out:
# Mean Scores: 0.7020962822203978
# Standard Deviations: 0.014778102077639771

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7162
# Fold 2: 0.6989
# Fold 3: 0.7001
# Fold 4: 0.6923
# Fold 5: 0.7196
# Fold 6: 0.7084
# Fold 7: 0.6886
# Fold 8: 0.7060
# Fold 9: 0.7047
# Fold 10: 0.6861
#
# Iteration 2:
# Fold 1: 0.7051
# Fold 2: 0.6865
# Fold 3: 0.6976
# Fold 4: 0.7196
# Fold 5: 0.7022
# Fold 6: 0.7097
# Fold 7: 0.7060
# Fold 8: 0.7084
# Fold 9: 0.6948
# Fold 10: 0.6911
#
# Iteration 3:
# Fold 1: 0.6964
# Fold 2: 0.7026
# Fold 3: 0.7162
# Fold 4: 0.7097
# Fold 5: 0.6886
# Fold 6: 0.6774
# Fold 7: 0.6948
# Fold 8: 0.7122
# Fold 9: 0.6960
# Fold 10: 0.7270
#
# Iteration 4:
# Fold 1: 0.7187
# Fold 2: 0.6778
# Fold 3: 0.6828
# Fold 4: 0.7382
# Fold 5: 0.7159
# Fold 6: 0.6935
# Fold 7: 0.7283
# Fold 8: 0.6935
# Fold 9: 0.6973
# Fold 10: 0.6749
#
# Iteration 5:
# Fold 1: 0.7076
# Fold 2: 0.7361
# Fold 3: 0.6853
# Fold 4: 0.7134
# Fold 5: 0.7084
# Fold 6: 0.7184
# Fold 7: 0.7010
# Fold 8: 0.6923
# Fold 9: 0.6886
# Fold 10: 0.6700
#
# Iteration 6:
# Fold 1: 0.7187
# Fold 2: 0.7038
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_17 = np.mean(mnb_cv_scores)
mnb_std_scores_17 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_17)
print("Standard Deviations:", mnb_std_scores_17)
# Out:
# Mean Scores: 0.7020975582757571
# Standard Deviations: 0.01569635084395917

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7100
# Fold 2: 0.6989
# Fold 3: 0.7001
# Fold 4: 0.7258
# Fold 5: 0.6998
# Fold 6: 0.6911
# Fold 7: 0.7109
# Fold 8: 0.7060
# Fold 9: 0.6898
# Fold 10: 0.6886
#
# Iteration 2:
# Fold 1: 0.6914
# Fold 2: 0.7038
# Fold 3: 0.7187
# Fold 4: 0.6886
# Fold 5: 0.7146
# Fold 6: 0.6973
# Fold 7: 0.6898
# Fold 8: 0.6985
# Fold 9: 0.6948
# Fold 10: 0.7233
#
# Iteration 3:
# Fold 1: 0.7212
# Fold 2: 0.6989
# Fold 3: 0.7125
# Fold 4: 0.6886
# Fold 5: 0.7022
# Fold 6: 0.6923
# Fold 7: 0.7060
# Fold 8: 0.6948
# Fold 9: 0.6923
# Fold 10: 0.7122
#
# Iteration 4:
# Fold 1: 0.6902
# Fold 2: 0.7113
# Fold 3: 0.6964
# Fold 4: 0.7060
# Fold 5: 0.7246
# Fold 6: 0.7084
# Fold 7: 0.6998
# Fold 8: 0.6886
# Fold 9: 0.7035
# Fold 10: 0.6923
#
# Iteration 5:
# Fold 1: 0.7138
# Fold 2: 0.6939
# Fold 3: 0.7088
# Fold 4: 0.6911
# Fold 5: 0.7097
# Fold 6: 0.6985
# Fold 7: 0.7208
# Fold 8: 0.6935
# Fold 9: 0.6960
# Fold 10: 0.6948
#
# Iteration 6:
# Fold 1: 0.7175
# Fold 2: 0.6914
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_18 = np.mean(mnb_cv_scores)
mnb_std_scores_18 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_18)
print("Standard Deviations:", mnb_std_scores_18)
# Out:
# Mean Scores: 0.7020944680694052
# Standard Deviations: 0.013115381346372605

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6853
# Fold 2: 0.7014
# Fold 3: 0.6840
# Fold 4: 0.7171
# Fold 5: 0.6836
# Fold 6: 0.7060
# Fold 7: 0.7258
# Fold 8: 0.7134
# Fold 9: 0.6985
# Fold 10: 0.7060
#
# Iteration 2:
# Fold 1: 0.6890
# Fold 2: 0.6766
# Fold 3: 0.6914
# Fold 4: 0.7171
# Fold 5: 0.6898
# Fold 6: 0.6985
# Fold 7: 0.7171
# Fold 8: 0.7270
# Fold 9: 0.7134
# Fold 10: 0.7010
#
# Iteration 3:
# Fold 1: 0.6890
# Fold 2: 0.7175
# Fold 3: 0.6753
# Fold 4: 0.7010
# Fold 5: 0.6923
# Fold 6: 0.7258
# Fold 7: 0.6998
# Fold 8: 0.6998
# Fold 9: 0.7221
# Fold 10: 0.6985
#
# Iteration 4:
# Fold 1: 0.6952
# Fold 2: 0.6766
# Fold 3: 0.7175
# Fold 4: 0.7109
# Fold 5: 0.7370
# Fold 6: 0.6824
# Fold 7: 0.6985
# Fold 8: 0.7233
# Fold 9: 0.6787
# Fold 10: 0.7010
#
# Iteration 5:
# Fold 1: 0.6989
# Fold 2: 0.6914
# Fold 3: 0.7162
# Fold 4: 0.6923
# Fold 5: 0.7196
# Fold 6: 0.6886
# Fold 7: 0.6873
# Fold 8: 0.7171
# Fold 9: 0.7196
# Fold 10: 0.6898
#
# Iteration 6:
# Fold 1: 0.7113
# Fold 2: 0.6741
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_19 = np.mean(mnb_cv_scores)
mnb_std_scores_19 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_19)
print("Standard Deviations:", mnb_std_scores_19)
# Out:
# Mean Scores: 0.702097235418377
# Standard Deviations: 0.015751761934744653

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7200
# Fold 2: 0.7336
# Fold 3: 0.6902
# Fold 4: 0.6849
# Fold 5: 0.6886
# Fold 6: 0.6898
# Fold 7: 0.7122
# Fold 8: 0.6998
# Fold 9: 0.7084
# Fold 10: 0.6935
#
# Iteration 2:
# Fold 1: 0.7088
# Fold 2: 0.6976
# Fold 3: 0.6877
# Fold 4: 0.7060
# Fold 5: 0.6960
# Fold 6: 0.7122
# Fold 7: 0.6948
# Fold 8: 0.7357
# Fold 9: 0.7010
# Fold 10: 0.6811
#
# Iteration 3:
# Fold 1: 0.7274
# Fold 2: 0.6952
# Fold 3: 0.6989
# Fold 4: 0.6762
# Fold 5: 0.6886
# Fold 6: 0.7010
# Fold 7: 0.6998
# Fold 8: 0.6948
# Fold 9: 0.7072
# Fold 10: 0.7320
#
# Iteration 4:
# Fold 1: 0.7026
# Fold 2: 0.7088
# Fold 3: 0.6791
# Fold 4: 0.6935
# Fold 5: 0.6861
# Fold 6: 0.7097
# Fold 7: 0.6948
# Fold 8: 0.7184
# Fold 9: 0.7010
# Fold 10: 0.7270
#
# Iteration 5:
# Fold 1: 0.7100
# Fold 2: 0.6976
# Fold 3: 0.6927
# Fold 4: 0.6911
# Fold 5: 0.7146
# Fold 6: 0.7109
# Fold 7: 0.6749
# Fold 8: 0.6873
# Fold 9: 0.7444
# Fold 10: 0.6973
#
# Iteration 6:
# Fold 1: 0.7138
# Fold 2: 0.6853
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_20 = np.mean(mnb_cv_scores)
mnb_std_scores_20 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_20)
print("Standard Deviations:", mnb_std_scores_20)
# Out:
# Mean Scores: 0.7020957902472472
# Standard Deviations: 0.016007982767589

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7076
# Fold 2: 0.7187
# Fold 3: 0.7138
# Fold 4: 0.6774
# Fold 5: 0.7159
# Fold 6: 0.6998
# Fold 7: 0.6973
# Fold 8: 0.6886
# Fold 9: 0.6973
# Fold 10: 0.7047
#
# Iteration 2:
# Fold 1: 0.7076
# Fold 2: 0.6803
# Fold 3: 0.7038
# Fold 4: 0.7122
# Fold 5: 0.7072
# Fold 6: 0.7072
# Fold 7: 0.7035
# Fold 8: 0.6886
# Fold 9: 0.6948
# Fold 10: 0.7159
#
# Iteration 3:
# Fold 1: 0.6902
# Fold 2: 0.7100
# Fold 3: 0.7063
# Fold 4: 0.7134
# Fold 5: 0.6873
# Fold 6: 0.7022
# Fold 7: 0.6923
# Fold 8: 0.7097
# Fold 9: 0.7072
# Fold 10: 0.7022
#
# Iteration 4:
# Fold 1: 0.7311
# Fold 2: 0.6939
# Fold 3: 0.7026
# Fold 4: 0.7084
# Fold 5: 0.7159
# Fold 6: 0.6886
# Fold 7: 0.6911
# Fold 8: 0.6935
# Fold 9: 0.6836
# Fold 10: 0.7122
#
# Iteration 5:
# Fold 1: 0.6791
# Fold 2: 0.7237
# Fold 3: 0.7113
# Fold 4: 0.7035
# Fold 5: 0.6836
# Fold 6: 0.7246
# Fold 7: 0.6849
# Fold 8: 0.7084
# Fold 9: 0.6960
# Fold 10: 0.7060
#
# Iteration 6:
# Fold 1: 0.6964
# Fold 2: 0.7100
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_21 = np.mean(mnb_cv_scores)
mnb_std_scores_21 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_21)
print("Standard Deviations:", mnb_std_scores_21)
# Out:
# Mean Scores: 0.702095236777453
# Standard Deviations: 0.013080485806307095

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6877
# Fold 2: 0.6890
# Fold 3: 0.6778
# Fold 4: 0.7134
# Fold 5: 0.7333
# Fold 6: 0.7146
# Fold 7: 0.7109
# Fold 8: 0.7035
# Fold 9: 0.6935
# Fold 10: 0.6973
#
# Iteration 2:
# Fold 1: 0.7187
# Fold 2: 0.7224
# Fold 3: 0.6902
# Fold 4: 0.7134
# Fold 5: 0.6998
# Fold 6: 0.6898
# Fold 7: 0.7072
# Fold 8: 0.6998
# Fold 9: 0.7047
# Fold 10: 0.6749
#
# Iteration 3:
# Fold 1: 0.6914
# Fold 2: 0.6853
# Fold 3: 0.7200
# Fold 4: 0.6873
# Fold 5: 0.7022
# Fold 6: 0.7208
# Fold 7: 0.7109
# Fold 8: 0.6911
# Fold 9: 0.7022
# Fold 10: 0.7097
#
# Iteration 4:
# Fold 1: 0.6927
# Fold 2: 0.6952
# Fold 3: 0.6877
# Fold 4: 0.6712
# Fold 5: 0.7419
# Fold 6: 0.7246
# Fold 7: 0.7196
# Fold 8: 0.6973
# Fold 9: 0.7047
# Fold 10: 0.6861
#
# Iteration 5:
# Fold 1: 0.7162
# Fold 2: 0.6840
# Fold 3: 0.7212
# Fold 4: 0.6787
# Fold 5: 0.7221
# Fold 6: 0.6774
# Fold 7: 0.7035
# Fold 8: 0.7035
# Fold 9: 0.7233
# Fold 10: 0.6911
#
# Iteration 6:
# Fold 1: 0.7063
# Fold 2: 0.6964
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_22 = np.mean(mnb_cv_scores)
mnb_std_scores_22 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_22)
print("Standard Deviations:", mnb_std_scores_22)
# Out:
# Mean Scores: 0.7020968510643532
# Standard Deviations: 0.015581922574525753

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6791
# Fold 2: 0.6877
# Fold 3: 0.7224
# Fold 4: 0.6998
# Fold 5: 0.6911
# Fold 6: 0.7134
# Fold 7: 0.6861
# Fold 8: 0.7072
# Fold 9: 0.7370
# Fold 10: 0.6973
#
# Iteration 2:
# Fold 1: 0.7076
# Fold 2: 0.7113
# Fold 3: 0.7100
# Fold 4: 0.7047
# Fold 5: 0.7035
# Fold 6: 0.7084
# Fold 7: 0.7122
# Fold 8: 0.6973
# Fold 9: 0.6873
# Fold 10: 0.6787
#
# Iteration 3:
# Fold 1: 0.6902
# Fold 2: 0.7100
# Fold 3: 0.7001
# Fold 4: 0.6935
# Fold 5: 0.7159
# Fold 6: 0.7159
# Fold 7: 0.6998
# Fold 8: 0.6824
# Fold 9: 0.6873
# Fold 10: 0.7258
#
# Iteration 4:
# Fold 1: 0.7348
# Fold 2: 0.7063
# Fold 3: 0.6853
# Fold 4: 0.6886
# Fold 5: 0.6849
# Fold 6: 0.6849
# Fold 7: 0.7184
# Fold 8: 0.6923
# Fold 9: 0.7146
# Fold 10: 0.7109
#
# Iteration 5:
# Fold 1: 0.7076
# Fold 2: 0.7187
# Fold 3: 0.7001
# Fold 4: 0.7109
# Fold 5: 0.7072
# Fold 6: 0.6886
# Fold 7: 0.7196
# Fold 8: 0.6911
# Fold 9: 0.6898
# Fold 10: 0.6873
#
# Iteration 6:
# Fold 1: 0.6964
# Fold 2: 0.6853
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_23 = np.mean(mnb_cv_scores)
mnb_std_scores_23 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_23)
print("Standard Deviations:", mnb_std_scores_23)
# Out:
# Mean Scores: 0.7020960208596617
# Standard Deviations: 0.01463411706273321

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7212
# Fold 2: 0.6914
# Fold 3: 0.6952
# Fold 4: 0.7047
# Fold 5: 0.7233
# Fold 6: 0.7022
# Fold 7: 0.6973
# Fold 8: 0.7072
# Fold 9: 0.6836
# Fold 10: 0.6948
#
# Iteration 2:
# Fold 1: 0.6840
# Fold 2: 0.6766
# Fold 3: 0.6976
# Fold 4: 0.7122
# Fold 5: 0.7333
# Fold 6: 0.7084
# Fold 7: 0.6873
# Fold 8: 0.6948
# Fold 9: 0.7060
# Fold 10: 0.7208
#
# Iteration 3:
# Fold 1: 0.7175
# Fold 2: 0.7001
# Fold 3: 0.6964
# Fold 4: 0.7109
# Fold 5: 0.7109
# Fold 6: 0.6886
# Fold 7: 0.7122
# Fold 8: 0.7035
# Fold 9: 0.6836
# Fold 10: 0.6973
#
# Iteration 4:
# Fold 1: 0.6976
# Fold 2: 0.7249
# Fold 3: 0.6927
# Fold 4: 0.6687
# Fold 5: 0.6824
# Fold 6: 0.6948
# Fold 7: 0.7357
# Fold 8: 0.7159
# Fold 9: 0.7084
# Fold 10: 0.6998
#
# Iteration 5:
# Fold 1: 0.6716
# Fold 2: 0.6853
# Fold 3: 0.6989
# Fold 4: 0.7171
# Fold 5: 0.6973
# Fold 6: 0.7295
# Fold 7: 0.7047
# Fold 8: 0.7246
# Fold 9: 0.7035
# Fold 10: 0.6886
#
# Iteration 6:
# Fold 1: 0.7138
# Fold 2: 0.7100
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_24 = np.mean(mnb_cv_scores)
mnb_std_scores_24 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_24)
print("Standard Deviations:", mnb_std_scores_24)
# Out:
# Mean Scores: 0.7020966512002605
# Standard Deviations: 0.01475093839788625

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7274
# Fold 2: 0.6914
# Fold 3: 0.6815
# Fold 4: 0.7035
# Fold 5: 0.6873
# Fold 6: 0.7171
# Fold 7: 0.7047
# Fold 8: 0.6675
# Fold 9: 0.7270
# Fold 10: 0.7134
#
# Iteration 2:
# Fold 1: 0.6989
# Fold 2: 0.7187
# Fold 3: 0.6853
# Fold 4: 0.7035
# Fold 5: 0.7122
# Fold 6: 0.7010
# Fold 7: 0.7084
# Fold 8: 0.7035
# Fold 9: 0.6911
# Fold 10: 0.6985
#
# Iteration 3:
# Fold 1: 0.6902
# Fold 2: 0.7187
# Fold 3: 0.7274
# Fold 4: 0.7047
# Fold 5: 0.7171
# Fold 6: 0.6849
# Fold 7: 0.7047
# Fold 8: 0.6787
# Fold 9: 0.7060
# Fold 10: 0.6886
#
# Iteration 4:
# Fold 1: 0.7063
# Fold 2: 0.7076
# Fold 3: 0.6927
# Fold 4: 0.7010
# Fold 5: 0.7097
# Fold 6: 0.7184
# Fold 7: 0.6898
# Fold 8: 0.6886
# Fold 9: 0.7047
# Fold 10: 0.7022
#
# Iteration 5:
# Fold 1: 0.6865
# Fold 2: 0.7001
# Fold 3: 0.6729
# Fold 4: 0.7270
# Fold 5: 0.7022
# Fold 6: 0.6973
# Fold 7: 0.6650
# Fold 8: 0.7357
# Fold 9: 0.7171
# Fold 10: 0.7171
#
# Iteration 6:
# Fold 1: 0.7162
# Fold 2: 0.7026
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_25 = np.mean(mnb_cv_scores)
mnb_std_scores_25 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_25)
print("Standard Deviations:", mnb_std_scores_25)
# Out:
# Mean Scores: 0.7020966204519388
# Standard Deviations: 0.015833865543149733

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6877
# Fold 2: 0.7187
# Fold 3: 0.7224
# Fold 4: 0.7047
# Fold 5: 0.7022
# Fold 6: 0.6725
# Fold 7: 0.6960
# Fold 8: 0.7122
# Fold 9: 0.6886
# Fold 10: 0.7159
#
# Iteration 2:
# Fold 1: 0.6964
# Fold 2: 0.7063
# Fold 3: 0.7051
# Fold 4: 0.7097
# Fold 5: 0.6960
# Fold 6: 0.7035
# Fold 7: 0.6712
# Fold 8: 0.6886
# Fold 9: 0.7382
# Fold 10: 0.7060
#
# Iteration 3:
# Fold 1: 0.7125
# Fold 2: 0.7150
# Fold 3: 0.7063
# Fold 4: 0.6861
# Fold 5: 0.6948
# Fold 6: 0.6985
# Fold 7: 0.7122
# Fold 8: 0.6998
# Fold 9: 0.6923
# Fold 10: 0.7035
#
# Iteration 4:
# Fold 1: 0.7063
# Fold 2: 0.6964
# Fold 3: 0.6853
# Fold 4: 0.6998
# Fold 5: 0.6886
# Fold 6: 0.7122
# Fold 7: 0.7109
# Fold 8: 0.7035
# Fold 9: 0.7072
# Fold 10: 0.7109
#
# Iteration 5:
# Fold 1: 0.7385
# Fold 2: 0.7200
# Fold 3: 0.6927
# Fold 4: 0.7146
# Fold 5: 0.7022
# Fold 6: 0.6960
# Fold 7: 0.6911
# Fold 8: 0.7084
# Fold 9: 0.6873
# Fold 10: 0.6700
#
# Iteration 6:
# Fold 1: 0.6952
# Fold 2: 0.7113
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_26 = np.mean(mnb_cv_scores)
mnb_std_scores_26 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_26)
print("Standard Deviations:", mnb_std_scores_26)
# Out:
# Mean Scores: 0.7020947140559802
# Standard Deviations: 0.016159411842943203

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7348
# Fold 2: 0.6989
# Fold 3: 0.7063
# Fold 4: 0.6836
# Fold 5: 0.7047
# Fold 6: 0.6898
# Fold 7: 0.7196
# Fold 8: 0.6873
# Fold 9: 0.6861
# Fold 10: 0.7097
#
# Iteration 2:
# Fold 1: 0.7162
# Fold 2: 0.7261
# Fold 3: 0.6914
# Fold 4: 0.6935
# Fold 5: 0.6898
# Fold 6: 0.6923
# Fold 7: 0.7134
# Fold 8: 0.7010
# Fold 9: 0.7072
# Fold 10: 0.6898
#
# Iteration 3:
# Fold 1: 0.6753
# Fold 2: 0.7001
# Fold 3: 0.6989
# Fold 4: 0.7184
# Fold 5: 0.7122
# Fold 6: 0.7035
# Fold 7: 0.6898
# Fold 8: 0.7109
# Fold 9: 0.7221
# Fold 10: 0.6898
#
# Iteration 4:
# Fold 1: 0.6914
# Fold 2: 0.7063
# Fold 3: 0.6952
# Fold 4: 0.6923
# Fold 5: 0.7246
# Fold 6: 0.6861
# Fold 7: 0.7246
# Fold 8: 0.6985
# Fold 9: 0.7196
# Fold 10: 0.6824
#
# Iteration 5:
# Fold 1: 0.6853
# Fold 2: 0.7150
# Fold 3: 0.7051
# Fold 4: 0.6911
# Fold 5: 0.6998
# Fold 6: 0.7072
# Fold 7: 0.7469
# Fold 8: 0.7196
# Fold 9: 0.6774
# Fold 10: 0.6737
#
# Iteration 6:
# Fold 1: 0.7051
# Fold 2: 0.7038
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_27 = np.mean(mnb_cv_scores)
mnb_std_scores_27 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_27)
print("Standard Deviations:", mnb_std_scores_27)
# Out:
# Mean Scores: 0.7020958209955691
# Standard Deviations: 0.016186264538288645

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7336
# Fold 2: 0.7014
# Fold 3: 0.6828
# Fold 4: 0.6935
# Fold 5: 0.7047
# Fold 6: 0.7159
# Fold 7: 0.7184
# Fold 8: 0.6811
# Fold 9: 0.7196
# Fold 10: 0.6700
#
# Iteration 2:
# Fold 1: 0.7138
# Fold 2: 0.7224
# Fold 3: 0.6952
# Fold 4: 0.6886
# Fold 5: 0.6911
# Fold 6: 0.7084
# Fold 7: 0.7283
# Fold 8: 0.6985
# Fold 9: 0.6749
# Fold 10: 0.6998
#
# Iteration 3:
# Fold 1: 0.6927
# Fold 2: 0.6815
# Fold 3: 0.7026
# Fold 4: 0.6948
# Fold 5: 0.6799
# Fold 6: 0.7084
# Fold 7: 0.6985
# Fold 8: 0.7345
# Fold 9: 0.7221
# Fold 10: 0.7060
#
# Iteration 4:
# Fold 1: 0.6704
# Fold 2: 0.6902
# Fold 3: 0.7224
# Fold 4: 0.6762
# Fold 5: 0.6985
# Fold 6: 0.7171
# Fold 7: 0.7233
# Fold 8: 0.7184
# Fold 9: 0.7022
# Fold 10: 0.7022
#
# Iteration 5:
# Fold 1: 0.7274
# Fold 2: 0.6815
# Fold 3: 0.6964
# Fold 4: 0.6898
# Fold 5: 0.7184
# Fold 6: 0.7146
# Fold 7: 0.6824
# Fold 8: 0.7320
# Fold 9: 0.7146
# Fold 10: 0.6638
#
# Iteration 6:
# Fold 1: 0.6952
# Fold 2: 0.7261
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_28 = np.mean(mnb_cv_scores)
mnb_std_scores_28 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_28)
print("Standard Deviations:", mnb_std_scores_28)
# Out:
# Mean Scores: 0.7020961592271102
# Standard Deviations: 0.017229501676238584

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6964
# Fold 2: 0.6952
# Fold 3: 0.6989
# Fold 4: 0.7072
# Fold 5: 0.7159
# Fold 6: 0.6849
# Fold 7: 0.6985
# Fold 8: 0.7109
# Fold 9: 0.6973
# Fold 10: 0.7159
#
# Iteration 2:
# Fold 1: 0.6976
# Fold 2: 0.6890
# Fold 3: 0.6840
# Fold 4: 0.7047
# Fold 5: 0.7084
# Fold 6: 0.7159
# Fold 7: 0.7159
# Fold 8: 0.6799
# Fold 9: 0.7122
# Fold 10: 0.7134
#
# Iteration 3:
# Fold 1: 0.6976
# Fold 2: 0.7175
# Fold 3: 0.6914
# Fold 4: 0.7022
# Fold 5: 0.6998
# Fold 6: 0.7035
# Fold 7: 0.6886
# Fold 8: 0.7097
# Fold 9: 0.6774
# Fold 10: 0.7333
#
# Iteration 4:
# Fold 1: 0.7051
# Fold 2: 0.6914
# Fold 3: 0.7051
# Fold 4: 0.6923
# Fold 5: 0.7084
# Fold 6: 0.6774
# Fold 7: 0.7097
# Fold 8: 0.6960
# Fold 9: 0.7072
# Fold 10: 0.7283
#
# Iteration 5:
# Fold 1: 0.7249
# Fold 2: 0.6976
# Fold 3: 0.6939
# Fold 4: 0.7221
# Fold 5: 0.7122
# Fold 6: 0.7035
# Fold 7: 0.6700
# Fold 8: 0.7159
# Fold 9: 0.6948
# Fold 10: 0.6861
#
# Iteration 6:
# Fold 1: 0.6877
# Fold 2: 0.7063
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_29 = np.mean(mnb_cv_scores)
mnb_std_scores_29 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_29)
print("Standard Deviations:", mnb_std_scores_29)
# Out:
# Mean Scores: 0.7020970970509285
# Standard Deviations: 0.013058161145844483

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7125
# Fold 2: 0.7038
# Fold 3: 0.6952
# Fold 4: 0.7035
# Fold 5: 0.6960
# Fold 6: 0.7109
# Fold 7: 0.7035
# Fold 8: 0.6886
# Fold 9: 0.6985
# Fold 10: 0.7084
#
# Iteration 2:
# Fold 1: 0.7323
# Fold 2: 0.7051
# Fold 3: 0.6704
# Fold 4: 0.6787
# Fold 5: 0.7022
# Fold 6: 0.7208
# Fold 7: 0.6836
# Fold 8: 0.7047
# Fold 9: 0.7159
# Fold 10: 0.7072
#
# Iteration 3:
# Fold 1: 0.6654
# Fold 2: 0.6964
# Fold 3: 0.7323
# Fold 4: 0.6998
# Fold 5: 0.6960
# Fold 6: 0.7270
# Fold 7: 0.7122
# Fold 8: 0.6998
# Fold 9: 0.6985
# Fold 10: 0.6935
#
# Iteration 4:
# Fold 1: 0.7150
# Fold 2: 0.7323
# Fold 3: 0.6877
# Fold 4: 0.6948
# Fold 5: 0.7246
# Fold 6: 0.6799
# Fold 7: 0.7035
# Fold 8: 0.7060
# Fold 9: 0.6911
# Fold 10: 0.6861
#
# Iteration 5:
# Fold 1: 0.6914
# Fold 2: 0.7410
# Fold 3: 0.7150
# Fold 4: 0.6861
# Fold 5: 0.6836
# Fold 6: 0.6998
# Fold 7: 0.6836
# Fold 8: 0.6998
# Fold 9: 0.7010
# Fold 10: 0.7196
#
# Iteration 6:
# Fold 1: 0.7038
# Fold 2: 0.6927
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_30 = np.mean(mnb_cv_scores)
mnb_std_scores_30 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_30)
print("Standard Deviations:", mnb_std_scores_30)
# Out:
# Mean Scores: 0.7020963590912025
# Standard Deviations: 0.01763016656436762

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6877
# Fold 2: 0.7088
# Fold 3: 0.7212
# Fold 4: 0.6886
# Fold 5: 0.6712
# Fold 6: 0.7171
# Fold 7: 0.7060
# Fold 8: 0.6948
# Fold 9: 0.7134
# Fold 10: 0.7122
#
# Iteration 2:
# Fold 1: 0.6803
# Fold 2: 0.7385
# Fold 3: 0.6853
# Fold 4: 0.6960
# Fold 5: 0.6923
# Fold 6: 0.7122
# Fold 7: 0.6985
# Fold 8: 0.7295
# Fold 9: 0.6787
# Fold 10: 0.7097
#
# Iteration 3:
# Fold 1: 0.6964
# Fold 2: 0.7125
# Fold 3: 0.7150
# Fold 4: 0.7010
# Fold 5: 0.7233
# Fold 6: 0.6960
# Fold 7: 0.6849
# Fold 8: 0.6960
# Fold 9: 0.7109
# Fold 10: 0.6849
#
# Iteration 4:
# Fold 1: 0.6976
# Fold 2: 0.6865
# Fold 3: 0.7076
# Fold 4: 0.6923
# Fold 5: 0.7184
# Fold 6: 0.7221
# Fold 7: 0.7060
# Fold 8: 0.6886
# Fold 9: 0.7072
# Fold 10: 0.6948
#
# Iteration 5:
# Fold 1: 0.7175
# Fold 2: 0.7100
# Fold 3: 0.7200
# Fold 4: 0.7072
# Fold 5: 0.6861
# Fold 6: 0.7109
# Fold 7: 0.6799
# Fold 8: 0.7047
# Fold 9: 0.6960
# Fold 10: 0.6886
#
# Iteration 6:
# Fold 1: 0.7038
# Fold 2: 0.6877
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_31 = np.mean(mnb_cv_scores)
mnb_std_scores_31 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_31)
print("Standard Deviations:", mnb_std_scores_31)
# Out:
# Mean Scores: 0.7020954981381891
# Standard Deviations: 0.014702526493102304

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6828
# Fold 2: 0.7026
# Fold 3: 0.7212
# Fold 4: 0.7134
# Fold 5: 0.7060
# Fold 6: 0.7221
# Fold 7: 0.6799
# Fold 8: 0.6849
# Fold 9: 0.7333
# Fold 10: 0.6749
#
# Iteration 2:
# Fold 1: 0.6989
# Fold 2: 0.6976
# Fold 3: 0.7038
# Fold 4: 0.7022
# Fold 5: 0.7084
# Fold 6: 0.7022
# Fold 7: 0.6787
# Fold 8: 0.7146
# Fold 9: 0.7134
# Fold 10: 0.7010
#
# Iteration 3:
# Fold 1: 0.7125
# Fold 2: 0.6828
# Fold 3: 0.7014
# Fold 4: 0.7258
# Fold 5: 0.7097
# Fold 6: 0.7060
# Fold 7: 0.7122
# Fold 8: 0.6811
# Fold 9: 0.7022
# Fold 10: 0.6873
#
# Iteration 4:
# Fold 1: 0.7286
# Fold 2: 0.6902
# Fold 3: 0.6976
# Fold 4: 0.6873
# Fold 5: 0.6923
# Fold 6: 0.7010
# Fold 7: 0.7035
# Fold 8: 0.6923
# Fold 9: 0.7184
# Fold 10: 0.7097
#
# Iteration 5:
# Fold 1: 0.7038
# Fold 2: 0.7088
# Fold 3: 0.6914
# Fold 4: 0.6998
# Fold 5: 0.7047
# Fold 6: 0.7258
# Fold 7: 0.6973
# Fold 8: 0.6948
# Fold 9: 0.6749
# Fold 10: 0.7196
#
# Iteration 6:
# Fold 1: 0.7038
# Fold 2: 0.7051
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_32 = np.mean(mnb_cv_scores)
mnb_std_scores_32 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_32)
print("Standard Deviations:", mnb_std_scores_32)
# Out:
# Mean Scores: 0.702096558955295
# Standard Deviations: 0.015767275283493812

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7026
# Fold 2: 0.7224
# Fold 3: 0.7076
# Fold 4: 0.6749
# Fold 5: 0.7258
# Fold 6: 0.7072
# Fold 7: 0.7370
# Fold 8: 0.6799
# Fold 9: 0.6935
# Fold 10: 0.6700
#
# Iteration 2:
# Fold 1: 0.7162
# Fold 2: 0.6753
# Fold 3: 0.7088
# Fold 4: 0.7072
# Fold 5: 0.6948
# Fold 6: 0.7097
# Fold 7: 0.6824
# Fold 8: 0.7270
# Fold 9: 0.6898
# Fold 10: 0.7097
#
# Iteration 3:
# Fold 1: 0.7212
# Fold 2: 0.7138
# Fold 3: 0.6902
# Fold 4: 0.6935
# Fold 5: 0.6836
# Fold 6: 0.6811
# Fold 7: 0.7283
# Fold 8: 0.7196
# Fold 9: 0.6787
# Fold 10: 0.7109
#
# Iteration 4:
# Fold 1: 0.7224
# Fold 2: 0.6592
# Fold 3: 0.7423
# Fold 4: 0.7072
# Fold 5: 0.6948
# Fold 6: 0.7084
# Fold 7: 0.6514
# Fold 8: 0.7010
# Fold 9: 0.7221
# Fold 10: 0.7122
#
# Iteration 5:
# Fold 1: 0.6865
# Fold 2: 0.7026
# Fold 3: 0.7125
# Fold 4: 0.7258
# Fold 5: 0.7333
# Fold 6: 0.6873
# Fold 7: 0.6898
# Fold 8: 0.6935
# Fold 9: 0.6861
# Fold 10: 0.7035
#
# Iteration 6:
# Fold 1: 0.6828
# Fold 2: 0.7162
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_33 = np.mean(mnb_cv_scores)
mnb_std_scores_33 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_33)
print("Standard Deviations:", mnb_std_scores_33)
# Out:
# Mean Scores: 0.7020956057573156
# Standard Deviations: 0.01782393037738273

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7150
# Fold 2: 0.7200
# Fold 3: 0.6976
# Fold 4: 0.6811
# Fold 5: 0.7072
# Fold 6: 0.7159
# Fold 7: 0.6799
# Fold 8: 0.6973
# Fold 9: 0.7035
# Fold 10: 0.7035
#
# Iteration 2:
# Fold 1: 0.7026
# Fold 2: 0.6927
# Fold 3: 0.6914
# Fold 4: 0.7357
# Fold 5: 0.7010
# Fold 6: 0.7084
# Fold 7: 0.7084
# Fold 8: 0.6774
# Fold 9: 0.7134
# Fold 10: 0.6898
#
# Iteration 3:
# Fold 1: 0.7038
# Fold 2: 0.6939
# Fold 3: 0.7026
# Fold 4: 0.7022
# Fold 5: 0.7109
# Fold 6: 0.6948
# Fold 7: 0.7308
# Fold 8: 0.6824
# Fold 9: 0.6973
# Fold 10: 0.7022
#
# Iteration 4:
# Fold 1: 0.7113
# Fold 2: 0.6939
# Fold 3: 0.6791
# Fold 4: 0.7345
# Fold 5: 0.6663
# Fold 6: 0.7010
# Fold 7: 0.6973
# Fold 8: 0.7022
# Fold 9: 0.7159
# Fold 10: 0.7196
#
# Iteration 5:
# Fold 1: 0.7249
# Fold 2: 0.7014
# Fold 3: 0.6865
# Fold 4: 0.7035
# Fold 5: 0.7072
# Fold 6: 0.7122
# Fold 7: 0.6960
# Fold 8: 0.7208
# Fold 9: 0.6911
# Fold 10: 0.6774
#
# Iteration 6:
# Fold 1: 0.7001
# Fold 2: 0.6989
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_34 = np.mean(mnb_cv_scores)
mnb_std_scores_34 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_34)
print("Standard Deviations:", mnb_std_scores_34)
# Out:
# Mean Scores: 0.7020960362338226
# Standard Deviations: 0.01589944330735111

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7299
# Fold 2: 0.6890
# Fold 3: 0.6890
# Fold 4: 0.7097
# Fold 5: 0.7171
# Fold 6: 0.6811
# Fold 7: 0.6998
# Fold 8: 0.7010
# Fold 9: 0.7022
# Fold 10: 0.7022
#
# Iteration 2:
# Fold 1: 0.6927
# Fold 2: 0.6691
# Fold 3: 0.7063
# Fold 4: 0.6973
# Fold 5: 0.7295
# Fold 6: 0.6811
# Fold 7: 0.6873
# Fold 8: 0.7382
# Fold 9: 0.7122
# Fold 10: 0.7072
#
# Iteration 3:
# Fold 1: 0.7100
# Fold 2: 0.7336
# Fold 3: 0.7076
# Fold 4: 0.7072
# Fold 5: 0.6985
# Fold 6: 0.6675
# Fold 7: 0.7345
# Fold 8: 0.6935
# Fold 9: 0.6625
# Fold 10: 0.7060
#
# Iteration 4:
# Fold 1: 0.6976
# Fold 2: 0.7138
# Fold 3: 0.6952
# Fold 4: 0.7270
# Fold 5: 0.6923
# Fold 6: 0.6960
# Fold 7: 0.7097
# Fold 8: 0.6787
# Fold 9: 0.7084
# Fold 10: 0.7022
#
# Iteration 5:
# Fold 1: 0.6877
# Fold 2: 0.6716
# Fold 3: 0.6716
# Fold 4: 0.6998
# Fold 5: 0.7047
# Fold 6: 0.7196
# Fold 7: 0.7159
# Fold 8: 0.7134
# Fold 9: 0.7246
# Fold 10: 0.7122
#
# Iteration 6:
# Fold 1: 0.6828
# Fold 2: 0.7038
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_35 = np.mean(mnb_cv_scores)
mnb_std_scores_35 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_35)
print("Standard Deviations:", mnb_std_scores_35)
# Out:
# Mean Scores: 0.702098311609644
# Standard Deviations: 0.01674981807731691

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7026
# Fold 2: 0.6927
# Fold 3: 0.6877
# Fold 4: 0.6948
# Fold 5: 0.7146
# Fold 6: 0.7134
# Fold 7: 0.6998
# Fold 8: 0.7047
# Fold 9: 0.7432
# Fold 10: 0.6675
#
# Iteration 2:
# Fold 1: 0.7237
# Fold 2: 0.7373
# Fold 3: 0.6704
# Fold 4: 0.7258
# Fold 5: 0.7196
# Fold 6: 0.6923
# Fold 7: 0.7084
# Fold 8: 0.6687
# Fold 9: 0.6824
# Fold 10: 0.6923
#
# Iteration 3:
# Fold 1: 0.7038
# Fold 2: 0.7187
# Fold 3: 0.6877
# Fold 4: 0.6935
# Fold 5: 0.7084
# Fold 6: 0.7146
# Fold 7: 0.6898
# Fold 8: 0.7109
# Fold 9: 0.6873
# Fold 10: 0.7060
#
# Iteration 4:
# Fold 1: 0.6803
# Fold 2: 0.7150
# Fold 3: 0.7200
# Fold 4: 0.6973
# Fold 5: 0.6960
# Fold 6: 0.7134
# Fold 7: 0.7432
# Fold 8: 0.6886
# Fold 9: 0.6849
# Fold 10: 0.6824
#
# Iteration 5:
# Fold 1: 0.7286
# Fold 2: 0.7088
# Fold 3: 0.6778
# Fold 4: 0.7010
# Fold 5: 0.6935
# Fold 6: 0.6712
# Fold 7: 0.7320
# Fold 8: 0.7109
# Fold 9: 0.6898
# Fold 10: 0.7072
#
# Iteration 6:
# Fold 1: 0.7162
# Fold 2: 0.7014
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_36 = np.mean(mnb_cv_scores)
mnb_std_scores_36 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_36)
print("Standard Deviations:", mnb_std_scores_36)
# Out:
# Mean Scores: 0.7020958209955691
# Standard Deviations: 0.017555708156231246

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6914
# Fold 2: 0.6964
# Fold 3: 0.7286
# Fold 4: 0.6960
# Fold 5: 0.7171
# Fold 6: 0.6873
# Fold 7: 0.7122
# Fold 8: 0.7035
# Fold 9: 0.6973
# Fold 10: 0.6911
#
# Iteration 2:
# Fold 1: 0.6976
# Fold 2: 0.6927
# Fold 3: 0.6853
# Fold 4: 0.6985
# Fold 5: 0.7022
# Fold 6: 0.6811
# Fold 7: 0.7258
# Fold 8: 0.7196
# Fold 9: 0.7221
# Fold 10: 0.6960
#
# Iteration 3:
# Fold 1: 0.7076
# Fold 2: 0.7100
# Fold 3: 0.6890
# Fold 4: 0.6923
# Fold 5: 0.7283
# Fold 6: 0.6948
# Fold 7: 0.6998
# Fold 8: 0.7258
# Fold 9: 0.6948
# Fold 10: 0.6787
#
# Iteration 4:
# Fold 1: 0.6914
# Fold 2: 0.6840
# Fold 3: 0.6952
# Fold 4: 0.6960
# Fold 5: 0.7022
# Fold 6: 0.7010
# Fold 7: 0.7407
# Fold 8: 0.7122
# Fold 9: 0.6948
# Fold 10: 0.7035
#
# Iteration 5:
# Fold 1: 0.7026
# Fold 2: 0.6964
# Fold 3: 0.7051
# Fold 4: 0.7258
# Fold 5: 0.7246
# Fold 6: 0.7060
# Fold 7: 0.7022
# Fold 8: 0.7010
# Fold 9: 0.7010
# Fold 10: 0.6563
#
# Iteration 6:
# Fold 1: 0.6939
# Fold 2: 0.6865
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_37 = np.mean(mnb_cv_scores)
mnb_std_scores_37 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_37)
print("Standard Deviations:", mnb_std_scores_37)
# Out:
# Mean Scores: 0.7020970970509282
# Standard Deviations: 0.016393484616977507

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6914
# Fold 2: 0.7175
# Fold 3: 0.7175
# Fold 4: 0.7134
# Fold 5: 0.6935
# Fold 6: 0.7109
# Fold 7: 0.7109
# Fold 8: 0.6799
# Fold 9: 0.7184
# Fold 10: 0.6675
#
# Iteration 2:
# Fold 1: 0.7113
# Fold 2: 0.7385
# Fold 3: 0.6865
# Fold 4: 0.6923
# Fold 5: 0.6873
# Fold 6: 0.7072
# Fold 7: 0.6749
# Fold 8: 0.7097
# Fold 9: 0.6960
# Fold 10: 0.7171
#
# Iteration 3:
# Fold 1: 0.7026
# Fold 2: 0.7014
# Fold 3: 0.7014
# Fold 4: 0.6973
# Fold 5: 0.7196
# Fold 6: 0.6861
# Fold 7: 0.7109
# Fold 8: 0.7283
# Fold 9: 0.6873
# Fold 10: 0.6861
#
# Iteration 4:
# Fold 1: 0.7212
# Fold 2: 0.6989
# Fold 3: 0.7051
# Fold 4: 0.6923
# Fold 5: 0.6799
# Fold 6: 0.6998
# Fold 7: 0.7022
# Fold 8: 0.7171
# Fold 9: 0.7134
# Fold 10: 0.6911
#
# Iteration 5:
# Fold 1: 0.6976
# Fold 2: 0.7100
# Fold 3: 0.7026
# Fold 4: 0.7047
# Fold 5: 0.6700
# Fold 6: 0.7035
# Fold 7: 0.7109
# Fold 8: 0.6861
# Fold 9: 0.7109
# Fold 10: 0.7246
#
# Iteration 6:
# Fold 1: 0.7237
# Fold 2: 0.6840
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_38 = np.mean(mnb_cv_scores)
mnb_std_scores_38 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_38)
print("Standard Deviations:", mnb_std_scores_38)
# Out:
# Mean Scores: 0.7020948985459118
# Standard Deviations: 0.01509624120770662

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7051
# Fold 2: 0.6778
# Fold 3: 0.7286
# Fold 4: 0.6787
# Fold 5: 0.7072
# Fold 6: 0.7122
# Fold 7: 0.7109
# Fold 8: 0.7146
# Fold 9: 0.6935
# Fold 10: 0.6923
#
# Iteration 2:
# Fold 1: 0.7063
# Fold 2: 0.6753
# Fold 3: 0.7088
# Fold 4: 0.7382
# Fold 5: 0.7122
# Fold 6: 0.7159
# Fold 7: 0.6712
# Fold 8: 0.7035
# Fold 9: 0.7084
# Fold 10: 0.6811
#
# Iteration 3:
# Fold 1: 0.7125
# Fold 2: 0.6964
# Fold 3: 0.7038
# Fold 4: 0.7184
# Fold 5: 0.6762
# Fold 6: 0.7159
# Fold 7: 0.6911
# Fold 8: 0.6638
# Fold 9: 0.7171
# Fold 10: 0.7258
#
# Iteration 4:
# Fold 1: 0.6902
# Fold 2: 0.7088
# Fold 3: 0.7125
# Fold 4: 0.7159
# Fold 5: 0.7134
# Fold 6: 0.7122
# Fold 7: 0.7022
# Fold 8: 0.7035
# Fold 9: 0.6712
# Fold 10: 0.6911
#
# Iteration 5:
# Fold 1: 0.6741
# Fold 2: 0.7051
# Fold 3: 0.7113
# Fold 4: 0.6600
# Fold 5: 0.7270
# Fold 6: 0.6998
# Fold 7: 0.7270
# Fold 8: 0.7196
# Fold 9: 0.6886
# Fold 10: 0.7084
#
# Iteration 6:
# Fold 1: 0.7187
# Fold 2: 0.7076
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_39 = np.mean(mnb_cv_scores)
mnb_std_scores_39 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_39)
print("Standard Deviations:", mnb_std_scores_39)
# Out:
# Mean Scores: 0.7020966819485828
# Standard Deviations: 0.01673739701818803

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6642
# Fold 2: 0.7398
# Fold 3: 0.6927
# Fold 4: 0.7097
# Fold 5: 0.6836
# Fold 6: 0.7060
# Fold 7: 0.7258
# Fold 8: 0.6960
# Fold 9: 0.7159
# Fold 10: 0.6873
#
# Iteration 2:
# Fold 1: 0.7150
# Fold 2: 0.7051
# Fold 3: 0.6840
# Fold 4: 0.6811
# Fold 5: 0.7146
# Fold 6: 0.7084
# Fold 7: 0.7060
# Fold 8: 0.6799
# Fold 9: 0.7184
# Fold 10: 0.7084
#
# Iteration 3:
# Fold 1: 0.6741
# Fold 2: 0.7286
# Fold 3: 0.6964
# Fold 4: 0.6836
# Fold 5: 0.7134
# Fold 6: 0.6985
# Fold 7: 0.7196
# Fold 8: 0.6948
# Fold 9: 0.7060
# Fold 10: 0.7060
#
# Iteration 4:
# Fold 1: 0.6902
# Fold 2: 0.7051
# Fold 3: 0.7100
# Fold 4: 0.7283
# Fold 5: 0.7010
# Fold 6: 0.6923
# Fold 7: 0.6985
# Fold 8: 0.7035
# Fold 9: 0.6873
# Fold 10: 0.7047
#
# Iteration 5:
# Fold 1: 0.7311
# Fold 2: 0.7138
# Fold 3: 0.6890
# Fold 4: 0.6923
# Fold 5: 0.7047
# Fold 6: 0.7171
# Fold 7: 0.6762
# Fold 8: 0.7196
# Fold 9: 0.6725
# Fold 10: 0.7047
#
# Iteration 6:
# Fold 1: 0.6890
# Fold 2: 0.7088
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_40 = np.mean(mnb_cv_scores)
mnb_std_scores_40 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_40)
print("Standard Deviations:", mnb_std_scores_40)
# Out:
# Mean Scores: 0.7020956518797987
# Standard Deviations: 0.015943236842937733

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7026
# Fold 2: 0.7286
# Fold 3: 0.7088
# Fold 4: 0.7333
# Fold 5: 0.7047
# Fold 6: 0.6625
# Fold 7: 0.6712
# Fold 8: 0.6973
# Fold 9: 0.7022
# Fold 10: 0.7097
#
# Iteration 2:
# Fold 1: 0.7113
# Fold 2: 0.7100
# Fold 3: 0.7001
# Fold 4: 0.6960
# Fold 5: 0.6886
# Fold 6: 0.6998
# Fold 7: 0.7097
# Fold 8: 0.6998
# Fold 9: 0.6898
# Fold 10: 0.7159
#
# Iteration 3:
# Fold 1: 0.7076
# Fold 2: 0.7150
# Fold 3: 0.6952
# Fold 4: 0.6725
# Fold 5: 0.6712
# Fold 6: 0.7295
# Fold 7: 0.7109
# Fold 8: 0.7171
# Fold 9: 0.6973
# Fold 10: 0.7047
#
# Iteration 4:
# Fold 1: 0.7014
# Fold 2: 0.7348
# Fold 3: 0.6989
# Fold 4: 0.7208
# Fold 5: 0.7060
# Fold 6: 0.6811
# Fold 7: 0.6998
# Fold 8: 0.7047
# Fold 9: 0.6886
# Fold 10: 0.6849
#
# Iteration 5:
# Fold 1: 0.6952
# Fold 2: 0.6791
# Fold 3: 0.7051
# Fold 4: 0.7357
# Fold 5: 0.6811
# Fold 6: 0.7010
# Fold 7: 0.7022
# Fold 8: 0.7159
# Fold 9: 0.7047
# Fold 10: 0.7010
#
# Iteration 6:
# Fold 1: 0.7014
# Fold 2: 0.6791
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_41 = np.mean(mnb_cv_scores)
mnb_std_scores_41 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_41)
print("Standard Deviations:", mnb_std_scores_41)
# Out:
# Mean Scores: 0.7020949446683947
# Standard Deviations: 0.014969522773075509

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6865
# Fold 2: 0.6964
# Fold 3: 0.6976
# Fold 4: 0.7208
# Fold 5: 0.7320
# Fold 6: 0.7171
# Fold 7: 0.7060
# Fold 8: 0.6886
# Fold 9: 0.6948
# Fold 10: 0.6811
#
# Iteration 2:
# Fold 1: 0.6778
# Fold 2: 0.6741
# Fold 3: 0.7026
# Fold 4: 0.6985
# Fold 5: 0.6836
# Fold 6: 0.7221
# Fold 7: 0.7159
# Fold 8: 0.7159
# Fold 9: 0.7035
# Fold 10: 0.7270
#
# Iteration 3:
# Fold 1: 0.7076
# Fold 2: 0.7063
# Fold 3: 0.7187
# Fold 4: 0.7084
# Fold 5: 0.7159
# Fold 6: 0.6700
# Fold 7: 0.6836
# Fold 8: 0.7333
# Fold 9: 0.7060
# Fold 10: 0.6712
#
# Iteration 4:
# Fold 1: 0.6989
# Fold 2: 0.7261
# Fold 3: 0.6729
# Fold 4: 0.7171
# Fold 5: 0.7022
# Fold 6: 0.6836
# Fold 7: 0.7010
# Fold 8: 0.7084
# Fold 9: 0.6923
# Fold 10: 0.7184
#
# Iteration 5:
# Fold 1: 0.7100
# Fold 2: 0.6939
# Fold 3: 0.7162
# Fold 4: 0.7171
# Fold 5: 0.6898
# Fold 6: 0.6911
# Fold 7: 0.6873
# Fold 8: 0.6873
# Fold 9: 0.7084
# Fold 10: 0.7196
#
# Iteration 6:
# Fold 1: 0.6989
# Fold 2: 0.6877
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_42 = np.mean(mnb_cv_scores)
mnb_std_scores_42 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_42)
print("Standard Deviations:", mnb_std_scores_42)
# Out:
# Mean Scores: 0.7020960669821444
# Standard Deviations: 0.016087639055414785

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6914
# Fold 2: 0.6952
# Fold 3: 0.7162
# Fold 4: 0.6663
# Fold 5: 0.7072
# Fold 6: 0.7035
# Fold 7: 0.7022
# Fold 8: 0.7047
# Fold 9: 0.7208
# Fold 10: 0.7134
#
# Iteration 2:
# Fold 1: 0.7051
# Fold 2: 0.7038
# Fold 3: 0.7076
# Fold 4: 0.7060
# Fold 5: 0.7370
# Fold 6: 0.6873
# Fold 7: 0.6613
# Fold 8: 0.7060
# Fold 9: 0.7022
# Fold 10: 0.7047
#
# Iteration 3:
# Fold 1: 0.6803
# Fold 2: 0.7162
# Fold 3: 0.6890
# Fold 4: 0.6973
# Fold 5: 0.7122
# Fold 6: 0.7109
# Fold 7: 0.7258
# Fold 8: 0.6799
# Fold 9: 0.6973
# Fold 10: 0.7122
#
# Iteration 4:
# Fold 1: 0.6877
# Fold 2: 0.6976
# Fold 3: 0.7014
# Fold 4: 0.6898
# Fold 5: 0.7196
# Fold 6: 0.7345
# Fold 7: 0.6998
# Fold 8: 0.6998
# Fold 9: 0.7084
# Fold 10: 0.6824
#
# Iteration 5:
# Fold 1: 0.7113
# Fold 2: 0.7076
# Fold 3: 0.6803
# Fold 4: 0.7109
# Fold 5: 0.6948
# Fold 6: 0.7184
# Fold 7: 0.6960
# Fold 8: 0.6787
# Fold 9: 0.7122
# Fold 10: 0.7109
#
# Iteration 6:
# Fold 1: 0.6964
# Fold 2: 0.7162
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_43 = np.mean(mnb_cv_scores)
mnb_std_scores_43 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_43)
print("Standard Deviations:", mnb_std_scores_43)
# Out:
# Mean Scores: 0.7020961899754319
# Standard Deviations: 0.014635359528546475

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7113
# Fold 2: 0.7187
# Fold 3: 0.7348
# Fold 4: 0.6787
# Fold 5: 0.7208
# Fold 6: 0.6576
# Fold 7: 0.7233
# Fold 8: 0.7246
# Fold 9: 0.6663
# Fold 10: 0.6849
#
# Iteration 2:
# Fold 1: 0.6939
# Fold 2: 0.6939
# Fold 3: 0.6989
# Fold 4: 0.7308
# Fold 5: 0.6849
# Fold 6: 0.7109
# Fold 7: 0.7295
# Fold 8: 0.6799
# Fold 9: 0.7010
# Fold 10: 0.6973
#
# Iteration 3:
# Fold 1: 0.7175
# Fold 2: 0.7088
# Fold 3: 0.7088
# Fold 4: 0.7382
# Fold 5: 0.6576
# Fold 6: 0.6998
# Fold 7: 0.6886
# Fold 8: 0.7097
# Fold 9: 0.6873
# Fold 10: 0.7047
#
# Iteration 4:
# Fold 1: 0.7038
# Fold 2: 0.6853
# Fold 3: 0.7051
# Fold 4: 0.6911
# Fold 5: 0.7047
# Fold 6: 0.7146
# Fold 7: 0.7072
# Fold 8: 0.7010
# Fold 9: 0.6960
# Fold 10: 0.7122
#
# Iteration 5:
# Fold 1: 0.6766
# Fold 2: 0.7398
# Fold 3: 0.6865
# Fold 4: 0.7159
# Fold 5: 0.6948
# Fold 6: 0.7134
# Fold 7: 0.6923
# Fold 8: 0.7047
# Fold 9: 0.7109
# Fold 10: 0.6861
#
# Iteration 6:
# Fold 1: 0.7026
# Fold 2: 0.7026
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_44 = np.mean(mnb_cv_scores)
mnb_std_scores_44 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_44)
print("Standard Deviations:", mnb_std_scores_44)
# Out:
# Mean Scores: 0.702096174601271
# Standard Deviations: 0.0169394935038729

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6791
# Fold 2: 0.7088
# Fold 3: 0.7187
# Fold 4: 0.6911
# Fold 5: 0.6923
# Fold 6: 0.6985
# Fold 7: 0.6811
# Fold 8: 0.7146
# Fold 9: 0.7246
# Fold 10: 0.7122
#
# Iteration 2:
# Fold 1: 0.7088
# Fold 2: 0.7125
# Fold 3: 0.7162
# Fold 4: 0.6762
# Fold 5: 0.7221
# Fold 6: 0.6911
# Fold 7: 0.6948
# Fold 8: 0.7035
# Fold 9: 0.7171
# Fold 10: 0.6787
#
# Iteration 3:
# Fold 1: 0.6877
# Fold 2: 0.7162
# Fold 3: 0.6902
# Fold 4: 0.6923
# Fold 5: 0.7097
# Fold 6: 0.6911
# Fold 7: 0.7109
# Fold 8: 0.6911
# Fold 9: 0.7109
# Fold 10: 0.7208
#
# Iteration 4:
# Fold 1: 0.6865
# Fold 2: 0.7249
# Fold 3: 0.6716
# Fold 4: 0.7159
# Fold 5: 0.7047
# Fold 6: 0.7097
# Fold 7: 0.7109
# Fold 8: 0.6948
# Fold 9: 0.7283
# Fold 10: 0.6737
#
# Iteration 5:
# Fold 1: 0.6741
# Fold 2: 0.7138
# Fold 3: 0.7014
# Fold 4: 0.7146
# Fold 5: 0.7171
# Fold 6: 0.6787
# Fold 7: 0.6849
# Fold 8: 0.7308
# Fold 9: 0.6985
# Fold 10: 0.7072
#
# Iteration 6:
# Fold 1: 0.6902
# Fold 2: 0.7076
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_45 = np.mean(mnb_cv_scores)
mnb_std_scores_45 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_45)
print("Standard Deviations:", mnb_std_scores_45)
# Out:
# Mean Scores: 0.7020962053495928
# Standard Deviations: 0.015422132532196086

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6989
# Fold 2: 0.6791
# Fold 3: 0.7138
# Fold 4: 0.7084
# Fold 5: 0.6836
# Fold 6: 0.7022
# Fold 7: 0.6973
# Fold 8: 0.7146
# Fold 9: 0.7146
# Fold 10: 0.7084
#
# Iteration 2:
# Fold 1: 0.6927
# Fold 2: 0.6914
# Fold 3: 0.7361
# Fold 4: 0.7072
# Fold 5: 0.6849
# Fold 6: 0.6985
# Fold 7: 0.7084
# Fold 8: 0.7171
# Fold 9: 0.6973
# Fold 10: 0.6873
#
# Iteration 3:
# Fold 1: 0.6877
# Fold 2: 0.6853
# Fold 3: 0.7113
# Fold 4: 0.7060
# Fold 5: 0.6935
# Fold 6: 0.7171
# Fold 7: 0.7171
# Fold 8: 0.6886
# Fold 9: 0.7146
# Fold 10: 0.6998
#
# Iteration 4:
# Fold 1: 0.7051
# Fold 2: 0.7509
# Fold 3: 0.7088
# Fold 4: 0.6923
# Fold 5: 0.7047
# Fold 6: 0.6898
# Fold 7: 0.6563
# Fold 8: 0.6985
# Fold 9: 0.7159
# Fold 10: 0.6985
#
# Iteration 5:
# Fold 1: 0.7212
# Fold 2: 0.6927
# Fold 3: 0.6840
# Fold 4: 0.6985
# Fold 5: 0.6861
# Fold 6: 0.7184
# Fold 7: 0.7333
# Fold 8: 0.6985
# Fold 9: 0.7022
# Fold 10: 0.6861
#
# Iteration 6:
# Fold 1: 0.7261
# Fold 2: 0.6890
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_46 = np.mean(mnb_cv_scores)
mnb_std_scores_46 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_46)
print("Standard Deviations:", mnb_std_scores_46)
# Out:
# Mean Scores: 0.7020950676616823
# Standard Deviations: 0.01598944896625991

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7088
# Fold 2: 0.7100
# Fold 3: 0.6853
# Fold 4: 0.7010
# Fold 5: 0.7270
# Fold 6: 0.6985
# Fold 7: 0.7060
# Fold 8: 0.6774
# Fold 9: 0.6799
# Fold 10: 0.7270
#
# Iteration 2:
# Fold 1: 0.7076
# Fold 2: 0.6902
# Fold 3: 0.6890
# Fold 4: 0.7333
# Fold 5: 0.7196
# Fold 6: 0.6911
# Fold 7: 0.6849
# Fold 8: 0.7097
# Fold 9: 0.6849
# Fold 10: 0.7109
#
# Iteration 3:
# Fold 1: 0.6766
# Fold 2: 0.6902
# Fold 3: 0.7187
# Fold 4: 0.7171
# Fold 5: 0.6985
# Fold 6: 0.6886
# Fold 7: 0.6923
# Fold 8: 0.7035
# Fold 9: 0.7196
# Fold 10: 0.7159
#
# Iteration 4:
# Fold 1: 0.7249
# Fold 2: 0.7138
# Fold 3: 0.6902
# Fold 4: 0.7196
# Fold 5: 0.7022
# Fold 6: 0.6923
# Fold 7: 0.7010
# Fold 8: 0.6799
# Fold 9: 0.6811
# Fold 10: 0.7159
#
# Iteration 5:
# Fold 1: 0.6828
# Fold 2: 0.7150
# Fold 3: 0.7175
# Fold 4: 0.7146
# Fold 5: 0.7146
# Fold 6: 0.6824
# Fold 7: 0.7060
# Fold 8: 0.7134
# Fold 9: 0.7010
# Fold 10: 0.6737
#
# Iteration 6:
# Fold 1: 0.7100
# Fold 2: 0.7187
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_47 = np.mean(mnb_cv_scores)
mnb_std_scores_47 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_47)
print("Standard Deviations:", mnb_std_scores_47)
# Out:
# Mean Scores: 0.702096881812675
# Standard Deviations: 0.015050159925716301

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7026
# Fold 2: 0.7063
# Fold 3: 0.7014
# Fold 4: 0.6873
# Fold 5: 0.7171
# Fold 6: 0.7047
# Fold 7: 0.7010
# Fold 8: 0.6923
# Fold 9: 0.7357
# Fold 10: 0.6725
#
# Iteration 2:
# Fold 1: 0.6964
# Fold 2: 0.7014
# Fold 3: 0.7113
# Fold 4: 0.7146
# Fold 5: 0.7035
# Fold 6: 0.6787
# Fold 7: 0.6886
# Fold 8: 0.7333
# Fold 9: 0.7134
# Fold 10: 0.6799
#
# Iteration 3:
# Fold 1: 0.7212
# Fold 2: 0.7261
# Fold 3: 0.6902
# Fold 4: 0.6973
# Fold 5: 0.7097
# Fold 6: 0.6935
# Fold 7: 0.7047
# Fold 8: 0.6836
# Fold 9: 0.7072
# Fold 10: 0.6873
#
# Iteration 4:
# Fold 1: 0.7138
# Fold 2: 0.7051
# Fold 3: 0.6964
# Fold 4: 0.6712
# Fold 5: 0.7159
# Fold 6: 0.6787
# Fold 7: 0.6911
# Fold 8: 0.7146
# Fold 9: 0.7084
# Fold 10: 0.7258
#
# Iteration 5:
# Fold 1: 0.7026
# Fold 2: 0.6914
# Fold 3: 0.7001
# Fold 4: 0.6799
# Fold 5: 0.6998
# Fold 6: 0.7208
# Fold 7: 0.7097
# Fold 8: 0.6960
# Fold 9: 0.7097
# Fold 10: 0.7109
#
# Iteration 6:
# Fold 1: 0.6865
# Fold 2: 0.6629
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_48 = np.mean(mnb_cv_scores)
mnb_std_scores_48 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_48)
print("Standard Deviations:", mnb_std_scores_48)
# Out:
# Mean Scores: 0.7020960516079836
# Standard Deviations: 0.01573635705159754

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6815
# Fold 2: 0.7249
# Fold 3: 0.6741
# Fold 4: 0.6923
# Fold 5: 0.7084
# Fold 6: 0.7146
# Fold 7: 0.7072
# Fold 8: 0.7084
# Fold 9: 0.7221
# Fold 10: 0.6873
#
# Iteration 2:
# Fold 1: 0.7237
# Fold 2: 0.6803
# Fold 3: 0.7113
# Fold 4: 0.7221
# Fold 5: 0.6898
# Fold 6: 0.6898
# Fold 7: 0.7333
# Fold 8: 0.6836
# Fold 9: 0.7010
# Fold 10: 0.6861
#
# Iteration 3:
# Fold 1: 0.6989
# Fold 2: 0.7076
# Fold 3: 0.6902
# Fold 4: 0.7134
# Fold 5: 0.6836
# Fold 6: 0.6923
# Fold 7: 0.7146
# Fold 8: 0.7010
# Fold 9: 0.7208
# Fold 10: 0.6985
#
# Iteration 4:
# Fold 1: 0.7150
# Fold 2: 0.7373
# Fold 3: 0.7076
# Fold 4: 0.6824
# Fold 5: 0.6811
# Fold 6: 0.6687
# Fold 7: 0.7258
# Fold 8: 0.6898
# Fold 9: 0.7072
# Fold 10: 0.7060
#
# Iteration 5:
# Fold 1: 0.7125
# Fold 2: 0.7299
# Fold 3: 0.6704
# Fold 4: 0.7010
# Fold 5: 0.7022
# Fold 6: 0.6960
# Fold 7: 0.7171
# Fold 8: 0.6911
# Fold 9: 0.7047
# Fold 10: 0.6960
#
# Iteration 6:
# Fold 1: 0.6989
# Fold 2: 0.7212
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_49 = np.mean(mnb_cv_scores)
mnb_std_scores_49 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_49)
print("Standard Deviations:", mnb_std_scores_49)
# Out:
# Mean Scores: 0.7020958209955692
# Standard Deviations: 0.016408562475669793

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold


class MNBClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, alpha=1.0):
        self.model = MultinomialNB(alpha=alpha)
        self.alpha = alpha

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Initialize MNB classifier
mnb_classifier = MNBClassifier()
n_iterations = 10  # Number of iterations
k_folds = 10  # Number of folds

# Initialize a list to store cross-validation scores for MNB
mnb_cv_scores = []

for _ in range(n_iterations):
    # Perform cross-validation and calculate scores for MNB
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
    scores = cross_val_score(mnb_classifier, X, y, cv=kf)
    
    # Append the scores to the list for MNB
    mnb_cv_scores.append(scores)

# Convert the list of scores for MNB to a NumPy array for analysis
mnb_cv_scores = np.array(mnb_cv_scores)

# Print the cross-validation scores for each iteration and fold for MNB
for i, scores in enumerate(mnb_cv_scores):
    print(f"Iteration {i + 1}:")
    for j, score in enumerate(scores):
        print(f"Fold {j + 1}: {score:.4f}")
    print("")

# Calculate and print the mean and standard deviation of the scores for MNB
mnb_mean_scores = np.mean(mnb_cv_scores, axis=1)
mnb_std_scores = np.std(mnb_cv_scores, axis=1)
print("Mean Scores for MNB:", mnb_mean_scores)
print("Standard Deviations for MNB:", mnb_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7001
# Fold 2: 0.7038
# Fold 3: 0.7261
# Fold 4: 0.6985
# Fold 5: 0.7109
# Fold 6: 0.6923
# Fold 7: 0.6998
# Fold 8: 0.6861
# Fold 9: 0.6935
# Fold 10: 0.7097
#
# Iteration 2:
# Fold 1: 0.6927
# Fold 2: 0.6976
# Fold 3: 0.7200
# Fold 4: 0.7084
# Fold 5: 0.6973
# Fold 6: 0.6799
# Fold 7: 0.7097
# Fold 8: 0.6973
# Fold 9: 0.7084
# Fold 10: 0.7097
#
# Iteration 3:
# Fold 1: 0.7001
# Fold 2: 0.7076
# Fold 3: 0.7063
# Fold 4: 0.7295
# Fold 5: 0.7159
# Fold 6: 0.6824
# Fold 7: 0.6749
# Fold 8: 0.6886
# Fold 9: 0.7196
# Fold 10: 0.6960
#
# Iteration 4:
# Fold 1: 0.6791
# Fold 2: 0.6865
# Fold 3: 0.6840
# Fold 4: 0.7122
# Fold 5: 0.7159
# Fold 6: 0.6985
# Fold 7: 0.7035
# Fold 8: 0.7134
# Fold 9: 0.6973
# Fold 10: 0.7308
#
# Iteration 5:
# Fold 1: 0.6914
# Fold 2: 0.7261
# Fold 3: 0.6902
# Fold 4: 0.7097
# Fold 5: 0.7060
# Fold 6: 0.7060
# Fold 7: 0.7109
# Fold 8: 0.6886
# Fold 9: 0.6898
# Fold 10: 0.7022
#
# Iteration 6:
# Fold 1: 0.7038
# Fold 2: 0.7088
# ...

# %%
# Calculate and print the mean and standard deviation of the scores
mnb_mean_scores_50 = np.mean(mnb_cv_scores)
mnb_std_scores_50 = np.std(mnb_cv_scores)
print("Mean Scores:", mnb_mean_scores_50)
print("Standard Deviations:", mnb_std_scores_50)
# Out:
# Mean Scores: 0.7020956057573159
# Standard Deviations: 0.013695478261273484

# %%
values1 = [mnb_mean_scores_1,mnb_mean_scores_2,mnb_mean_scores_3,mnb_mean_scores_4,mnb_mean_scores_5,mnb_mean_scores_6,mnb_mean_scores_7,mnb_mean_scores_8,mnb_mean_scores_9,mnb_mean_scores_10,mnb_mean_scores_11,mnb_mean_scores_12,mnb_mean_scores_13,mnb_mean_scores_14,mnb_mean_scores_15,mnb_mean_scores_16,mnb_mean_scores_17,mnb_mean_scores_18,mnb_mean_scores_19,mnb_mean_scores_20,mnb_mean_scores_21,mnb_mean_scores_22,mnb_mean_scores_23,mnb_mean_scores_24,mnb_mean_scores_25,mnb_mean_scores_26,mnb_mean_scores_27,mnb_mean_scores_28,mnb_mean_scores_29,mnb_mean_scores_30,mnb_mean_scores_31,mnb_mean_scores_32,mnb_mean_scores_33,mnb_mean_scores_34,mnb_mean_scores_35,mnb_mean_scores_36,mnb_mean_scores_37,mnb_mean_scores_38,mnb_mean_scores_39,mnb_mean_scores_40,mnb_mean_scores_41,mnb_mean_scores_42,mnb_mean_scores_43,mnb_mean_scores_44,mnb_mean_scores_45,mnb_mean_scores_46,mnb_mean_scores_47,mnb_mean_scores_48,mnb_mean_scores_49,mnb_mean_scores_50]
print(values1)
# Out:
# [0.7020969279351579, 0.7020976966432058, 0.7020947448043023, 0.7020962207237541, 0.7020959132405348, 0.7020963437170415, 0.7020959747371788, 0.7020976658948839, 0.7020970663026066, 0.7020954366415453, 0.7020968664385143, 0.7020960516079835, 0.7020959439888569, 0.7020948370492678, 0.7020958824922127, 0.7020962822203978, 0.7020975582757571, 0.7020944680694052, 0.702097235418377, 0.7020957902472472, 0.702095236777453, 0.7020968510643532, 0.7020960208596617, 0.7020966512002605, 0.7020966204519388, 0.7020947140559802, 0.7020958209955691, 0.7020961592271102, 0.7020970970509285, 0.7020963590912025, 0.7020954981381891, 0.702096558955295, 0.7020956057573156, 0.7020960362338226, 0.702098311609644, 0.7020958209955691, 0.7020970970509282, 0.7020948985459118, 0.7020966819485828, 0.7020956518797987, 0.7020949446683947, 0.7020960669821444, 0.7020961899754319, 0.702096174601271, 0.7020962053495928, 0.7020950676616823, 0.702096881812675, 0.7020960516079836, 0.7020958209955692, 0.7020956057573159]

# %%
values2 = [mnb_std_scores_1,mnb_std_scores_2,mnb_std_scores_3,mnb_std_scores_4,mnb_std_scores_5,mnb_std_scores_6,mnb_std_scores_7,mnb_std_scores_8,mnb_std_scores_9,mnb_std_scores_10,mnb_std_scores_11,mnb_std_scores_12,mnb_std_scores_13,mnb_std_scores_14,mnb_std_scores_15,mnb_std_scores_16,mnb_std_scores_17,mnb_std_scores_18,mnb_std_scores_19,mnb_std_scores_20,mnb_std_scores_21,mnb_std_scores_22,mnb_std_scores_23,mnb_std_scores_24,mnb_std_scores_25,mnb_std_scores_26,mnb_std_scores_27,mnb_std_scores_28,mnb_std_scores_29,mnb_std_scores_30,mnb_std_scores_31,mnb_std_scores_32,mnb_std_scores_33,mnb_std_scores_34,mnb_std_scores_35,mnb_std_scores_36,mnb_std_scores_37,mnb_std_scores_38,mnb_std_scores_39,mnb_std_scores_40,mnb_std_scores_41,mnb_std_scores_42,mnb_std_scores_43,mnb_std_scores_44,mnb_std_scores_45,mnb_std_scores_46,mnb_std_scores_47,mnb_std_scores_48,mnb_std_scores_49,mnb_std_scores_50]
print(values2)
# Out:
# [0.013545174954489262, 0.01605713468272106, 0.01612190663125187, 0.015041876938787365, 0.013393835556726026, 0.014995671282596636, 0.014892874029123865, 0.014306603129348328, 0.01622984086145767, 0.013992891268741373, 0.015585269125875201, 0.016259900288598327, 0.01609494125693961, 0.01486192130921507, 0.01649625145620127, 0.014778102077639771, 0.01569635084395917, 0.013115381346372605, 0.015751761934744653, 0.016007982767589, 0.013080485806307095, 0.015581922574525753, 0.01463411706273321, 0.01475093839788625, 0.015833865543149733, 0.016159411842943203, 0.016186264538288645, 0.017229501676238584, 0.013058161145844483, 0.01763016656436762, 0.014702526493102304, 0.015767275283493812, 0.01782393037738273, 0.01589944330735111, 0.01674981807731691, 0.017555708156231246, 0.016393484616977507, 0.01509624120770662, 0.01673739701818803, 0.015943236842937733, 0.014969522773075509, 0.016087639055414785, 0.014635359528546475, 0.0169394935038729, 0.015422132532196086, 0.01598944896625991, 0.0150
# ...

# %%
mean=np.mean(values1)
std=np.mean(values2)
print("MNB Mean is:",mean)
print("MNB Standard Deviation is:",std)
# Out:
# MNB Mean is: 0.702096152154996
# MNB Standard Deviation is: 0.015499474446979468

# %%
import matplotlib.pyplot as plt
# Generating x-values based on the index of the list
x_values1 = list(range(len(values1)))

# Scatter plot with lines connecting the points
plt.figure(figsize=(8, 5))
plt.scatter(x_values1, values1, color='blue', marker='o', s=100)  # s is the marker size
plt.plot(x_values1, values1, color='blue', linestyle='-', linewidth=1.5)  # Connecting the points with a line

# Providing labels for the axes and the title for the graph
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Scatter Plot with Connected Points')
plt.xticks(x_values1)  # Setting x-ticks to match the indices

# Displaying the plot
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
# Generating x-values based on the index of the list
x_values2 = list(range(len(values2)))

# Scatter plot with lines connecting the points
plt.figure(figsize=(8, 5))
plt.scatter(x_values2, values2, color='blue', marker='o', s=100)  # s is the marker size
plt.plot(x_values2, values2, color='blue', linestyle='-', linewidth=1.5)  # Connecting the points with a line

# Providing labels for the axes and the title for the graph
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Scatter Plot with Connected Points')
plt.xticks(x_values2)  # Setting x-ticks to match the indices

# Displaying the plot
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler

# 1. Discretize the target variable y
bin_discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
y_train_binned = bin_discretizer.fit_transform(y_train.reshape(-1, 1)).ravel()
y_test_binned = bin_discretizer.transform(y_test.reshape(-1, 1)).ravel()

# Standardize the features
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 2. Train the Multinomial NB
clf = MultinomialNB()
clf.fit(X_train_scaled, y_train_binned)

# 3. Make predictions
sample_X = X_test_scaled[0].reshape(1, -1)
predicted_bin = clf.predict(sample_X)
bin_edges = bin_discretizer.bin_edges_[0]
predicted_bug_fixing_time = (bin_edges[int(predicted_bin)] + bin_edges[int(predicted_bin) + 1]) / 2

print("Predicted next bug fixing time is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:
    print("Fast")
else:
        print("Slow")
# Out:
# Predicted next bug fixing time is: 0.05
# Fast

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler



# 1. Discretize the target variable y
bin_discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
y_train_binned1 = bin_discretizer.fit_transform(y_train1.reshape(-1, 1)).ravel()
y_test_binned1 = bin_discretizer.transform(y_test1.reshape(-1, 1)).ravel()

# Standardize the features
scaler = MinMaxScaler()
X_train_scaled1 = scaler.fit_transform(X_train1)
X_test_scaled1 = scaler.transform(X_test1)

# 2. Train the Multinomial NB
clf = MultinomialNB()
clf.fit(X_train_scaled1, y_train_binned1)

# 3. Make predictions
sample_X1 = X_test_scaled1[0].reshape(1, -1)
predicted_bin = clf.predict(sample_X1)
bin_edges = bin_discretizer.bin_edges_[0]
predicted_bug_fixing_time = (bin_edges[int(predicted_bin)] + bin_edges[int(predicted_bin) + 1]) / 2

print("Predicted next bug fixing time is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:
    print("Fast")
else:
        print("Slow")
# Out:
# Predicted next bug fixing time is: 0.05
# Fast

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler



# 1. Discretize the target variable y
bin_discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
y_train_binned2 = bin_discretizer.fit_transform(y_train2.reshape(-1, 1)).ravel()
y_test_binned2 = bin_discretizer.transform(y_test2.reshape(-1, 1)).ravel()

# Standardize the features
scaler = MinMaxScaler()
X_train_scaled2 = scaler.fit_transform(X_train2)
X_test_scaled2 = scaler.transform(X_test2)

# 2. Train the Multinomial NB
clf = MultinomialNB()
clf.fit(X_train_scaled2, y_train_binned2)

# 3. Make predictions
sample_X2 = X_test_scaled2[0].reshape(1, -1)
predicted_bin = clf.predict(sample_X2)
bin_edges = bin_discretizer.bin_edges_[0]
predicted_bug_fixing_time = (bin_edges[int(predicted_bin)] + bin_edges[int(predicted_bin) + 1]) / 2

print("Predicted next bug fixing time is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:
    print("Fast")
else:
        print("Slow")
# Out:
# Predicted next bug fixing time is: 0.05
# Fast

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler



# 1. Discretize the target variable y
bin_discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
y_train_binned3 = bin_discretizer.fit_transform(y_train3.reshape(-1, 1)).ravel()
y_test_binned3 = bin_discretizer.transform(y_test3.reshape(-1, 1)).ravel()

# Standardize the features
scaler = MinMaxScaler()
X_train_scaled3 = scaler.fit_transform(X_train3)
X_test_scaled3 = scaler.transform(X_test3)

# 2. Train the Multinomial NB
clf = MultinomialNB()
clf.fit(X_train_scaled3, y_train_binned3)

# 3. Make predictions
sample_X3 = X_test_scaled3[0].reshape(1, -1)
predicted_bin = clf.predict(sample_X3)
bin_edges = bin_discretizer.bin_edges_[0]
predicted_bug_fixing_time = (bin_edges[int(predicted_bin)] + bin_edges[int(predicted_bin) + 1]) / 2

print("Predicted next bug fixing time is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:
    print("Fast")
else:
        print("Slow")
# Out:
# Predicted next bug fixing time is: 0.95
# Fast

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler



# 1. Discretize the target variable y
bin_discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
y_train_binned4 = bin_discretizer.fit_transform(y_train4.reshape(-1, 1)).ravel()
y_test_binned4 = bin_discretizer.transform(y_test4.reshape(-1, 1)).ravel()

# Standardize the features
scaler = MinMaxScaler()
X_train_scaled4 = scaler.fit_transform(X_train4)
X_test_scaled4 = scaler.transform(X_test4)

# 2. Train the Multinomial NB
clf = MultinomialNB()
clf.fit(X_train_scaled4, y_train_binned4)

# 3. Make predictions
sample_X4 = X_test_scaled4[0].reshape(1, -1)
predicted_bin = clf.predict(sample_X4)
bin_edges = bin_discretizer.bin_edges_[0]
predicted_bug_fixing_time = (bin_edges[int(predicted_bin)] + bin_edges[int(predicted_bin) + 1]) / 2

print("Predicted next bug fixing time is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:
    print("Fast")
else:
        print("Slow")
# Out:
# Predicted next bug fixing time is: 0.05
# Fast

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler



# 1. Discretize the target variable y
bin_discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
y_train_binned5 = bin_discretizer.fit_transform(y_train5.reshape(-1, 1)).ravel()
y_test_binned5 = bin_discretizer.transform(y_test5.reshape(-1, 1)).ravel()

# Standardize the features
scaler = MinMaxScaler()
X_train_scaled5 = scaler.fit_transform(X_train5)
X_test_scaled5 = scaler.transform(X_test5)

# 2. Train the Multinomial NB
clf = MultinomialNB()
clf.fit(X_train_scaled5, y_train_binned5)

# 3. Make predictions
sample_X5 = X_test_scaled5[0].reshape(1, -1)
predicted_bin = clf.predict(sample_X5)
bin_edges = bin_discretizer.bin_edges_[0]
predicted_bug_fixing_time = (bin_edges[int(predicted_bin)] + bin_edges[int(predicted_bin) + 1]) / 2

print("Predicted next bug fixing time is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:
    print("Fast")
else:
        print("Slow")
# Out:
# Predicted next bug fixing time is: 0.05
# Fast

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler



# 1. Discretize the target variable y
bin_discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
y_train_binned6 = bin_discretizer.fit_transform(y_train6.reshape(-1, 1)).ravel()
y_test_binned6 = bin_discretizer.transform(y_test6.reshape(-1, 1)).ravel()

# Standardize the features
scaler = MinMaxScaler()
X_train_scaled6 = scaler.fit_transform(X_train6)
X_test_scaled6 = scaler.transform(X_test6)

# 2. Train the Multinomial NB
clf = MultinomialNB()
clf.fit(X_train_scaled6, y_train_binned6)

# 3. Make predictions
sample_X6 = X_test_scaled6[0].reshape(1, -1)
predicted_bin = clf.predict(sample_X6)
bin_edges = bin_discretizer.bin_edges_[0]
predicted_bug_fixing_time = (bin_edges[int(predicted_bin)] + bin_edges[int(predicted_bin) + 1]) / 2

print("Predicted next bug fixing time is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:
    print("Fast")
else:
        print("Slow")
# Out:
# Predicted next bug fixing time is: 0.05
# Fast

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler



# 1. Discretize the target variable y
bin_discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
y_train_binned7 = bin_discretizer.fit_transform(y_train7.reshape(-1, 1)).ravel()
y_test_binned7 = bin_discretizer.transform(y_test7.reshape(-1, 1)).ravel()

# Standardize the features
scaler = MinMaxScaler()
X_train_scaled7 = scaler.fit_transform(X_train7)
X_test_scaled7 = scaler.transform(X_test7)

# 2. Train the Multinomial NB
clf = MultinomialNB()
clf.fit(X_train_scaled7, y_train_binned7)

# 3. Make predictions
sample_X7 = X_test_scaled7[0].reshape(1, -1)
predicted_bin = clf.predict(sample_X7)
bin_edges = bin_discretizer.bin_edges_[0]
predicted_bug_fixing_time = (bin_edges[int(predicted_bin)] + bin_edges[int(predicted_bin) + 1]) / 2

print("Predicted next bug fixing time is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:
    print("Fast")
else:
        print("Slow")
# Out:
# Predicted next bug fixing time is: 0.05
# Fast

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler



# 1. Discretize the target variable y
bin_discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
y_train_binned8 = bin_discretizer.fit_transform(y_train8.reshape(-1, 1)).ravel()
y_test_binned8 = bin_discretizer.transform(y_test8.reshape(-1, 1)).ravel()

# Standardize the features
scaler = MinMaxScaler()
X_train_scaled8 = scaler.fit_transform(X_train8)
X_test_scaled8 = scaler.transform(X_test8)

# 2. Train the Multinomial NB
clf = MultinomialNB()
clf.fit(X_train_scaled8, y_train_binned8)

# 3. Make predictions
sample_X8 = X_test_scaled8[0].reshape(1, -1)
predicted_bin = clf.predict(sample_X8)
bin_edges = bin_discretizer.bin_edges_[0]
predicted_bug_fixing_time = (bin_edges[int(predicted_bin)] + bin_edges[int(predicted_bin) + 1]) / 2

print("Predicted next bug fixing time is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:
    print("Fast")
else:
        print("Slow")
# Out:
# Predicted next bug fixing time is: 0.05
# Fast

# %%
#Naive Bayes Multinomial
from sklearn.naive_bayes import MultinomialNB
# Training the Multinomial Naive Bayes model
clf_num = MultinomialNB()
clf_num.fit(X_train, y_train)
# Predicting on the test set
y_pred_mnb = clf_num.predict(X_test)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

# Assuming y_test and y_pred_mnb are available
# Calculate precision, accuracy, recall, f1_score, G-Measure, Matthews correlation coefficient, AUC, and confusion matrix
precision = precision_score(y_test, y_pred_mnb, average='macro')
accuracy = accuracy_score(y_test, y_pred_mnb)
recall = recall_score(y_test, y_pred_mnb, average='macro')
f_measure_mnb = f1_score(y_test, y_pred_mnb, average='macro')

def g_measure(y_test, y_pred_mnb):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test, y_pred_mnb, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test, y_pred_mnb)
MCC = matthews_corrcoef(y_test, y_pred_mnb)
AUC = roc_auc_score(y_test, y_pred_mnb)
cm = confusion_matrix(y_test, y_pred_mnb)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_mnb)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.3530688158710477
# Accuracy: 0.7061376317420954
# Recall: 0.5
# F-Measure: 0.4138808139534883
# G-Measure: 0.4138808134683214
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[1139    0]
#  [ 474    0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
#Naive Bayes Multinomial
from sklearn.naive_bayes import MultinomialNB
# Training the Multinomial Naive Bayes model
clf_num = MultinomialNB()
clf_num.fit(X_train1, y_train1)
# Predicting on the test set
y_pred_mnb = clf_num.predict(X_test1)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

# Assuming y_test1 and y_pred_mnb are available
# Calculate precision, accuracy, recall, f1_score, G-Measure, Matthews correlation coefficient, AUC, and confusion matrix
precision = precision_score(y_test1, y_pred_mnb, average='macro')
accuracy = accuracy_score(y_test1, y_pred_mnb)
recall = recall_score(y_test1, y_pred_mnb, average='macro')
f_measure_mnb = f1_score(y_test1, y_pred_mnb, average='macro')

def g_measure(y_test1, y_pred_mnb):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test1, y_pred_mnb, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test1, y_pred_mnb)
MCC = matthews_corrcoef(y_test1, y_pred_mnb)
AUC = roc_auc_score(y_test1, y_pred_mnb)
cm = confusion_matrix(y_test1, y_pred_mnb)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_mnb)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.3431372549019608
# Accuracy: 0.6862745098039216
# Recall: 0.5
# F-Measure: 0.4069767441860465
# G-Measure: 0.4069767437033532
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[35  0]
#  [16  0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
#Naive Bayes Multinomial
from sklearn.naive_bayes import MultinomialNB
# Training the Multinomial Naive Bayes model
clf_num = MultinomialNB()
clf_num.fit(X_train2, y_train2)
# Predicting on the test set
y_pred_mnb = clf_num.predict(X_test2)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

# Assuming y_test2 and y_pred_mnb are available
# Calculate precision, accuracy, recall, f1_score, G-Measure, Matthews correlation coefficient, AUC, and confusion matrix
precision = precision_score(y_test2, y_pred_mnb, average='macro')
accuracy = accuracy_score(y_test2, y_pred_mnb)
recall = recall_score(y_test2, y_pred_mnb, average='macro')
f_measure_mnb = f1_score(y_test2, y_pred_mnb, average='macro')

def g_measure(y_test2, y_pred_mnb):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test2, y_pred_mnb, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test2, y_pred_mnb)
MCC = matthews_corrcoef(y_test2, y_pred_mnb)
AUC = roc_auc_score(y_test2, y_pred_mnb)
cm = confusion_matrix(y_test2, y_pred_mnb)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_mnb)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.39285714285714285
# Accuracy: 0.7857142857142857
# Recall: 0.5
# F-Measure: 0.44
# G-Measure: 0.43999999950720003
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[66  0]
#  [18  0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
#Naive Bayes Multinomial
from sklearn.naive_bayes import MultinomialNB
# Training the Multinomial Naive Bayes model
clf_num = MultinomialNB()
clf_num.fit(X_train3, y_train3)
# Predicting on the test set
y_pred_mnb = clf_num.predict(X_test3)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

# Assuming y_test3 and y_pred_mnb are available
# Calculate precision, accuracy, recall, f1_score, G-Measure, Matthews correlation coefficient, AUC, and confusion matrix
precision = precision_score(y_test3, y_pred_mnb, average='macro')
accuracy = accuracy_score(y_test3, y_pred_mnb)
recall = recall_score(y_test3, y_pred_mnb, average='macro')
f_measure_mnb = f1_score(y_test3, y_pred_mnb, average='macro')

def g_measure(y_test3, y_pred_mnb):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test3, y_pred_mnb, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test3, y_pred_mnb)
MCC = matthews_corrcoef(y_test3, y_pred_mnb)
AUC = roc_auc_score(y_test3, y_pred_mnb)
cm = confusion_matrix(y_test3, y_pred_mnb)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_mnb)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.6219792865362486
# Accuracy: 0.6178861788617886
# Recall: 0.6122881355932204
# F-Measure: 0.6075089958585104
# G-Measure: 0.6170956643500971
# Matthews correlation coefficient: 0.23406688502346124
# Area under curve: 0.6122881355932203
# Confusion Matrix:
#  [[48 16]
#  [31 28]]
# Normalized Confusion Matrix:
#  [[0.75       0.25      ]
#  [0.52542373 0.47457627]]
# Min: 0.25
# Max: 0.75
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.17768844361238775
# Mean Square: 0.28157318299339273

# %%
#Naive Bayes Multinomial
from sklearn.naive_bayes import MultinomialNB
# Training the Multinomial Naive Bayes model
clf_num = MultinomialNB()
clf_num.fit(X_train4, y_train4)
# Predicting on the test set
y_pred_mnb = clf_num.predict(X_test4)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

# Assuming y_test4 and y_pred_mnb are available
# Calculate precision, accuracy, recall, f1_score, G-Measure, Matthews correlation coefficient, AUC, and confusion matrix
precision = precision_score(y_test4, y_pred_mnb, average='macro')
accuracy = accuracy_score(y_test4, y_pred_mnb)
recall = recall_score(y_test4, y_pred_mnb, average='macro')
f_measure_mnb = f1_score(y_test4, y_pred_mnb, average='macro')

def g_measure(y_test4, y_pred_mnb):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test4, y_pred_mnb, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test4, y_pred_mnb)
MCC = matthews_corrcoef(y_test4, y_pred_mnb)
AUC = roc_auc_score(y_test4, y_pred_mnb)
cm = confusion_matrix(y_test4, y_pred_mnb)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_mnb)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.3727810650887574
# Accuracy: 0.7455621301775148
# Recall: 0.5
# F-Measure: 0.4271186440677966
# G-Measure: 0.42711864357842
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[126   0]
#  [ 43   0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
#Naive Bayes Multinomial
from sklearn.naive_bayes import MultinomialNB
# Training the Multinomial Naive Bayes model
clf_num = MultinomialNB()
clf_num.fit(X_train5, y_train5)
# Predicting on the test set
y_pred_mnb = clf_num.predict(X_test5)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

# Assuming y_test5 and y_pred_mnb are available
# Calculate precision, accuracy, recall, f1_score, G-Measure, Matthews correlation coefficient, AUC, and confusion matrix
precision = precision_score(y_test5, y_pred_mnb, average='macro')
accuracy = accuracy_score(y_test5, y_pred_mnb)
recall = recall_score(y_test5, y_pred_mnb, average='macro')
f_measure_mnb = f1_score(y_test5, y_pred_mnb, average='macro')

def g_measure(y_test5, y_pred_mnb):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test5, y_pred_mnb, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test5, y_pred_mnb)
MCC = matthews_corrcoef(y_test5, y_pred_mnb)
AUC = roc_auc_score(y_test5, y_pred_mnb)
cm = confusion_matrix(y_test5, y_pred_mnb)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_mnb)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.3888888888888889
# Accuracy: 0.7777777777777778
# Recall: 0.5
# F-Measure: 0.43750000000000006
# G-Measure: 0.43749999950781254
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[140   0]
#  [ 40   0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
#Naive Bayes Multinomial
from sklearn.naive_bayes import MultinomialNB
# Training the Multinomial Naive Bayes model
clf_num = MultinomialNB()
clf_num.fit(X_train6, y_train6)
# Predicting on the test set
y_pred_mnb = clf_num.predict(X_test6)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

# Assuming y_test6 and y_pred_mnb are available
# Calculate precision, accuracy, recall, f1_score, G-Measure, Matthews correlation coefficient, AUC, and confusion matrix
precision = precision_score(y_test6, y_pred_mnb, average='macro')
accuracy = accuracy_score(y_test6, y_pred_mnb)
recall = recall_score(y_test6, y_pred_mnb, average='macro')
f_measure_mnb = f1_score(y_test6, y_pred_mnb, average='macro')

def g_measure(y_test6, y_pred_mnb):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test6, y_pred_mnb, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test6, y_pred_mnb)
MCC = matthews_corrcoef(y_test6, y_pred_mnb)
AUC = roc_auc_score(y_test6, y_pred_mnb)
cm = confusion_matrix(y_test6, y_pred_mnb)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_mnb)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.32132564841498557
# Accuracy: 0.6426512968299711
# Recall: 0.5
# F-Measure: 0.3912280701754386
# G-Measure: 0.39122806969910123
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[223   0]
#  [124   0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
#Naive Bayes Multinomial
from sklearn.naive_bayes import MultinomialNB
# Training the Multinomial Naive Bayes model
clf_num = MultinomialNB()
clf_num.fit(X_train7, y_train7)
# Predicting on the test set
y_pred_mnb = clf_num.predict(X_test7)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

# Assuming y_test7 and y_pred_mnb are available
# Calculate precision, accuracy, recall, f1_score, G-Measure, Matthews correlation coefficient, AUC, and confusion matrix
precision = precision_score(y_test7, y_pred_mnb, average='macro')
accuracy = accuracy_score(y_test7, y_pred_mnb)
recall = recall_score(y_test7, y_pred_mnb, average='macro')
f_measure_mnb = f1_score(y_test7, y_pred_mnb, average='macro')

def g_measure(y_test7, y_pred_mnb):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test7, y_pred_mnb, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test7, y_pred_mnb)
MCC = matthews_corrcoef(y_test7, y_pred_mnb)
AUC = roc_auc_score(y_test7, y_pred_mnb)
cm = confusion_matrix(y_test7, y_pred_mnb)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_mnb)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.38284518828451886
# Accuracy: 0.7656903765690377
# Recall: 0.5
# F-Measure: 0.4336492890995261
# G-Measure: 0.4336492886083309
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[183   0]
#  [ 56   0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
#Naive Bayes Multinomial
from sklearn.naive_bayes import MultinomialNB
# Training the Multinomial Naive Bayes model
clf_num = MultinomialNB()
clf_num.fit(X_train8, y_train8)
# Predicting on the test set
y_pred_mnb = clf_num.predict(X_test8)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

# Assuming y_test8 and y_pred_mnb are available
# Calculate precision, accuracy, recall, f1_score, G-Measure, Matthews correlation coefficient, AUC, and confusion matrix
precision = precision_score(y_test8, y_pred_mnb, average='macro')
accuracy = accuracy_score(y_test8, y_pred_mnb)
recall = recall_score(y_test8, y_pred_mnb, average='macro')
f_measure_mnb = f1_score(y_test8, y_pred_mnb, average='macro')

def g_measure(y_test8, y_pred_mnb):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test8, y_pred_mnb, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test8, y_pred_mnb)
MCC = matthews_corrcoef(y_test8, y_pred_mnb)
AUC = roc_auc_score(y_test8, y_pred_mnb)
cm = confusion_matrix(y_test8, y_pred_mnb)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_mnb)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.33886255924170616
# Accuracy: 0.6777251184834123
# Recall: 0.5
# F-Measure: 0.403954802259887
# G-Measure: 0.40395480177833637
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[286   0]
#  [136   0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5
