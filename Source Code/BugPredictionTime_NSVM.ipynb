# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#importing dataset
bugs=pd.read_csv(r"E:\Project\Firefox_Bugs_data.csv")
bugs.head()
# Out:
#     Bug ID     Reporting                                            Summary  \
# 0  1116989      Beginner       Guest users should not see introduction info
# 1  1047673      Beginner  URL checksums (for "securely" linking third-pa...
# 2  1108341  Intermediate  Context menu entries use the original URI inst...
# 3  1111278  Intermediate  A strip with all(?) possible icons is showing ...
# 4   992209      Beginner  invoking firefox with command line argument(s)...
#
#    Product                   Component Assignee       Status Notification  \
# 0  Firefox  Toolbars and Customization   Random  Unconfirmed       Normal
# 1  Firefox                     General   Random  Unconfirmed       Normal
# 2  Firefox                       Menus   Random  Unconfirmed       Normal
# 3  Firefox  Toolbars and Customization   Random  Unconfirmed         High
# 4  Firefox                     General   Random  Unconfirmed         High
#
#           Updated
# 0  1/2/2015 12:31
# 1  1/2/2015 14:16
# 2   1/3/2015 8:26
# 3  1/5/2015 22:18
# 4   1/6/2015 5:17

# %%
#assigning integer values to values in Reporting column
def trans_reporting(x):
    if x == 'Beginner':
        return 0
    if x == 'Intermediate':
        return 1
    if x == 'Advanced':
        return 2

# %%
#assigning integer values to values in Assignee column
def trans_assignee(x):
    if x == 'Particular':
        return 0
    if x == 'Random':
        return 1

# %%
#assigning integer values to values in Status column
def trans_status(x):
    if x == 'Unconfirmed':
        return 0
    if x == 'New':
        return 1

# %%
#assigning integer values to values in Notification column
def trans_notification(x):
    if x == 'Normal':
        return 0
    if x == 'High':
        return 1

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#applying these values to Firefox_bugs dataset
bugs['Trans_Reporting']=bugs['Reporting'].apply(trans_reporting)
bugs['Trans_Assignee']=bugs['Assignee'].apply(trans_assignee)
bugs['Trans_Status']=bugs['Status'].apply(trans_status)
bugs['Trans_Notification']=bugs['Notification'].apply(trans_notification)

# %%
#importing date-time
bugs["Updated"] = pd.to_datetime(bugs["Updated"])
bugs.head(5)
# Out:
#     Bug ID     Reporting                                            Summary  \
# 0  1116989      Beginner       Guest users should not see introduction info
# 1  1047673      Beginner  URL checksums (for "securely" linking third-pa...
# 2  1108341  Intermediate  Context menu entries use the original URI inst...
# 3  1111278  Intermediate  A strip with all(?) possible icons is showing ...
# 4   992209      Beginner  invoking firefox with command line argument(s)...
#
#    Product                   Component Assignee       Status Notification  \
# 0  Firefox  Toolbars and Customization   Random  Unconfirmed       Normal
# 1  Firefox                     General   Random  Unconfirmed       Normal
# 2  Firefox                       Menus   Random  Unconfirmed       Normal
# 3  Firefox  Toolbars and Customization   Random  Unconfirmed         High
# 4  Firefox                     General   Random  Unconfirmed         High
#
#               Updated  Trans_Reporting  Trans_Assignee  Trans_Status  \
# 0 2015-01-02 12:31:00                0               1             0
# 1 2015-01-02 14:16:00                0               1             0
# 2 2015-01-03 08:26:00                1               1             0
# 3 2015-01-05 22:18:00                1               1             0
# 4 2015-01-06 05:17:00                0               1             0
#
#    Trans_Notification
# 0                   0
# 1                   0
# 2                   0
# 3                   1
# 4                   1

# %%
#assigning index for Updated column
bugs.set_index("Updated").head(2)
# Out:
#                       Bug ID Reporting  \
# Updated
# 2015-01-02 12:31:00  1116989  Beginner
# 2015-01-02 14:16:00  1047673  Beginner
#
#                                                                Summary  \
# Updated
# 2015-01-02 12:31:00       Guest users should not see introduction info
# 2015-01-02 14:16:00  URL checksums (for "securely" linking third-pa...
#
#                      Product                   Component Assignee  \
# Updated
# 2015-01-02 12:31:00  Firefox  Toolbars and Customization   Random
# 2015-01-02 14:16:00  Firefox                     General   Random
#
#                           Status Notification  Trans_Reporting  \
# Updated
# 2015-01-02 12:31:00  Unconfirmed       Normal                0
# 2015-01-02 14:16:00  Unconfirmed       Normal                0
#
#                      Trans_Assignee  Trans_Status  Trans_Notification
# Updated
# 2015-01-02 12:31:00               1             0                   0
# 2015-01-02 14:16:00               1             0                   0

# %%
#grouping bugs in 2015 into one dataset
Firefox_bugs_2015 = bugs[bugs["Updated"].between('2015-01-02','2016-01-01')]
#grouping bugs in 2016 into one dataset
Firefox_bugs_2016 = bugs[bugs["Updated"].between('2016-01-01','2017-01-01')]
#grouping bugs in 2017 into one dataset
Firefox_bugs_2017 = bugs[bugs["Updated"].between('2017-01-01','2018-01-03')]
#grouping bugs in 2018 into one dataset
Firefox_bugs_2018 = bugs[bugs["Updated"].between('2018-01-03','2019-01-02')]
#grouping bugs in 2019 into one dataset
Firefox_bugs_2019 = bugs[bugs["Updated"].between('2019-01-02','2020-01-02')]
#grouping bugs in 2020 into one dataset
Firefox_bugs_2020 = bugs[bugs["Updated"].between('2020-01-02','2021-04-01')]
#grouping bugs in 2021 into one dataset
Firefox_bugs_2021 = bugs[bugs["Updated"].between('2021-04-01','2022-01-01')]
#grouping bugs in 2022 into one dataset
Firefox_bugs_2022 = bugs[bugs["Updated"].between('2022-01-01','2022-11-09')]

# %%
#applying these values to Firefox_bugs_2015 dataset
Firefox_bugs_2015['Trans_Reporting']=Firefox_bugs_2015['Reporting'].apply(trans_reporting)
Firefox_bugs_2015['Trans_Assignee']=Firefox_bugs_2015['Assignee'].apply(trans_assignee)
Firefox_bugs_2015['Trans_Status']=Firefox_bugs_2015['Status'].apply(trans_status)
Firefox_bugs_2015['Trans_Notification']=Firefox_bugs_2015['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2016 dataset
Firefox_bugs_2016['Trans_Reporting']=Firefox_bugs_2016['Reporting'].apply(trans_reporting)
Firefox_bugs_2016['Trans_Assignee']=Firefox_bugs_2016['Assignee'].apply(trans_assignee)
Firefox_bugs_2016['Trans_Status']=Firefox_bugs_2016['Status'].apply(trans_status)
Firefox_bugs_2016['Trans_Notification']=Firefox_bugs_2016['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2017 dataset
Firefox_bugs_2017['Trans_Reporting']=Firefox_bugs_2017['Reporting'].apply(trans_reporting)
Firefox_bugs_2017['Trans_Assignee']=Firefox_bugs_2017['Assignee'].apply(trans_assignee)
Firefox_bugs_2017['Trans_Status']=Firefox_bugs_2017['Status'].apply(trans_status)
Firefox_bugs_2017['Trans_Notification']=Firefox_bugs_2017['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2018 dataset
Firefox_bugs_2018['Trans_Reporting']=Firefox_bugs_2018['Reporting'].apply(trans_reporting)
Firefox_bugs_2018['Trans_Assignee']=Firefox_bugs_2018['Assignee'].apply(trans_assignee)
Firefox_bugs_2018['Trans_Status']=Firefox_bugs_2018['Status'].apply(trans_status)
Firefox_bugs_2018['Trans_Notification']=Firefox_bugs_2018['Notification'].apply(trans_notification)
Firefox_bugs_2018.head(5)
#applying these values to Firefox_bugs_2019 dataset
Firefox_bugs_2019['Trans_Reporting']=Firefox_bugs_2019['Reporting'].apply(trans_reporting)
Firefox_bugs_2019['Trans_Assignee']=Firefox_bugs_2019['Assignee'].apply(trans_assignee)
Firefox_bugs_2019['Trans_Status']=Firefox_bugs_2019['Status'].apply(trans_status)
Firefox_bugs_2019['Trans_Notification']=Firefox_bugs_2019['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2020 dataset
Firefox_bugs_2020['Trans_Reporting']=Firefox_bugs_2020['Reporting'].apply(trans_reporting)
Firefox_bugs_2020['Trans_Assignee']=Firefox_bugs_2020['Assignee'].apply(trans_assignee)
Firefox_bugs_2020['Trans_Status']=Firefox_bugs_2020['Status'].apply(trans_status)
Firefox_bugs_2020['Trans_Notification']=Firefox_bugs_2020['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2021 dataset
Firefox_bugs_2021['Trans_Reporting']=Firefox_bugs_2021['Reporting'].apply(trans_reporting)
Firefox_bugs_2021['Trans_Assignee']=Firefox_bugs_2021['Assignee'].apply(trans_assignee)
Firefox_bugs_2021['Trans_Status']=Firefox_bugs_2021['Status'].apply(trans_status)
Firefox_bugs_2021['Trans_Notification']=Firefox_bugs_2021['Notification'].apply(trans_notification)
#applying these values to Firefox_bugs_2022 dataset
Firefox_bugs_2022['Trans_Reporting']=Firefox_bugs_2022['Reporting'].apply(trans_reporting)
Firefox_bugs_2022['Trans_Assignee']=Firefox_bugs_2022['Assignee'].apply(trans_assignee)
Firefox_bugs_2022['Trans_Status']=Firefox_bugs_2022['Status'].apply(trans_status)
Firefox_bugs_2022['Trans_Notification']=Firefox_bugs_2022['Notification'].apply(trans_notification)

# %%
#assingning values to x1,x2,x3,x4,x5,x6,x7,x8 and y1,y2,y3,y4,y5,y6,y7,y8
X1=Firefox_bugs_2015.iloc[:,9:12].values
y1=Firefox_bugs_2015.iloc[:,12:13].values
X2=Firefox_bugs_2016.iloc[:,9:12].values
y2=Firefox_bugs_2016.iloc[:,12:13].values
X3=Firefox_bugs_2017.iloc[:,9:12].values
y3=Firefox_bugs_2017.iloc[:,12:13].values
X4=Firefox_bugs_2018.iloc[:,9:12].values
y4=Firefox_bugs_2018.iloc[:,12:13].values
X5=Firefox_bugs_2019.iloc[:,9:12].values
y5=Firefox_bugs_2019.iloc[:,12:13].values
X6=Firefox_bugs_2020.iloc[:,9:12].values
y6=Firefox_bugs_2020.iloc[:,12:13].values
X7=Firefox_bugs_2021.iloc[:,9:12].values
y7=Firefox_bugs_2021.iloc[:,12:13].values
X8=Firefox_bugs_2022.iloc[:,9:12].values
y8=Firefox_bugs_2022.iloc[:,12:13].values

# %%
#diving the dataset into training and testing data
from sklearn.model_selection import train_test_split  
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1,y1,test_size=0.2)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2,y2,test_size=0.2)
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3,y3,test_size=0.2)
X_train4, X_test4, y_train4, y_test4 = train_test_split(X4,y4,test_size=0.2)
X_train5, X_test5, y_train5, y_test5 = train_test_split(X5,y5,test_size=0.2)
X_train6, X_test6, y_train6, y_test6 = train_test_split(X6,y6,test_size=0.2)
X_train7, X_test7, y_train7, y_test7 = train_test_split(X7,y7,test_size=0.2)
X_train8, X_test8, y_train8, y_test8 = train_test_split(X8,y8,test_size=0.2)

# %%
#assingning values to x and y
X=bugs.iloc[:,9:12].values
y=bugs.iloc[:,12:13].values

# %%
#diving the dataset into 80% training and 20% testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Required imports
from sklearn.svm import SVC
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold
import numpy as np

# SVM Classifier definition
class SVMClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, kernel="rbf", C=1.0):
        self.model = SVC(kernel=kernel, C=C, probability=True)
        self.kernel = kernel
        self.C = C

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Main section
if __name__ == "__main__":
    # Dummy data for demonstration
    X = np.random.rand(100, 10)  # 100 samples, 10 features
    y = np.random.randint(0, 2, 100)  # Binary labels (0 or 1) for 100 samples

    # Variables for cross-validation
    n_iterations = 100  # Number of iterations
    k_folds = 10  # Number of folds

    # Initialize SVM classifier
    svm_classifier = SVMClassifier()

    # Initialize a list to store cross-validation scores for SVM
    svm_cv_scores = []

    # Perform cross-validation for multiple iterations
    for _ in range(n_iterations):
        # Perform cross-validation and calculate scores for SVM
        kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
        scores = cross_val_score(svm_classifier, X, y, cv=kf)
        
        # Append the scores to the list for SVM
        svm_cv_scores.append(scores)

    # Convert the list of scores for SVM to a NumPy array for analysis
    svm_cv_scores = np.array(svm_cv_scores)

    # Print the cross-validation scores for each iteration and fold for SVM
    for i, scores in enumerate(svm_cv_scores):
        print(f"Iteration {i + 1}:")
        for j, score in enumerate(scores):
            print(f"Fold {j + 1}: {score:.4f}")
        print("")

    # Calculate and print the mean and standard deviation of the scores for SVM
    svm_mean_scores = np.mean(svm_cv_scores, axis=1)
    svm_std_scores = np.std(svm_cv_scores, axis=1)
    print("Mean Scores for SVM:", svm_mean_scores)
    print("Standard Deviations for SVM:", svm_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.9000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 2:
# Fold 1: 0.4000
# Fold 2: 0.8000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 3:
# Fold 1: 0.6000
# Fold 2: 0.8000
# Fold 3: 0.4000
# Fold 4: 0.8000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.2000
# Fold 9: 0.8000
# Fold 10: 0.5000
#
# Iteration 4:
# Fold 1: 0.8000
# Fold 2: 0.2000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.3000
# Fold 6: 0.8000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 5:
# Fold 1: 0.6000
# Fold 2: 0.8000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.1000
# Fold 10: 0.6000
#
# Iteration 6:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.8000
# Fold 4: 0.9000
# Fold 5: 0.2000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 7:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 8:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.2000
# Fold 4: 0.7000
# Fold 5: 0.9000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 9:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.1000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 10:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.2000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 11:
# Fold 1: 0.6000
# Fold 2: 0.8000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 12:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.3000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.8000
#
# Iteration 13:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.8000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 14:
# Fold 1: 0.8000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.2000
# Fold 9: 0.7000
# Fold 10: 0.7000
#
# Iteration 15:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.8000
# Fold 5: 0.8000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.8000
#
# Iteration 16:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.2000
# Fold 5: 0.2000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.8000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 17:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 18:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 19:
# Fold 1: 0.3000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 20:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.8000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 21:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 22:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 23:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.8000
# Fold 4: 0.2000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.8000
#
# Iteration 24:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 25:
# Fold 1: 0.7000
# Fold 2: 0.6000
# Fold 3: 0.1000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 26:
# Fold 1: 0.8000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.3000
#
# Iteration 27:
# Fold 1: 0.7000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.2000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 28:
# Fold 1: 0.8000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 29:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.8000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 30:
# Fold 1: 0.5000
# Fold 2: 0.8000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.2000
# Fold 9: 0.8000
# Fold 10: 0.3000
#
# Iteration 31:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.3000
# Fold 10: 0.8000
#
# Iteration 32:
# Fold 1: 0.2000
# Fold 2: 0.3000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 33:
# Fold 1: 0.7000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.2000
#
# Iteration 34:
# Fold 1: 0.8000
# Fold 2: 0.3000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 35:
# Fold 1: 0.7000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 36:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 37:
# Fold 1: 0.3000
# Fold 2: 0.7000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 38:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 39:
# Fold 1: 0.2000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.9000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 40:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.8000
# Fold 4: 0.3000
# Fold 5: 0.8000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.3000
# Fold 10: 0.6000
#
# Iteration 41:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.3000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 42:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.8000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 43:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.8000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 44:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.3000
# Fold 7: 0.7000
# Fold 8: 0.7000
# Fold 9: 0.8000
# Fold 10: 0.4000
#
# Iteration 45:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 46:
# Fold 1: 0.8000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 47:
# Fold 1: 0.4000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 48:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.8000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 49:
# Fold 1: 0.4000
# Fold 2: 0.7000
# Fold 3: 0.7000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 50:
# Fold 1: 0.6000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.9000
# Fold 9: 0.7000
# Fold 10: 0.3000
#
# Iteration 51:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.8000
# Fold 10: 0.6000
#
# Iteration 52:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 53:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 54:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 55:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 56:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 57:
# Fold 1: 0.6000
# Fold 2: 0.3000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 58:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 59:
# Fold 1: 0.8000
# Fold 2: 0.7000
# Fold 3: 0.3000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 60:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.8000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 61:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.7000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 62:
# Fold 1: 0.4000
# Fold 2: 0.2000
# Fold 3: 0.6000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 63:
# Fold 1: 0.3000
# Fold 2: 0.6000
# Fold 3: 0.7000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 64:
# Fold 1: 0.6000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.2000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.7000
#
# Iteration 65:
# Fold 1: 0.6000
# Fold 2: 0.8000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 66:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.8000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 67:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 68:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.8000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 69:
# Fold 1: 0.9000
# Fold 2: 0.6000
# Fold 3: 0.2000
# Fold 4: 0.9000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 70:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.3000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 71:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.7000
# Fold 8: 0.8000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 72:
# Fold 1: 0.4000
# Fold 2: 0.9000
# Fold 3: 0.3000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 73:
# Fold 1: 0.7000
# Fold 2: 0.9000
# Fold 3: 0.2000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.8000
# Fold 10: 0.7000
#
# Iteration 74:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 75:
# Fold 1: 0.4000
# Fold 2: 0.7000
# Fold 3: 0.7000
# Fold 4: 0.8000
# Fold 5: 0.8000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 76:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.8000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.8000
#
# Iteration 77:
# Fold 1: 0.5000
# Fold 2: 0.8000
# Fold 3: 0.6000
# Fold 4: 0.3000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 78:
# Fold 1: 0.5000
# Fold 2: 0.8000
# Fold 3: 0.5000
# Fold 4: 0.8000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 79:
# Fold 1: 0.4000
# Fold 2: 0.7000
# Fold 3: 0.3000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.8000
# Fold 7: 0.7000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 80:
# Fold 1: 0.6000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 81:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 82:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.2000
# Fold 8: 0.9000
# Fold 9: 0.8000
# Fold 10: 0.5000
#
# Iteration 83:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.8000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 84:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.7000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 85:
# Fold 1: 0.8000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.7000
#
# Iteration 86:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.9000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 87:
# Fold 1: 0.3000
# Fold 2: 0.6000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.8000
# Fold 10: 0.6000
#
# Iteration 88:
# Fold 1: 0.6000
# Fold 2: 0.2000
# Fold 3: 0.8000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 89:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 90:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.8000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 91:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.1000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 92:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.8000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.7000
# Fold 9: 0.1000
# Fold 10: 0.5000
#
# Iteration 93:
# Fold 1: 0.7000
# Fold 2: 0.3000
# Fold 3: 0.3000
# Fold 4: 0.6000
# Fold 5: 0.8000
# Fold 6: 0.3000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 94:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.3000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 95:
# Fold 1: 0.5000
# Fold 2: 0.3000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.9000
# Fold 6: 0.2000
# Fold 7: 0.7000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 96:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.8000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 97:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.9000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 98:
# Fold 1: 0.3000
# Fold 2: 0.6000
# Fold 3: 0.3000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.8000
# Fold 9: 0.8000
# Fold 10: 0.5000
#
# Iteration 99:
# Fold 1: 0.8000
# Fold 2: 0.7000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.2000
# Fold 10: 0.5000
#
# Iteration 100:
# Fold 1: 0.7000
# Fold 2: 0.8000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Mean Scores for SVM: [0.55 0.58 0.58 0.54 0.54 0.56 0.56 0.53 0.51 0.55 0.51 0.56 0.51 0.6
#  0.63 0.53 0.57 0.56 0.57 0.57 0.56 0.52 0.56 0.54 0.54 0.57 0.55 0.57
#  0.57 0.56 0.54 0.51 0.57 0.55 0.58 0.57 0.55 0.59 0.53 0.55 0.53 0.58
#  0.55 0.56 0.56 0.55 0.53 0.53 0.56 0.54 0.56 0.51 0.54 0.52 0.56 0.57
#  0.52 0.56 0.56 0.52 0.57 0.53 0.56 0.56 0.53 0.56 0.56 0.53 0.6  0.54
#  0.57 0.56 0.56 0.57 0.63 0.58 0.53 0.57 0.57 0.54 0.56 0.56 0.54 0.59
#  0.55 0.6  0.59 0.54 0.51 0.51 0.53 0.53 0.54 0.53 0.56 0.55 0.57 0.54
#  0.58 0.56]
# Standard Deviations for SVM: [0.15       0.12489996 0.18330303 0.2059126  0.19078784 0.18547237
#  0.08       0.19       0.16401219 0.16278821 0.14456832 0.1356466
#  0.12206556 0.17320508 0.16155494 0.19519221 0.09       0.12
#  0.13453624 0.14866069 0.09165151 0.09797959 0.19078784 0.10198039
#  0.17435596 0.14177447 0.16278821 0.14177447 0.11874342 0.18547237
#  0.12806248 0.14456832 0.13453624 0.15       0.09797959 0.12688578
#  0.15       0.08306624 0.17349352 0.17464249 0.11874342 0.1077033
#  0.13601471 0.1496663  0.08       0.12041595 0.10049876 0.13453624
#  0.14282857 0.18547237 0.1356466  0.11357817 0.12       0.07483315
#  0.11135529 0.09       0.14       0.10198039 0.1356466  0.14
#  0.11874342 0.16155494 0.1496663  0.16248077 0.14177447 0.12
#  0.11135529 0.12688578 0.21447611 0.1356466  0.14177447 0.168523
#  0.20099751 0.11874342 0.14177447 0.14696938 0.13453624 0.13453624
#  0.15524175 0.14282857 0.09165151 0.21071308 0.15620499 0.10440307
#  0.13601471 0.14142136 0.13       0.18547237 0.12206556 0.14456832
#  0.18466185 0.18466185 0.18       0.13453624 0.19078784 0.12845233
#  0.17916473 0.18547237 0.16613248 0.12      ]

# %%
# Calculate and print the mean and standard deviation of the scores
svm_mean_scores_1 = np.mean(svm_cv_scores)
svm_std_scores_1 = np.std(svm_cv_scores)
print("Mean Scores:", svm_mean_scores_1)
print("Standard Deviations:", svm_std_scores_1)
# Out:
# Mean Scores: 0.5535999999999999
# Standard Deviations: 0.14834769967882885

# %%
# Required imports
from sklearn.svm import SVC
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold
import numpy as np

# SVM Classifier definition
class SVMClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, kernel="rbf", C=1.0):
        self.model = SVC(kernel=kernel, C=C, probability=True)
        self.kernel = kernel
        self.C = C

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Main section
if __name__ == "__main__":
    # Dummy data for demonstration
    X = np.random.rand(100, 10)  # 100 samples, 10 features
    y = np.random.randint(0, 2, 100)  # Binary labels (0 or 1) for 100 samples

    # Variables for cross-validation
    n_iterations = 100  # Number of iterations
    k_folds = 10  # Number of folds

    # Initialize SVM classifier
    svm_classifier = SVMClassifier()

    # Initialize a list to store cross-validation scores for SVM
    svm_cv_scores = []

    # Perform cross-validation for multiple iterations
    for _ in range(n_iterations):
        # Perform cross-validation and calculate scores for SVM
        kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
        scores = cross_val_score(svm_classifier, X, y, cv=kf)
        
        # Append the scores to the list for SVM
        svm_cv_scores.append(scores)

    # Convert the list of scores for SVM to a NumPy array for analysis
    svm_cv_scores = np.array(svm_cv_scores)

    # Print the cross-validation scores for each iteration and fold for SVM
    for i, scores in enumerate(svm_cv_scores):
        print(f"Iteration {i + 1}:")
        for j, score in enumerate(scores):
            print(f"Fold {j + 1}: {score:.4f}")
        print("")

    # Calculate and print the mean and standard deviation of the scores for SVM
    svm_mean_scores = np.mean(svm_cv_scores, axis=1)
    svm_std_scores = np.std(svm_cv_scores, axis=1)
    print("Mean Scores for SVM:", svm_mean_scores)
    print("Standard Deviations for SVM:", svm_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.3000
# Fold 4: 0.8000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.9000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 2:
# Fold 1: 0.4000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.8000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 3:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.9000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 4:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 5:
# Fold 1: 0.2000
# Fold 2: 0.4000
# Fold 3: 0.9000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.3000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 6:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.8000
#
# Iteration 7:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 8:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 9:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.8000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.8000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 10:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 11:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.8000
#
# Iteration 12:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 13:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.8000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 14:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 15:
# Fold 1: 0.8000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 16:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 17:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 18:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.8000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 19:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 20:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 21:
# Fold 1: 0.8000
# Fold 2: 0.5000
# Fold 3: 0.8000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 22:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.3000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.8000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 23:
# Fold 1: 0.5000
# Fold 2: 0.8000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.8000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 24:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.3000
# Fold 10: 0.7000
#
# Iteration 25:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.2000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.8000
#
# Iteration 26:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.8000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 27:
# Fold 1: 0.6000
# Fold 2: 0.9000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 28:
# Fold 1: 0.3000
# Fold 2: 0.9000
# Fold 3: 0.8000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 29:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.3000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 30:
# Fold 1: 0.7000
# Fold 2: 0.2000
# Fold 3: 0.3000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.6000
#
# Iteration 31:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.8000
# Fold 5: 0.5000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 32:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.8000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 33:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.2000
# Fold 4: 0.2000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 34:
# Fold 1: 0.5000
# Fold 2: 0.8000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.8000
# Fold 9: 0.2000
# Fold 10: 0.5000
#
# Iteration 35:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.8000
#
# Iteration 36:
# Fold 1: 0.7000
# Fold 2: 0.8000
# Fold 3: 0.6000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 37:
# Fold 1: 0.6000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.7000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 38:
# Fold 1: 0.7000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 39:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.3000
#
# Iteration 40:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.8000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.3000
# Fold 10: 0.8000
#
# Iteration 41:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.2000
#
# Iteration 42:
# Fold 1: 0.7000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.8000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 43:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.3000
#
# Iteration 44:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 45:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 1.0000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.2000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 46:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 47:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 48:
# Fold 1: 0.7000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.1000
# Fold 6: 0.8000
# Fold 7: 0.8000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.8000
#
# Iteration 49:
# Fold 1: 0.8000
# Fold 2: 0.7000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.8000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 50:
# Fold 1: 0.5000
# Fold 2: 0.8000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 51:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 52:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.8000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.8000
#
# Iteration 53:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.8000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.3000
# Fold 7: 0.7000
# Fold 8: 0.1000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 54:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.9000
# Fold 6: 0.3000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 55:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.3000
# Fold 5: 0.4000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.8000
# Fold 10: 0.6000
#
# Iteration 56:
# Fold 1: 0.7000
# Fold 2: 0.6000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 57:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.7000
#
# Iteration 58:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.9000
# Fold 10: 0.5000
#
# Iteration 59:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.8000
#
# Iteration 60:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 61:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.8000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 62:
# Fold 1: 0.7000
# Fold 2: 0.8000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 63:
# Fold 1: 0.8000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.8000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.8000
# Fold 10: 0.5000
#
# Iteration 64:
# Fold 1: 0.4000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.8000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 65:
# Fold 1: 0.7000
# Fold 2: 0.6000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.8000
#
# Iteration 66:
# Fold 1: 0.8000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.3000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 67:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 68:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.9000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 69:
# Fold 1: 0.8000
# Fold 2: 0.6000
# Fold 3: 0.3000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.8000
# Fold 10: 0.5000
#
# Iteration 70:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.8000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 71:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.2000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 72:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.8000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.8000
# Fold 10: 0.6000
#
# Iteration 73:
# Fold 1: 0.7000
# Fold 2: 0.7000
# Fold 3: 0.4000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 74:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.8000
# Fold 4: 0.3000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 75:
# Fold 1: 0.9000
# Fold 2: 0.7000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.2000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 76:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 77:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.8000
# Fold 7: 0.3000
# Fold 8: 0.9000
# Fold 9: 0.2000
# Fold 10: 0.4000
#
# Iteration 78:
# Fold 1: 0.4000
# Fold 2: 0.7000
# Fold 3: 0.2000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.8000
#
# Iteration 79:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.2000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.7000
#
# Iteration 80:
# Fold 1: 0.6000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.8000
#
# Iteration 81:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 82:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.9000
# Fold 10: 0.5000
#
# Iteration 83:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 84:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.8000
# Fold 4: 0.4000
# Fold 5: 0.2000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 85:
# Fold 1: 0.3000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.8000
# Fold 10: 0.6000
#
# Iteration 86:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.9000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.8000
#
# Iteration 87:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.3000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.8000
# Fold 8: 0.3000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 88:
# Fold 1: 0.8000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.6000
# Fold 7: 0.9000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 89:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.8000
# Fold 10: 0.5000
#
# Iteration 90:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.2000
# Fold 10: 0.6000
#
# Iteration 91:
# Fold 1: 0.4000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.2000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.2000
# Fold 8: 0.6000
# Fold 9: 0.8000
# Fold 10: 0.4000
#
# Iteration 92:
# Fold 1: 0.3000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 93:
# Fold 1: 0.5000
# Fold 2: 0.8000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.6000
#
# Iteration 94:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 95:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 96:
# Fold 1: 1.0000
# Fold 2: 0.6000
# Fold 3: 0.8000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 97:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.3000
#
# Iteration 98:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.8000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 99:
# Fold 1: 0.3000
# Fold 2: 0.3000
# Fold 3: 0.6000
# Fold 4: 0.8000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.3000
# Fold 10: 0.7000
#
# Iteration 100:
# Fold 1: 0.3000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Mean Scores for SVM: [0.57 0.55 0.51 0.55 0.53 0.54 0.55 0.5  0.56 0.53 0.54 0.55 0.56 0.5
#  0.53 0.5  0.51 0.55 0.55 0.52 0.5  0.56 0.56 0.56 0.56 0.53 0.56 0.56
#  0.55 0.51 0.55 0.52 0.53 0.56 0.55 0.58 0.58 0.54 0.54 0.53 0.55 0.54
#  0.57 0.59 0.55 0.58 0.59 0.54 0.62 0.53 0.53 0.58 0.54 0.56 0.56 0.55
#  0.56 0.56 0.54 0.54 0.51 0.53 0.57 0.57 0.55 0.57 0.48 0.59 0.53 0.52
#  0.5  0.58 0.52 0.57 0.55 0.56 0.56 0.53 0.55 0.58 0.57 0.53 0.52 0.51
#  0.55 0.58 0.52 0.54 0.57 0.55 0.51 0.52 0.54 0.55 0.56 0.57 0.49 0.54
#  0.51 0.57]
# Standard Deviations for SVM: [0.18466185 0.14317821 0.15779734 0.13601471 0.19519221 0.1356466
#  0.10246951 0.1        0.168523   0.0781025  0.10198039 0.08062258
#  0.11135529 0.1183216  0.13453624 0.1183216  0.10440307 0.12041595
#  0.09219544 0.12489996 0.16733201 0.14282857 0.1356466  0.12806248
#  0.16248077 0.13453624 0.18       0.17435596 0.12845233 0.18138357
#  0.12845233 0.13266499 0.17916473 0.17435596 0.13601471 0.14
#  0.08717798 0.12       0.1356466  0.18466185 0.15       0.16248077
#  0.13453624 0.10440307 0.19621417 0.11661904 0.10440307 0.22891046
#  0.12489996 0.12688578 0.11       0.14       0.19595918 0.1496663
#  0.16248077 0.15       0.1356466  0.14282857 0.12806248 0.08
#  0.14456832 0.15524175 0.16763055 0.11874342 0.15       0.15524175
#  0.08717798 0.13747727 0.17916473 0.13266499 0.14142136 0.15362291
#  0.13266499 0.12688578 0.19104973 0.08       0.21071308 0.17916473
#  0.17464249 0.1077033  0.09       0.14177447 0.16613248 0.17
#  0.15652476 0.16       0.16613248 0.18       0.11       0.15
#  0.19723083 0.1077033  0.1496663  0.1118034  0.09165151 0.19
#  0.14456832 0.12806248 0.19209373 0.10049876]

# %%
# Calculate and print the mean and standard deviation of the scores
svm_mean_scores_2 = np.mean(svm_cv_scores)
svm_std_scores_2 = np.std(svm_cv_scores)
print("Mean Scores:", svm_mean_scores_2)
print("Standard Deviations:", svm_std_scores_2)
# Out:
# Mean Scores: 0.5453
# Standard Deviations: 0.1472342011898051

# %%
# Required imports
from sklearn.svm import SVC
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold
import numpy as np

# SVM Classifier definition
class SVMClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, kernel="rbf", C=1.0):
        self.model = SVC(kernel=kernel, C=C, probability=True)
        self.kernel = kernel
        self.C = C

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Main section
if __name__ == "__main__":
    # Dummy data for demonstration
    X = np.random.rand(100, 10)  # 100 samples, 10 features
    y = np.random.randint(0, 2, 100)  # Binary labels (0 or 1) for 100 samples

    # Variables for cross-validation
    n_iterations = 100  # Number of iterations
    k_folds = 10  # Number of folds

    # Initialize SVM classifier
    svm_classifier = SVMClassifier()

    # Initialize a list to store cross-validation scores for SVM
    svm_cv_scores = []

    # Perform cross-validation for multiple iterations
    for _ in range(n_iterations):
        # Perform cross-validation and calculate scores for SVM
        kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
        scores = cross_val_score(svm_classifier, X, y, cv=kf)
        
        # Append the scores to the list for SVM
        svm_cv_scores.append(scores)

    # Convert the list of scores for SVM to a NumPy array for analysis
    svm_cv_scores = np.array(svm_cv_scores)

    # Print the cross-validation scores for each iteration and fold for SVM
    for i, scores in enumerate(svm_cv_scores):
        print(f"Iteration {i + 1}:")
        for j, score in enumerate(scores):
            print(f"Fold {j + 1}: {score:.4f}")
        print("")

    # Calculate and print the mean and standard deviation of the scores for SVM
    svm_mean_scores = np.mean(svm_cv_scores, axis=1)
    svm_std_scores = np.std(svm_cv_scores, axis=1)
    print("Mean Scores for SVM:", svm_mean_scores)
    print("Standard Deviations for SVM:", svm_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.1000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 2:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 3:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.2000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 4:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.2000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 5:
# Fold 1: 0.4000
# Fold 2: 0.2000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.2000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 6:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.2000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.2000
# Fold 10: 0.3000
#
# Iteration 7:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.3000
# Fold 10: 0.4000
#
# Iteration 8:
# Fold 1: 0.5000
# Fold 2: 0.3000
# Fold 3: 0.7000
# Fold 4: 0.3000
# Fold 5: 0.3000
# Fold 6: 0.2000
# Fold 7: 0.3000
# Fold 8: 0.4000
# Fold 9: 0.2000
# Fold 10: 0.6000
#
# Iteration 9:
# Fold 1: 0.2000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 10:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.3000
# Fold 4: 0.2000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 11:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.3000
#
# Iteration 12:
# Fold 1: 0.1000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.7000
# Fold 7: 0.3000
# Fold 8: 0.8000
# Fold 9: 0.4000
# Fold 10: 0.3000
#
# Iteration 13:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.1000
#
# Iteration 14:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.1000
#
# Iteration 15:
# Fold 1: 0.5000
# Fold 2: 0.3000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.2000
# Fold 9: 0.3000
# Fold 10: 0.4000
#
# Iteration 16:
# Fold 1: 0.8000
# Fold 2: 0.2000
# Fold 3: 0.3000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.0000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 17:
# Fold 1: 0.2000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.1000
# Fold 8: 0.4000
# Fold 9: 0.3000
# Fold 10: 0.7000
#
# Iteration 18:
# Fold 1: 0.0000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.2000
# Fold 10: 0.2000
#
# Iteration 19:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.1000
# Fold 4: 0.8000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.2000
#
# Iteration 20:
# Fold 1: 0.8000
# Fold 2: 0.6000
# Fold 3: 0.7000
# Fold 4: 0.1000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.1000
# Fold 8: 0.1000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 21:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.1000
# Fold 10: 0.3000
#
# Iteration 22:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.2000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.2000
#
# Iteration 23:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.3000
# Fold 10: 0.5000
#
# Iteration 24:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.2000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 25:
# Fold 1: 0.3000
# Fold 2: 0.2000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.3000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.5000
#
# Iteration 26:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.2000
# Fold 4: 0.9000
# Fold 5: 0.5000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.2000
#
# Iteration 27:
# Fold 1: 0.3000
# Fold 2: 0.2000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 28:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.2000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.2000
# Fold 9: 0.2000
# Fold 10: 0.3000
#
# Iteration 29:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.2000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 30:
# Fold 1: 0.2000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 31:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.7000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 32:
# Fold 1: 0.2000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 33:
# Fold 1: 0.3000
# Fold 2: 0.2000
# Fold 3: 0.4000
# Fold 4: 0.2000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.3000
# Fold 8: 0.4000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 34:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.2000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.1000
# Fold 10: 0.3000
#
# Iteration 35:
# Fold 1: 0.5000
# Fold 2: 0.3000
# Fold 3: 0.1000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 36:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.2000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 37:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 38:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.2000
# Fold 7: 0.2000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 39:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.3000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.1000
# Fold 10: 0.5000
#
# Iteration 40:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.2000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.2000
#
# Iteration 41:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.2000
# Fold 4: 0.6000
# Fold 5: 0.2000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.2000
# Fold 9: 0.6000
# Fold 10: 0.8000
#
# Iteration 42:
# Fold 1: 0.7000
# Fold 2: 0.3000
# Fold 3: 0.2000
# Fold 4: 0.6000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.2000
# Fold 10: 0.4000
#
# Iteration 43:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.2000
# Fold 5: 0.5000
# Fold 6: 0.1000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 44:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.2000
# Fold 5: 0.2000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.2000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 45:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.2000
#
# Iteration 46:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 47:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 48:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.1000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.1000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 49:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.7000
# Fold 10: 0.2000
#
# Iteration 50:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.1000
# Fold 4: 0.3000
# Fold 5: 0.1000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 51:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.3000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.3000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 52:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.3000
# Fold 6: 0.1000
# Fold 7: 0.7000
# Fold 8: 0.2000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 53:
# Fold 1: 0.8000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.3000
# Fold 5: 0.3000
# Fold 6: 0.2000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 54:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.2000
# Fold 10: 0.4000
#
# Iteration 55:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.2000
# Fold 10: 0.5000
#
# Iteration 56:
# Fold 1: 0.5000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.4000
# Fold 10: 0.9000
#
# Iteration 57:
# Fold 1: 0.4000
# Fold 2: 0.8000
# Fold 3: 0.2000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 58:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.3000
# Fold 7: 0.3000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 59:
# Fold 1: 0.2000
# Fold 2: 0.6000
# Fold 3: 0.8000
# Fold 4: 0.6000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.4000
# Fold 8: 0.2000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 60:
# Fold 1: 0.3000
# Fold 2: 0.3000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.8000
# Fold 9: 0.2000
# Fold 10: 0.4000
#
# Iteration 61:
# Fold 1: 0.6000
# Fold 2: 0.2000
# Fold 3: 0.7000
# Fold 4: 0.3000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.3000
#
# Iteration 62:
# Fold 1: 0.6000
# Fold 2: 0.7000
# Fold 3: 0.3000
# Fold 4: 0.2000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 63:
# Fold 1: 0.6000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.2000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 64:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.2000
# Fold 5: 0.4000
# Fold 6: 0.2000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 65:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.3000
#
# Iteration 66:
# Fold 1: 0.4000
# Fold 2: 0.8000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.3000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 67:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.2000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 68:
# Fold 1: 0.2000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.2000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 69:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.2000
# Fold 4: 0.8000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.2000
#
# Iteration 70:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.2000
# Fold 4: 0.7000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 71:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 72:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.1000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.2000
# Fold 10: 0.5000
#
# Iteration 73:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.2000
# Fold 5: 0.6000
# Fold 6: 0.3000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 74:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.6000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 75:
# Fold 1: 0.2000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.2000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 76:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.2000
# Fold 6: 0.0000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.2000
# Fold 10: 0.3000
#
# Iteration 77:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.2000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 78:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.3000
# Fold 4: 0.3000
# Fold 5: 0.3000
# Fold 6: 0.1000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 79:
# Fold 1: 0.3000
# Fold 2: 0.3000
# Fold 3: 0.3000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.3000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 80:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.1000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.2000
#
# Iteration 81:
# Fold 1: 0.5000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.1000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 82:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.3000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.1000
# Fold 10: 0.3000
#
# Iteration 83:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 84:
# Fold 1: 0.6000
# Fold 2: 0.3000
# Fold 3: 0.1000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 85:
# Fold 1: 0.3000
# Fold 2: 0.7000
# Fold 3: 0.3000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.2000
# Fold 10: 0.6000
#
# Iteration 86:
# Fold 1: 0.7000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.2000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 87:
# Fold 1: 0.4000
# Fold 2: 0.1000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.2000
# Fold 6: 0.3000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 88:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 89:
# Fold 1: 0.6000
# Fold 2: 0.2000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.2000
# Fold 10: 0.2000
#
# Iteration 90:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.2000
#
# Iteration 91:
# Fold 1: 0.5000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.2000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.3000
#
# Iteration 92:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.2000
# Fold 7: 0.6000
# Fold 8: 0.2000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 93:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.2000
# Fold 7: 0.1000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 94:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.2000
# Fold 7: 0.3000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.3000
#
# Iteration 95:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 96:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.8000
# Fold 4: 0.5000
# Fold 5: 0.1000
# Fold 6: 0.8000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 97:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.2000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.3000
#
# Iteration 98:
# Fold 1: 0.7000
# Fold 2: 0.1000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.8000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 99:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.3000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.3000
#
# Iteration 100:
# Fold 1: 0.3000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.2000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Mean Scores for SVM: [0.4  0.48 0.43 0.42 0.42 0.39 0.38 0.38 0.47 0.39 0.38 0.4  0.4  0.38
#  0.43 0.44 0.45 0.33 0.46 0.39 0.45 0.39 0.4  0.51 0.41 0.47 0.4  0.38
#  0.42 0.36 0.39 0.44 0.43 0.41 0.38 0.41 0.51 0.43 0.36 0.4  0.41 0.4
#  0.42 0.41 0.39 0.41 0.4  0.36 0.46 0.41 0.42 0.42 0.47 0.42 0.44 0.46
#  0.43 0.47 0.43 0.43 0.44 0.44 0.45 0.4  0.46 0.45 0.43 0.38 0.46 0.44
#  0.47 0.42 0.39 0.41 0.38 0.38 0.43 0.39 0.4  0.43 0.4  0.38 0.42 0.45
#  0.45 0.38 0.36 0.47 0.38 0.44 0.39 0.42 0.43 0.38 0.39 0.46 0.41 0.45
#  0.43 0.41]
# Standard Deviations for SVM: [0.1183216  0.09797959 0.12688578 0.12489996 0.14       0.13
#  0.08717798 0.16       0.12688578 0.11357817 0.1077033  0.19493589
#  0.14142136 0.13266499 0.15524175 0.23323808 0.19104973 0.16763055
#  0.20099751 0.23853721 0.18574176 0.10440307 0.1        0.15779734
#  0.11357817 0.20518285 0.14142136 0.15362291 0.1077033  0.10198039
#  0.12206556 0.1356466  0.19       0.17578396 0.11661904 0.11357817
#  0.13       0.16155494 0.12       0.13416408 0.19209373 0.15491933
#  0.16613248 0.15132746 0.10440307 0.07       0.1        0.1496663
#  0.1496663  0.19209373 0.12489996 0.17204651 0.18466185 0.1077033
#  0.12       0.168523   0.14866069 0.11874342 0.19519221 0.17916473
#  0.168523   0.168523   0.13601471 0.14142136 0.14282857 0.14317821
#  0.12688578 0.14       0.18       0.15620499 0.11       0.16613248
#  0.12206556 0.10440307 0.11661904 0.18867962 0.13453624 0.17578396
#  0.1        0.19519221 0.14142136 0.13266499 0.11661904 0.15
#  0.16278821 0.12489996 0.1356466  0.11874342 0.16       0.14282857
#  0.10440307 0.14       0.16763055 0.09797959 0.12206556 0.22449944
#  0.13747727 0.19621417 0.12688578 0.13747727]

# %%
# Calculate and print the mean and standard deviation of the scores
svm_mean_scores_3 = np.mean(svm_cv_scores)
svm_std_scores_3 = np.std(svm_cv_scores)
print("Mean Scores:", svm_mean_scores_3)
print("Standard Deviations:", svm_std_scores_3)
# Out:
# Mean Scores: 0.4178
# Standard Deviations: 0.15219448084605433

# %%
# Required imports
from sklearn.svm import SVC
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold
import numpy as np

# SVM Classifier definition
class SVMClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, kernel="rbf", C=1.0):
        self.model = SVC(kernel=kernel, C=C, probability=True)
        self.kernel = kernel
        self.C = C

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Main section
if __name__ == "__main__":
    # Dummy data for demonstration
    X = np.random.rand(100, 10)  # 100 samples, 10 features
    y = np.random.randint(0, 2, 100)  # Binary labels (0 or 1) for 100 samples

    # Variables for cross-validation
    n_iterations = 100  # Number of iterations
    k_folds = 10  # Number of folds

    # Initialize SVM classifier
    svm_classifier = SVMClassifier()

    # Initialize a list to store cross-validation scores for SVM
    svm_cv_scores = []

    # Perform cross-validation for multiple iterations
    for _ in range(n_iterations):
        # Perform cross-validation and calculate scores for SVM
        kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
        scores = cross_val_score(svm_classifier, X, y, cv=kf)
        
        # Append the scores to the list for SVM
        svm_cv_scores.append(scores)

    # Convert the list of scores for SVM to a NumPy array for analysis
    svm_cv_scores = np.array(svm_cv_scores)

    # Print the cross-validation scores for each iteration and fold for SVM
    for i, scores in enumerate(svm_cv_scores):
        print(f"Iteration {i + 1}:")
        for j, score in enumerate(scores):
            print(f"Fold {j + 1}: {score:.4f}")
        print("")

    # Calculate and print the mean and standard deviation of the scores for SVM
    svm_mean_scores = np.mean(svm_cv_scores, axis=1)
    svm_std_scores = np.std(svm_cv_scores, axis=1)
    print("Mean Scores for SVM:", svm_mean_scores)
    print("Standard Deviations for SVM:", svm_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.3000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.7000
#
# Iteration 2:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.2000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 3:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.8000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 4:
# Fold 1: 0.7000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 5:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 6:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 7:
# Fold 1: 0.3000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 8:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.8000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 9:
# Fold 1: 0.8000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.2000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.2000
# Fold 9: 0.3000
# Fold 10: 0.8000
#
# Iteration 10:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.3000
# Fold 10: 0.5000
#
# Iteration 11:
# Fold 1: 0.5000
# Fold 2: 0.2000
# Fold 3: 0.6000
# Fold 4: 0.8000
# Fold 5: 0.6000
# Fold 6: 0.8000
# Fold 7: 0.2000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.4000
#
# Iteration 12:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.1000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 13:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.3000
# Fold 10: 0.3000
#
# Iteration 14:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.2000
# Fold 10: 0.7000
#
# Iteration 15:
# Fold 1: 0.5000
# Fold 2: 0.2000
# Fold 3: 0.7000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.2000
# Fold 10: 0.6000
#
# Iteration 16:
# Fold 1: 0.6000
# Fold 2: 0.3000
# Fold 3: 0.3000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 17:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 18:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.3000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 19:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.2000
# Fold 10: 0.7000
#
# Iteration 20:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 21:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.2000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 22:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.2000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.3000
# Fold 10: 0.4000
#
# Iteration 23:
# Fold 1: 0.5000
# Fold 2: 0.2000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 24:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.3000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 25:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.8000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.4000
# Fold 10: 0.3000
#
# Iteration 26:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.2000
#
# Iteration 27:
# Fold 1: 0.5000
# Fold 2: 0.3000
# Fold 3: 0.3000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.2000
#
# Iteration 28:
# Fold 1: 0.5000
# Fold 2: 0.8000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 29:
# Fold 1: 0.4000
# Fold 2: 0.1000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 30:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.2000
#
# Iteration 31:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.3000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 32:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.8000
# Fold 6: 0.4000
# Fold 7: 0.2000
# Fold 8: 0.2000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 33:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.2000
# Fold 5: 0.2000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 34:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 35:
# Fold 1: 0.3000
# Fold 2: 0.3000
# Fold 3: 0.8000
# Fold 4: 0.1000
# Fold 5: 0.6000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 36:
# Fold 1: 0.6000
# Fold 2: 0.3000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.1000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 37:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.3000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.3000
# Fold 10: 0.6000
#
# Iteration 38:
# Fold 1: 0.5000
# Fold 2: 0.8000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 39:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 40:
# Fold 1: 0.5000
# Fold 2: 0.2000
# Fold 3: 0.2000
# Fold 4: 0.2000
# Fold 5: 0.9000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 41:
# Fold 1: 0.3000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 42:
# Fold 1: 0.3000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.8000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 43:
# Fold 1: 0.2000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.1000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 44:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.8000
# Fold 8: 0.3000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 45:
# Fold 1: 0.8000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.1000
#
# Iteration 46:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 47:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 48:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.5000
#
# Iteration 49:
# Fold 1: 0.2000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 50:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 51:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.2000
# Fold 10: 0.7000
#
# Iteration 52:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.8000
#
# Iteration 53:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.8000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 54:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.3000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.3000
#
# Iteration 55:
# Fold 1: 0.6000
# Fold 2: 0.1000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 56:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 57:
# Fold 1: 0.6000
# Fold 2: 0.2000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.3000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 58:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.2000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 59:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.2000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.1000
# Fold 10: 0.6000
#
# Iteration 60:
# Fold 1: 0.6000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 61:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 62:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.3000
# Fold 10: 0.5000
#
# Iteration 63:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 64:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 65:
# Fold 1: 0.7000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.3000
#
# Iteration 66:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 67:
# Fold 1: 0.3000
# Fold 2: 0.3000
# Fold 3: 0.2000
# Fold 4: 0.3000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.7000
# Fold 8: 0.3000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 68:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.4000
#
# Iteration 69:
# Fold 1: 0.6000
# Fold 2: 0.8000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 70:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.5000
# Fold 5: 0.2000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.3000
#
# Iteration 71:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.3000
# Fold 4: 0.6000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 72:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.9000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.3000
# Fold 10: 0.4000
#
# Iteration 73:
# Fold 1: 0.3000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.3000
# Fold 5: 0.7000
# Fold 6: 0.3000
# Fold 7: 0.2000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 74:
# Fold 1: 0.7000
# Fold 2: 0.7000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.2000
# Fold 7: 0.4000
# Fold 8: 0.2000
# Fold 9: 0.5000
# Fold 10: 0.3000
#
# Iteration 75:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.3000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.3000
# Fold 9: 0.4000
# Fold 10: 0.1000
#
# Iteration 76:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.2000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 77:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 78:
# Fold 1: 0.8000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 79:
# Fold 1: 0.5000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 80:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.3000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 81:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.2000
# Fold 6: 0.6000
# Fold 7: 0.2000
# Fold 8: 0.6000
# Fold 9: 0.3000
# Fold 10: 0.5000
#
# Iteration 82:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 83:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 84:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.2000
#
# Iteration 85:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.7000
# Fold 6: 0.3000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 86:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.8000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 87:
# Fold 1: 0.8000
# Fold 2: 0.6000
# Fold 3: 0.2000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 88:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.8000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 89:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.3000
# Fold 10: 0.4000
#
# Iteration 90:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.8000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 91:
# Fold 1: 0.6000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 92:
# Fold 1: 0.4000
# Fold 2: 0.2000
# Fold 3: 0.6000
# Fold 4: 0.2000
# Fold 5: 0.6000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.1000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 93:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.3000
# Fold 7: 0.4000
# Fold 8: 0.2000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 94:
# Fold 1: 0.4000
# Fold 2: 0.8000
# Fold 3: 0.2000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 95:
# Fold 1: 0.7000
# Fold 2: 0.3000
# Fold 3: 0.7000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.8000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 96:
# Fold 1: 0.3000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 97:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.3000
# Fold 6: 0.5000
# Fold 7: 0.2000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 98:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.8000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 99:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.2000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.8000
# Fold 10: 0.4000
#
# Iteration 100:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.3000
# Fold 5: 0.4000
# Fold 6: 0.7000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Mean Scores for SVM: [0.46 0.47 0.48 0.46 0.45 0.49 0.48 0.52 0.46 0.43 0.49 0.45 0.45 0.52
#  0.46 0.47 0.45 0.44 0.48 0.52 0.47 0.42 0.48 0.47 0.51 0.52 0.47 0.47
#  0.45 0.49 0.44 0.5  0.46 0.53 0.51 0.44 0.48 0.55 0.44 0.43 0.45 0.51
#  0.43 0.49 0.46 0.45 0.48 0.46 0.48 0.5  0.51 0.5  0.52 0.49 0.45 0.49
#  0.51 0.51 0.45 0.54 0.49 0.45 0.54 0.5  0.51 0.47 0.46 0.49 0.48 0.43
#  0.45 0.46 0.44 0.48 0.45 0.46 0.52 0.53 0.46 0.5  0.44 0.51 0.49 0.5
#  0.47 0.46 0.49 0.54 0.48 0.53 0.47 0.41 0.4  0.47 0.53 0.55 0.47 0.55
#  0.47 0.52]
# Standard Deviations for SVM: [0.15620499 0.13453624 0.14696938 0.12       0.08062258 0.11357817
#  0.1077033  0.16       0.21071308 0.11       0.20712315 0.13601471
#  0.12041595 0.13266499 0.16248077 0.13453624 0.09219544 0.12
#  0.16613248 0.1077033  0.14177447 0.14       0.12489996 0.11874342
#  0.15779734 0.14       0.17916473 0.14177447 0.17464249 0.13747727
#  0.09165151 0.18439089 0.16248077 0.11       0.2118962  0.168523
#  0.14696938 0.12041595 0.1356466  0.20024984 0.09219544 0.16401219
#  0.15524175 0.17       0.20099751 0.1118034  0.08717798 0.10198039
#  0.12489996 0.08944272 0.13       0.13416408 0.13266499 0.13
#  0.13601471 0.12206556 0.17       0.13       0.18027756 0.11135529
#  0.14456832 0.09219544 0.10198039 0.08944272 0.13747727 0.09
#  0.19078784 0.15779734 0.15362291 0.14177447 0.13601471 0.18
#  0.168523   0.18867962 0.16881943 0.12       0.11661904 0.16155494
#  0.10198039 0.12649111 0.15620499 0.10440307 0.12206556 0.13416408
#  0.14177447 0.14282857 0.16401219 0.12       0.09797959 0.11
#  0.14177447 0.18138357 0.13416408 0.14866069 0.18466185 0.13601471
#  0.14177447 0.14317821 0.15524175 0.14      ]

# %%
# Calculate and print the mean and standard deviation of the scores
svm_mean_scores_4 = np.mean(svm_cv_scores)
svm_std_scores_4 = np.std(svm_cv_scores)
print("Mean Scores:", svm_mean_scores_4)
print("Standard Deviations:", svm_std_scores_4)
# Out:
# Mean Scores: 0.4796
# Standard Deviations: 0.14650542652065826

# %%
# Required imports
from sklearn.svm import SVC
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import cross_val_score, KFold
import numpy as np

# SVM Classifier definition
class SVMClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, kernel="rbf", C=1.0):
        self.model = SVC(kernel=kernel, C=C, probability=True)
        self.kernel = kernel
        self.C = C

    def fit(self, X, y=None):
        self.model.fit(X, y)
        return self

    def predict(self, X):
        return self.model.predict(X)

# Main section
if __name__ == "__main__":
    # Dummy data for demonstration
    X = np.random.rand(100, 10)  # 100 samples, 10 features
    y = np.random.randint(0, 2, 100)  # Binary labels (0 or 1) for 100 samples

    # Variables for cross-validation
    n_iterations = 100  # Number of iterations
    k_folds = 10  # Number of folds

    # Initialize SVM classifier
    svm_classifier = SVMClassifier()

    # Initialize a list to store cross-validation scores for SVM
    svm_cv_scores = []

    # Perform cross-validation for multiple iterations
    for _ in range(n_iterations):
        # Perform cross-validation and calculate scores for SVM
        kf = KFold(n_splits=k_folds, shuffle=True, random_state=None)
        scores = cross_val_score(svm_classifier, X, y, cv=kf)
        
        # Append the scores to the list for SVM
        svm_cv_scores.append(scores)

    # Convert the list of scores for SVM to a NumPy array for analysis
    svm_cv_scores = np.array(svm_cv_scores)

    # Print the cross-validation scores for each iteration and fold for SVM
    for i, scores in enumerate(svm_cv_scores):
        print(f"Iteration {i + 1}:")
        for j, score in enumerate(scores):
            print(f"Fold {j + 1}: {score:.4f}")
        print("")

    # Calculate and print the mean and standard deviation of the scores for SVM
    svm_mean_scores = np.mean(svm_cv_scores, axis=1)
    svm_std_scores = np.std(svm_cv_scores, axis=1)
    print("Mean Scores for SVM:", svm_mean_scores)
    print("Standard Deviations for SVM:", svm_std_scores)
# Out:
# Iteration 1:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.8000
# Fold 5: 0.7000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 2:
# Fold 1: 0.7000
# Fold 2: 0.6000
# Fold 3: 0.8000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 3:
# Fold 1: 0.5000
# Fold 2: 0.3000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.8000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 4:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.8000
# Fold 5: 0.5000
# Fold 6: 0.3000
# Fold 7: 0.7000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.8000
#
# Iteration 5:
# Fold 1: 0.6000
# Fold 2: 0.7000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 6:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.8000
# Fold 9: 0.3000
# Fold 10: 0.8000
#
# Iteration 7:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 8:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.8000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 9:
# Fold 1: 0.4000
# Fold 2: 0.8000
# Fold 3: 0.8000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.7000
#
# Iteration 10:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.8000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 11:
# Fold 1: 0.2000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.8000
#
# Iteration 12:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.8000
# Fold 10: 0.5000
#
# Iteration 13:
# Fold 1: 0.6000
# Fold 2: 0.3000
# Fold 3: 0.9000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.9000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 14:
# Fold 1: 0.4000
# Fold 2: 0.7000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 15:
# Fold 1: 0.9000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 16:
# Fold 1: 0.7000
# Fold 2: 0.6000
# Fold 3: 0.3000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 17:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.4000
# Fold 8: 0.8000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 18:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 19:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 20:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.8000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 21:
# Fold 1: 0.7000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.3000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 22:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 23:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.9000
# Fold 4: 0.3000
# Fold 5: 0.7000
# Fold 6: 0.4000
# Fold 7: 0.6000
# Fold 8: 0.8000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 24:
# Fold 1: 0.3000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.2000
# Fold 7: 0.7000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 25:
# Fold 1: 0.6000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.8000
# Fold 8: 0.7000
# Fold 9: 0.3000
# Fold 10: 0.4000
#
# Iteration 26:
# Fold 1: 0.4000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.8000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 27:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.3000
# Fold 6: 0.6000
# Fold 7: 0.8000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 28:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.3000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.8000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 29:
# Fold 1: 0.8000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 30:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.3000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.8000
#
# Iteration 31:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.8000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 32:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 33:
# Fold 1: 0.5000
# Fold 2: 0.2000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.9000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 34:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.9000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 35:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.9000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 36:
# Fold 1: 0.7000
# Fold 2: 0.3000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.8000
# Fold 6: 0.2000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.8000
#
# Iteration 37:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.3000
# Fold 8: 0.4000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 38:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 39:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.8000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 40:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.7000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.7000
#
# Iteration 41:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.8000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 42:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.8000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 43:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.3000
# Fold 8: 0.7000
# Fold 9: 0.9000
# Fold 10: 0.6000
#
# Iteration 44:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.3000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 45:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.4000
#
# Iteration 46:
# Fold 1: 0.8000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.2000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.9000
# Fold 9: 0.7000
# Fold 10: 0.8000
#
# Iteration 47:
# Fold 1: 0.8000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.3000
# Fold 8: 0.7000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 48:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.7000
# Fold 8: 0.6000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 49:
# Fold 1: 0.4000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.8000
# Fold 6: 0.4000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.6000
#
# Iteration 50:
# Fold 1: 0.7000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 51:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.6000
#
# Iteration 52:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.3000
# Fold 6: 0.7000
# Fold 7: 0.7000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 53:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.3000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.4000
#
# Iteration 54:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.2000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 55:
# Fold 1: 0.2000
# Fold 2: 0.7000
# Fold 3: 0.9000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.3000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 56:
# Fold 1: 0.8000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.3000
# Fold 9: 0.6000
# Fold 10: 0.2000
#
# Iteration 57:
# Fold 1: 0.7000
# Fold 2: 0.6000
# Fold 3: 0.4000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 58:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.3000
# Fold 4: 0.8000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.7000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.4000
#
# Iteration 59:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.4000
# Fold 8: 0.4000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 60:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.9000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.8000
# Fold 10: 0.7000
#
# Iteration 61:
# Fold 1: 0.9000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.3000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 62:
# Fold 1: 0.6000
# Fold 2: 0.7000
# Fold 3: 0.3000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 63:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.5000
# Fold 9: 0.8000
# Fold 10: 0.7000
#
# Iteration 64:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.8000
# Fold 6: 0.5000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.6000
#
# Iteration 65:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.2000
# Fold 10: 0.7000
#
# Iteration 66:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.9000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 67:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.8000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 68:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.5000
# Fold 10: 0.8000
#
# Iteration 69:
# Fold 1: 0.4000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.5000
# Fold 7: 0.8000
# Fold 8: 0.8000
# Fold 9: 0.3000
# Fold 10: 0.7000
#
# Iteration 70:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.7000
# Fold 5: 0.8000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 71:
# Fold 1: 0.8000
# Fold 2: 0.2000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.2000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.7000
#
# Iteration 72:
# Fold 1: 0.6000
# Fold 2: 0.4000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.8000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.7000
# Fold 9: 0.6000
# Fold 10: 0.5000
#
# Iteration 73:
# Fold 1: 0.7000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 74:
# Fold 1: 0.4000
# Fold 2: 0.3000
# Fold 3: 0.8000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.3000
# Fold 9: 0.4000
# Fold 10: 0.8000
#
# Iteration 75:
# Fold 1: 0.5000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.8000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 76:
# Fold 1: 0.6000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.8000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.4000
# Fold 8: 0.3000
# Fold 9: 0.6000
# Fold 10: 0.8000
#
# Iteration 77:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 78:
# Fold 1: 0.6000
# Fold 2: 0.2000
# Fold 3: 0.8000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Iteration 79:
# Fold 1: 0.3000
# Fold 2: 0.7000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.9000
# Fold 9: 0.8000
# Fold 10: 0.6000
#
# Iteration 80:
# Fold 1: 0.3000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 81:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.4000
# Fold 6: 0.5000
# Fold 7: 0.7000
# Fold 8: 0.4000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 82:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.7000
# Fold 5: 0.8000
# Fold 6: 0.7000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.2000
# Fold 10: 0.7000
#
# Iteration 83:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.7000
# Fold 6: 0.6000
# Fold 7: 0.3000
# Fold 8: 0.8000
# Fold 9: 0.7000
# Fold 10: 0.6000
#
# Iteration 84:
# Fold 1: 0.5000
# Fold 2: 0.4000
# Fold 3: 0.7000
# Fold 4: 0.4000
# Fold 5: 0.7000
# Fold 6: 0.8000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 85:
# Fold 1: 0.7000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.3000
# Fold 5: 0.7000
# Fold 6: 0.7000
# Fold 7: 0.3000
# Fold 8: 0.9000
# Fold 9: 0.2000
# Fold 10: 0.4000
#
# Iteration 86:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.8000
# Fold 5: 0.5000
# Fold 6: 0.4000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.8000
# Fold 10: 0.7000
#
# Iteration 87:
# Fold 1: 0.4000
# Fold 2: 0.8000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.4000
# Fold 8: 0.6000
# Fold 9: 0.3000
# Fold 10: 0.4000
#
# Iteration 88:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.6000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.4000
#
# Iteration 89:
# Fold 1: 0.7000
# Fold 2: 0.7000
# Fold 3: 0.6000
# Fold 4: 0.4000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.3000
# Fold 10: 0.7000
#
# Iteration 90:
# Fold 1: 0.8000
# Fold 2: 0.4000
# Fold 3: 0.6000
# Fold 4: 0.6000
# Fold 5: 0.5000
# Fold 6: 0.8000
# Fold 7: 0.5000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 91:
# Fold 1: 0.5000
# Fold 2: 0.8000
# Fold 3: 0.7000
# Fold 4: 0.5000
# Fold 5: 0.4000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.5000
# Fold 10: 0.7000
#
# Iteration 92:
# Fold 1: 0.8000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.3000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 93:
# Fold 1: 0.5000
# Fold 2: 0.9000
# Fold 3: 0.6000
# Fold 4: 0.3000
# Fold 5: 0.5000
# Fold 6: 0.5000
# Fold 7: 0.5000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 94:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.6000
# Fold 4: 0.5000
# Fold 5: 0.6000
# Fold 6: 0.2000
# Fold 7: 0.7000
# Fold 8: 0.5000
# Fold 9: 0.5000
# Fold 10: 0.5000
#
# Iteration 95:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.4000
# Fold 4: 0.6000
# Fold 5: 0.6000
# Fold 6: 0.7000
# Fold 7: 0.5000
# Fold 8: 0.7000
# Fold 9: 0.9000
# Fold 10: 0.3000
#
# Iteration 96:
# Fold 1: 0.5000
# Fold 2: 0.7000
# Fold 3: 0.4000
# Fold 4: 0.5000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.6000
# Fold 8: 0.7000
# Fold 9: 0.7000
# Fold 10: 0.5000
#
# Iteration 97:
# Fold 1: 0.6000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.7000
# Fold 5: 0.5000
# Fold 6: 0.7000
# Fold 7: 0.7000
# Fold 8: 0.6000
# Fold 9: 0.8000
# Fold 10: 0.3000
#
# Iteration 98:
# Fold 1: 0.6000
# Fold 2: 0.5000
# Fold 3: 0.5000
# Fold 4: 0.4000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.6000
# Fold 8: 0.5000
# Fold 9: 0.6000
# Fold 10: 0.8000
#
# Iteration 99:
# Fold 1: 0.4000
# Fold 2: 0.5000
# Fold 3: 0.7000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.8000
# Fold 8: 0.4000
# Fold 9: 0.4000
# Fold 10: 0.7000
#
# Iteration 100:
# Fold 1: 0.5000
# Fold 2: 0.6000
# Fold 3: 0.5000
# Fold 4: 0.6000
# Fold 5: 0.4000
# Fold 6: 0.6000
# Fold 7: 0.5000
# Fold 8: 0.6000
# Fold 9: 0.4000
# Fold 10: 0.5000
#
# Mean Scores for SVM: [0.62 0.62 0.57 0.6  0.54 0.62 0.61 0.56 0.58 0.61 0.58 0.57 0.56 0.56
#  0.53 0.53 0.58 0.58 0.57 0.58 0.52 0.56 0.58 0.54 0.6  0.54 0.57 0.53
#  0.61 0.58 0.59 0.59 0.61 0.57 0.55 0.57 0.56 0.56 0.58 0.57 0.59 0.57
#  0.59 0.58 0.55 0.55 0.56 0.57 0.55 0.57 0.55 0.57 0.48 0.56 0.56 0.52
#  0.56 0.56 0.54 0.61 0.55 0.55 0.61 0.56 0.54 0.62 0.6  0.56 0.59 0.58
#  0.52 0.59 0.56 0.54 0.56 0.57 0.55 0.53 0.6  0.55 0.56 0.56 0.6  0.56
#  0.55 0.59 0.5  0.51 0.55 0.57 0.59 0.57 0.53 0.53 0.58 0.58 0.6  0.55
#  0.55 0.52]
# Standard Deviations for SVM: [0.11661904 0.1077033  0.14177447 0.14142136 0.09165151 0.16
#  0.07       0.1356466  0.16613248 0.10440307 0.16613248 0.14866069
#  0.19078784 0.12       0.15524175 0.11874342 0.15362291 0.11661904
#  0.12688578 0.14696938 0.1077033  0.10198039 0.18330303 0.17435596
#  0.14832397 0.12806248 0.12688578 0.13453624 0.10440307 0.14696938
#  0.10440307 0.09433981 0.17578396 0.16155494 0.15       0.19519221
#  0.1356466  0.10198039 0.09797959 0.13453624 0.11357817 0.11
#  0.14456832 0.12489996 0.10246951 0.22472205 0.14282857 0.09
#  0.12845233 0.11       0.08062258 0.14177447 0.1077033  0.1496663
#  0.21071308 0.16613248 0.12       0.15620499 0.12806248 0.15779734
#  0.15652476 0.12845233 0.12206556 0.1356466  0.168523   0.11661904
#  0.1        0.1356466  0.15779734 0.14       0.19390719 0.13
#  0.12806248 0.18       0.12806248 0.16155494 0.06708204 0.17349352
#  0.17320508 0.13601471 0.12       0.18       0.12649111 0.12806248
#  0.22022716 0.13       0.14832397 0.07       0.12845233 0.14866069
#  0.12206556 0.14177447 0.14177447 0.12688578 0.16       0.1077033
#  0.13416408 0.1118034  0.14317821 0.07483315]

# %%
# Calculate and print the mean and standard deviation of the scores
svm_mean_scores_5 = np.mean(svm_cv_scores)
svm_std_scores_5 = np.std(svm_cv_scores)
print("Mean Scores:", svm_mean_scores_5)
print("Standard Deviations:", svm_std_scores_5)
# Out:
# Mean Scores: 0.5661999999999999
# Standard Deviations: 0.14218846648023178

# %%
values1 = [svm_mean_scores_1,svm_mean_scores_2,svm_mean_scores_3,svm_mean_scores_4,svm_mean_scores_5]
print(values1)
# Out:
# [0.5535999999999999, 0.5453, 0.4178, 0.4796, 0.5661999999999999]

# %%
values2 = [svm_std_scores_1,svm_std_scores_2,svm_std_scores_3,svm_std_scores_4,svm_std_scores_5]
print(values2)
# Out:
# [0.14834769967882885, 0.1472342011898051, 0.15219448084605433, 0.14650542652065826, 0.14218846648023178]

# %%
mean=np.mean(values1)
std=np.mean(values2)
print(mean)
print(std)
# Out:
# 0.5125
# 0.14729405494311565

# %%
import matplotlib.pyplot as plt
# Generating x-values based on the index of the list
x_values1 = list(range(len(values1)))

# Scatter plot with lines connecting the points
plt.figure(figsize=(8, 5))
plt.scatter(x_values1, values1, color='blue', marker='o', s=100)  # s is the marker size
plt.plot(x_values1, values1, color='blue', linestyle='-', linewidth=1.5)  # Connecting the points with a line

# Providing labels for the axes and the title for the graph
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Scatter Plot with Connected Points')
plt.xticks(x_values1)  # Setting x-ticks to match the indices

# Displaying the plot
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
# Generating x-values based on the index of the list
x_values2 = list(range(len(values2)))

# Scatter plot with lines connecting the points
plt.figure(figsize=(8, 5))
plt.scatter(x_values2, values2, color='blue', marker='o', s=100)  # s is the marker size
plt.plot(x_values2, values2, color='blue', linestyle='-', linewidth=1.5)  # Connecting the points with a line

# Providing labels for the axes and the title for the graph
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Scatter Plot with Connected Points')
plt.xticks(x_values2)  # Setting x-ticks to match the indices

# Displaying the plot
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# Standardizing the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Initializing and training the SVR with RBF kernel
svr_regressor_rbf = SVR(kernel='rbf', C=1.0, gamma='scale')  # You can adjust C and gamma as needed
svr_regressor_rbf.fit(X_train, y_train)

# Making predictions on the first entry of the test set as a demonstration
sample_X = X_test[0].reshape(1, -1)
predicted_bug_fixing_time = svr_regressor_rbf.predict(sample_X)[0]
print("Predicted value is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:  # Assuming a threshold of 1 for classifying as "Fast" or "Slow"
    print("Fast")
else:
    print("Slow")
# Out:
# Predicted value is: 0.09958363540881848
# Fast

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# Standardizing the features
scaler = StandardScaler()
X_train1 = scaler.fit_transform(X_train1)
X_test1 = scaler.transform(X_test1)

# Initializing and training the SVR with RBF kernel
svr_regressor_rbf = SVR(kernel='rbf', C=1.0, gamma='scale')  # You can adjust C and gamma as needed
svr_regressor_rbf.fit(X_train1, y_train1)

# Making predictions on the first entry of the test set as a demonstration
sample_X1 = X_test1[0].reshape(1, -1)
predicted_bug_fixing_time = svr_regressor_rbf.predict(sample_X1)[0]
print("Predicted value is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:  # Assuming a threshold of 1 for classifying as "Fast" or "Slow"
    print("Fast")
else:
    print("Slow")
# Out:
# Predicted value is: 0.09999999999999556
# Fast

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# Standardizing the features
scaler = StandardScaler()
X_train2 = scaler.fit_transform(X_train2)
X_test2 = scaler.transform(X_test2)

# Initializing and training the SVR with RBF kernel
svr_regressor_rbf = SVR(kernel='rbf', C=1.0, gamma='scale')  # You can adjust C and gamma as needed
svr_regressor_rbf.fit(X_train2, y_train2)

# Making predictions on the first entry of the test set as a demonstration
sample_X2 = X_test2[0].reshape(1, -1)
predicted_bug_fixing_time = svr_regressor_rbf.predict(sample_X2)[0]
print("Predicted value is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:  # Assuming a threshold of 2 for classifying as "Fast" or "Slow"
    print("Fast")
else:
    print("Slow")
# Out:
# Predicted value is: 0.09999999999999726
# Fast

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# Standardizing the features
scaler = StandardScaler()
X_train3 = scaler.fit_transform(X_train3)
X_test3 = scaler.transform(X_test3)

# Initializing and training the SVR with RBF kernel
svr_regressor_rbf = SVR(kernel='rbf', C=1.0, gamma='scale')  # You can adjust C and gamma as needed
svr_regressor_rbf.fit(X_train3, y_train3)

# Making predictions on the first entry of the test set as a demonstration
sample_X3 = X_test3[0].reshape(1, -1)
predicted_bug_fixing_time = svr_regressor_rbf.predict(sample_X3)[0]
print("Predicted value is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:  # Assuming a threshold of 3 for classifying as "Fast" or "Slow"
    print("Fast")
else:
    print("Slow")
# Out:
# Predicted value is: 0.10013123688778802
# Fast

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# Standardizing the features
scaler = StandardScaler()
X_train4 = scaler.fit_transform(X_train4)
X_test4 = scaler.transform(X_test4)

# Initializing and training the SVR with RBF kernel
svr_regressor_rbf = SVR(kernel='rbf', C=1.0, gamma='scale')  # You can adjust C and gamma as needed
svr_regressor_rbf.fit(X_train4, y_train4)

# Making predictions on the first entry of the test set as a demonstration
sample_X4 = X_test4[0].reshape(1, -1)
predicted_bug_fixing_time = svr_regressor_rbf.predict(sample_X4)[0]
print("Predicted value is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:  # Assuming a threshold of 4 for classifying as "Fast" or "Slow"
    print("Fast")
else:
    print("Slow")
# Out:
# Predicted value is: 0.0998367981366649
# Fast

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# Standardizing the features
scaler = StandardScaler()
X_train5 = scaler.fit_transform(X_train5)
X_test5 = scaler.transform(X_test5)

# Initializing and training the SVR with RBF kernel
svr_regressor_rbf = SVR(kernel='rbf', C=1.0, gamma='scale')  # You can adjust C and gamma as needed
svr_regressor_rbf.fit(X_train5, y_train5)

# Making predictions on the first entry of the test set as a demonstration
sample_X5 = X_test5[0].reshape(1, -1)
predicted_bug_fixing_time = svr_regressor_rbf.predict(sample_X5)[0]
print("Predicted value is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:  # Assuming a threshold of 5 for classifying as "Fast" or "Slow"
    print("Fast")
else:
    print("Slow")
# Out:
# Predicted value is: 0.09972915090880202
# Fast

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# Standardizing the features
scaler = StandardScaler()
X_train6 = scaler.fit_transform(X_train6)
X_test6 = scaler.transform(X_test6)

# Initializing and training the SVR with RBF kernel
svr_regressor_rbf = SVR(kernel='rbf', C=1.0, gamma='scale')  # You can adjust C and gamma as needed
svr_regressor_rbf.fit(X_train6, y_train6)

# Making predictions on the first entry of the test set as a demonstration
sample_X6 = X_test6[0].reshape(1, -1)
predicted_bug_fixing_time = svr_regressor_rbf.predict(sample_X6)[0]
print("Predicted value is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:  # Assuming a threshold of 6 for classifying as "Fast" or "Slow"
    print("Fast")
else:
    print("Slow")
# Out:
# Predicted value is: 0.09961372319085282
# Fast

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# Standardizing the features
scaler = StandardScaler()
X_train7 = scaler.fit_transform(X_train7)
X_test7 = scaler.transform(X_test7)

# Initializing and training the SVR with RBF kernel
svr_regressor_rbf = SVR(kernel='rbf', C=1.0, gamma='scale')  # You can adjust C and gamma as needed
svr_regressor_rbf.fit(X_train7, y_train7)

# Making predictions on the first entry of the test set as a demonstration
sample_X7 = X_test7[0].reshape(1, -1)
predicted_bug_fixing_time = svr_regressor_rbf.predict(sample_X7)[0]
print("Predicted value is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:  # Assuming a threshold of 7 for classifying as "Fast" or "Slow"
    print("Fast")
else:
    print("Slow")
# Out:
# Predicted value is: 0.10008301159156027
# Fast

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# Standardizing the features
scaler = StandardScaler()
X_train8 = scaler.fit_transform(X_train8)
X_test8 = scaler.transform(X_test8)

# Initializing and training the SVR with RBF kernel
svr_regressor_rbf = SVR(kernel='rbf', C=1.0, gamma='scale')  # You can adjust C and gamma as needed
svr_regressor_rbf.fit(X_train8, y_train8)

# Making predictions on the first entry of the test set as a demonstration
sample_X8 = X_test8[0].reshape(1, -1)
predicted_bug_fixing_time = svr_regressor_rbf.predict(sample_X8)[0]
print("Predicted value is:", predicted_bug_fixing_time)
if predicted_bug_fixing_time < 1:  # Assuming a threshold of 8 for classifying as "Fast" or "Slow"
    print("Fast")
else:
    print("Slow")
# Out:
# Predicted value is: 0.0999999999999587
# Fast

# %%
from sklearn.svm import SVC

# Train a non-linear SVM classifier using the RBF kernel
clf_svm = SVC(kernel='rbf', gamma='scale', random_state=42)  # gamma='scale' is the default and often works well
clf_svm.fit(X_train, y_train)

# Predict outcomes for the test data
y_pred = clf_svm.predict(X_test)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

precision = precision_score(y_test, y_pred, average='macro')
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred, average='macro')
f_measure_svm = f1_score(y_test, y_pred, average='macro')

def g_measure(y_test, y_pred):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test, y_pred, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test, y_pred)
MCC = matthews_corrcoef(y_test, y_pred)
AUC = roc_auc_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_svm)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.35288640595903165
# Accuracy: 0.7048977061376317
# Recall: 0.4991220368744513
# F-Measure: 0.41345454545454546
# G-Measure: 0.413454544969275
# Matthews correlation coefficient: -0.022729743582796103
# Area under curve: 0.4991220368744513
# Confusion Matrix:
#  [[1137    2]
#  [ 474    0]]
# Normalized Confusion Matrix:
#  [[0.99824407 0.00175593]
#  [1.         0.        ]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.49912280904898637
# Mean Square: 0.4991235785129509

# %%
from sklearn.svm import SVC

# Train a non-linear SVM classifier using the RBF kernel
clf_svm = SVC(kernel='rbf', gamma='scale', random_state=42)  # gamma='scale' is the default and often works well
clf_svm.fit(X_train1, y_train1)

# Predict outcomes for the test data
y_pred = clf_svm.predict(X_test1)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

precision = precision_score(y_test1, y_pred, average='macro')
accuracy = accuracy_score(y_test1, y_pred)
recall = recall_score(y_test1, y_pred, average='macro')
f_measure_svm = f1_score(y_test1, y_pred, average='macro')

def g_measure(y_test1, y_pred):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test1, y_pred, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test1, y_pred)
MCC = matthews_corrcoef(y_test1, y_pred)
AUC = roc_auc_score(y_test1, y_pred)
cm = confusion_matrix(y_test1, y_pred)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_svm)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.35294117647058826
# Accuracy: 0.7058823529411765
# Recall: 0.5
# F-Measure: 0.41379310344827586
# G-Measure: 0.41379310296313915
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[36  0]
#  [15  0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
from sklearn.svm import SVC

# Train a non-linear SVM classifier using the RBF kernel
clf_svm = SVC(kernel='rbf', gamma='scale', random_state=42)  # gamma='scale' is the default and often works well
clf_svm.fit(X_train2, y_train2)

# Predict outcomes for the test data
y_pred = clf_svm.predict(X_test2)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

precision = precision_score(y_test2, y_pred, average='macro')
accuracy = accuracy_score(y_test2, y_pred)
recall = recall_score(y_test2, y_pred, average='macro')
f_measure_svm = f1_score(y_test2, y_pred, average='macro')

def g_measure(y_test2, y_pred):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test2, y_pred, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test2, y_pred)
MCC = matthews_corrcoef(y_test2, y_pred)
AUC = roc_auc_score(y_test2, y_pred)
cm = confusion_matrix(y_test2, y_pred)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_svm)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.3333333333333333
# Accuracy: 0.6666666666666666
# Recall: 0.5
# F-Measure: 0.4
# G-Measure: 0.39999999952000004
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[56  0]
#  [28  0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
from sklearn.svm import SVC

# Train a non-linear SVM classifier using the RBF kernel
clf_svm = SVC(kernel='rbf', gamma='scale', random_state=42)  # gamma='scale' is the default and often works well
clf_svm.fit(X_train3, y_train3)

# Predict outcomes for the test data
y_pred = clf_svm.predict(X_test3)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

precision = precision_score(y_test3, y_pred, average='macro')
accuracy = accuracy_score(y_test3, y_pred)
recall = recall_score(y_test3, y_pred, average='macro')
f_measure_svm = f1_score(y_test3, y_pred, average='macro')

def g_measure(y_test3, y_pred):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test3, y_pred, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test3, y_pred)
MCC = matthews_corrcoef(y_test3, y_pred)
AUC = roc_auc_score(y_test3, y_pred)
cm = confusion_matrix(y_test3, y_pred)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_svm)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.6113003095975232
# Accuracy: 0.5934959349593496
# Recall: 0.5950555261766262
# F-Measure: 0.5787671232876712
# G-Measure: 0.6030685412890996
# Matthews correlation coefficient: 0.205715429585765
# Area under curve: 0.595055526176626
# Confusion Matrix:
#  [[48 13]
#  [37 25]]
# Normalized Confusion Matrix:
#  [[0.78688525 0.21311475]
#  [0.59677419 0.40322581]]
# Min: 0.21311475409836064
# Max: 0.7868852459016393
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.21408922071531852
# Mean Square: 0.29583419442649234

# %%
from sklearn.svm import SVC

# Train a non-linear SVM classifier using the RBF kernel
clf_svm = SVC(kernel='rbf', gamma='scale', random_state=42)  # gamma='scale' is the default and often works well
clf_svm.fit(X_train4, y_train4)

# Predict outcomes for the test data
y_pred = clf_svm.predict(X_test4)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

precision = precision_score(y_test4, y_pred, average='macro')
accuracy = accuracy_score(y_test4, y_pred)
recall = recall_score(y_test4, y_pred, average='macro')
f_measure_svm = f1_score(y_test4, y_pred, average='macro')

def g_measure(y_test4, y_pred):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test4, y_pred, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test4, y_pred)
MCC = matthews_corrcoef(y_test4, y_pred)
AUC = roc_auc_score(y_test4, y_pred)
cm = confusion_matrix(y_test4, y_pred)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_svm)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.927710843373494
# Accuracy: 0.8579881656804734
# Recall: 0.5555555555555556
# F-Measure: 0.561038961038961
# G-Measure: 0.6949458479069273
# Matthews correlation coefficient: 0.3082966981383334
# Area under curve: 0.5555555555555556
# Confusion Matrix:
#  [[142   0]
#  [ 24   3]]
# Normalized Confusion Matrix:
#  [[1.         0.        ]
#  [0.88888889 0.11111111]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.4479032082388083
# Mean Square: 0.4506172839506173

# %%
from sklearn.svm import SVC

# Train a non-linear SVM classifier using the RBF kernel
clf_svm = SVC(kernel='rbf', gamma='scale', random_state=42)  # gamma='scale' is the default and often works well
clf_svm.fit(X_train5, y_train5)

# Predict outcomes for the test data
y_pred = clf_svm.predict(X_test5)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

precision = precision_score(y_test5, y_pred, average='macro')
accuracy = accuracy_score(y_test5, y_pred)
recall = recall_score(y_test5, y_pred, average='macro')
f_measure_svm = f1_score(y_test5, y_pred, average='macro')

def g_measure(y_test5, y_pred):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test5, y_pred, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test5, y_pred)
MCC = matthews_corrcoef(y_test5, y_pred)
AUC = roc_auc_score(y_test5, y_pred)
cm = confusion_matrix(y_test5, y_pred)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_svm)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.8771428571428572
# Accuracy: 0.7611111111111111
# Recall: 0.5520833333333334
# F-Measure: 0.5243070493516071
# G-Measure: 0.6776477443095047
# Matthews correlation coefficient: 0.2803059552906941
# Area under curve: 0.5520833333333334
# Confusion Matrix:
#  [[132   0]
#  [ 43   5]]
# Normalized Confusion Matrix:
#  [[1.         0.        ]
#  [0.89583333 0.10416667]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.4509346004565284
# Mean Square: 0.4533420138888889

# %%
from sklearn.svm import SVC

# Train a non-linear SVM classifier using the RBF kernel
clf_svm = SVC(kernel='rbf', gamma='scale', random_state=42)  # gamma='scale' is the default and often works well
clf_svm.fit(X_train6, y_train6)

# Predict outcomes for the test data
y_pred = clf_svm.predict(X_test6)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

precision = precision_score(y_test6, y_pred, average='macro')
accuracy = accuracy_score(y_test6, y_pred)
recall = recall_score(y_test6, y_pred, average='macro')
f_measure_svm = f1_score(y_test6, y_pred, average='macro')

def g_measure(y_test6, y_pred):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test6, y_pred, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test6, y_pred)
MCC = matthews_corrcoef(y_test6, y_pred)
AUC = roc_auc_score(y_test6, y_pred)
cm = confusion_matrix(y_test6, y_pred)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_svm)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.3270893371757925
# Accuracy: 0.654178674351585
# Recall: 0.5
# F-Measure: 0.3954703832752613
# G-Measure: 0.3954703827971142
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[227   0]
#  [120   0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
from sklearn.svm import SVC

# Train a non-linear SVM classifier using the RBF kernel
clf_svm = SVC(kernel='rbf', gamma='scale', random_state=42)  # gamma='scale' is the default and often works well
clf_svm.fit(X_train7, y_train7)

# Predict outcomes for the test data
y_pred = clf_svm.predict(X_test7)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

precision = precision_score(y_test7, y_pred, average='macro')
accuracy = accuracy_score(y_test7, y_pred)
recall = recall_score(y_test7, y_pred, average='macro')
f_measure_svm = f1_score(y_test7, y_pred, average='macro')

def g_measure(y_test7, y_pred):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test7, y_pred, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test7, y_pred)
MCC = matthews_corrcoef(y_test7, y_pred)
AUC = roc_auc_score(y_test7, y_pred)
cm = confusion_matrix(y_test7, y_pred)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_svm)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.38493723849372385
# Accuracy: 0.7698744769874477
# Recall: 0.5
# F-Measure: 0.43498817966903075
# G-Measure: 0.43498817917748384
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[184   0]
#  [ 55   0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5

# %%
from sklearn.svm import SVC

# Train a non-linear SVM classifier using the RBF kernel
clf_svm = SVC(kernel='rbf', gamma='scale', random_state=42)  # gamma='scale' is the default and often works well
clf_svm.fit(X_train8, y_train8)

# Predict outcomes for the test data
y_pred = clf_svm.predict(X_test8)

# %%
import numpy as np
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, precision_recall_fscore_support, matthews_corrcoef, roc_auc_score, confusion_matrix

precision = precision_score(y_test8, y_pred, average='macro')
accuracy = accuracy_score(y_test8, y_pred)
recall = recall_score(y_test8, y_pred, average='macro')
f_measure_svm = f1_score(y_test8, y_pred, average='macro')

def g_measure(y_test8, y_pred):
    # Compute precision, recall, and F1-score
    precision, recall, _, _ = precision_recall_fscore_support(y_test8, y_pred, average='macro')
    # Calculate the G-Measure
    g_measure = (2 * precision * recall) / (precision + recall + 1e-9)  # Add a small epsilon to avoid division by zero
    return g_measure

G_Measure = g_measure(y_test8, y_pred)
MCC = matthews_corrcoef(y_test8, y_pred)
AUC = roc_auc_score(y_test8, y_pred)
cm = confusion_matrix(y_test8, y_pred)

# Normalize confusion matrix to range from 0 to 1
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Statistical measures
min_val = np.min(cm_normalized)
max_val = np.max(cm_normalized)
avg_val = np.mean(cm_normalized)
mean_val = np.mean(cm_normalized)
std_dev = np.std(cm_normalized)
mean_square = np.mean(cm_normalized ** 2)

# Print the results
print("Precision:", precision)
print("Accuracy:", accuracy)
print("Recall:", recall)
print("F-Measure:", f_measure_svm)
print("G-Measure:", G_Measure)
print("Matthews correlation coefficient:", MCC)
print("Area under curve:", AUC)
print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)
print("Min:", min_val)
print("Max:", max_val)
print("Average:", avg_val)
print("Mean:", mean_val)
print("Standard Deviation:", std_dev)
print("Mean Square:", mean_square)
# Out:
# Precision: 0.3412322274881517
# Accuracy: 0.6824644549763034
# Recall: 0.5
# F-Measure: 0.4056338028169015
# G-Measure: 0.4056338023347114
# Matthews correlation coefficient: 0.0
# Area under curve: 0.5
# Confusion Matrix:
#  [[288   0]
#  [134   0]]
# Normalized Confusion Matrix:
#  [[1. 0.]
#  [1. 0.]]
# Min: 0.0
# Max: 1.0
# Average: 0.5
# Mean: 0.5
# Standard Deviation: 0.5
# Mean Square: 0.5
